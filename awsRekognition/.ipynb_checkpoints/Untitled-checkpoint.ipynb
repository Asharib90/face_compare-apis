# %%
aws rekognition create-collection --collection-id attandence_collection --region us-east-2

# %%
import boto3
import io
from PIL import Image
from pathlib import Path
import tempfile

name = 'abcd'
name_with_ext =  name + '.png'
path = 'register/'+ name_with_ext
region_name='us-east-2'
bucket ='attandence-bucket'
collection_id = "attandence_collection"
TableName='attandence_collection'

rekognition = boto3.client('rekognition', region_name = region_name)
dynamodb = boto3.client('dynamodb', region_name = region_name)
s3 = boto3.resource('s3')

file = open(name_with_ext,'rb')
object = s3.Object('attandence-bucket',path)
s3_upload = object.put(Body=file,
                Metadata={'FullName':name}
                )

index_face_response=rekognition.index_faces(CollectionId=collection_id,
                            Image={'S3Object':{'Bucket':bucket,'Name':path}},
                            MaxFaces=1,
                            QualityFilter="AUTO",
                            DetectionAttributes=['ALL'])

faceId = index_face_response['FaceRecords'][0]['Face']['FaceId']

dynamodb_response = dynamodb.put_item(
    TableName = TableName,
    Item={
        'RekognitionId': {'S': faceId},
        'FullName': {'S': name}
        }
    )

faceId
# Out:
# '635305bc-d7f8-4e02-8ba2-4f17c5ef2c3c'

# %%
index_face_response

# %%
import boto3
import io
from PIL import Image

name = '07010017'
name_with_ext =  name + '.jpg'
path = 'verify/'+ name_with_ext
region_name='us-east-2'
threshold=80

TableName='attandence_collection'
bucket ='attandence-bucket'
collection_id = "attandence_collection"

rekognition = boto3.client('rekognition', region_name = region_name)
dynamodb = boto3.client('dynamodb', region_name = region_name)
s3 = boto3.resource('s3')

response = rekognition.search_faces_by_image(
    Image={
        "S3Object": {
            "Bucket": bucket,
            "Name": path,
        }
    },
    CollectionId=collection_id,
    FaceMatchThreshold=threshold)

faceId = response['FaceMatches'][0]['Face']['FaceId']
similarity = response['FaceMatches'][0]['Similarity']

dynamodb_response = dynamodb.get_item(
    TableName=TableName,  
    Key={'RekognitionId':{'S': faceId}})


RekognitionId = dynamodb_response['Item']['RekognitionId']['S']
FullName = dynamodb_response['Item']['FullName']['S']

RekognitionId,FullName
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [14], in <cell line: 37>()
#      30 similarity = response['FaceMatches'][0]['Similarity']
#      32 dynamodb_response = dynamodb.get_item(
#      33     TableName=TableName,
#      34     Key={'RekognitionId':{'S': faceId}})
# ---> 37 RekognitionId = dynamodb_response['Item']['RekognitionId']['S']
#      38 FullName = dynamodb_response['Item']['FullName']['S']
#      40 RekognitionId,FullName
#
# KeyError: 'Item'

# %%
s3 = boto3.resource('s3')

# Get list of objects for indexing
images=[('abcd.png','Albert Einstein')]

# Iterate through list to upload objects to S3   
for image in images:
    file = open(image[0],'rb')
    object = s3.Object('attandence-bucket','index/'+ image[0])
    ret = object.put(Body=file,
                    Metadata={'FullName':image[1]}
                    )

# %%
import boto3
import io
from PIL import Image

rekognition = boto3.client('rekognition', region_name='us-east-2')
dynamodb = boto3.client('dynamodb', region_name='us-east-2')
    
image = Image.open("07010017.jpg")
stream = io.BytesIO()
image.save(stream,format="JPEG")
image_binary = stream.getvalue()


response = rekognition.search_faces_by_image(
        CollectionId='attandence_collection',
        Image={'Bytes':image_binary}                                       
        )
for match in response['FaceMatches']:
    print (match['Face']['FaceId'],match['Face']['Confidence'])
        
    face = dynamodb.get_item(
        TableName='attandence_collection',  
        Key={'RekognitionId': {'S': match['Face']['FaceId']}}
        )
    
    if 'Item' in face:
        print (face['Item']['FullName']['S'])
    else:
        print ('no match found in person lookup')
# Out:
# 2d7a55ff-9704-40ac-bb17-aa5f2f36b528 99.99840545654297
# no match found in person lookup

# %%
#Copyright 2018 Amazon.com, Inc. or its affiliates. All Rights Reserved.
#PDX-License-Identifier: MIT-0 (For details, see https://github.com/awsdocs/amazon-rekognition-developer-guide/blob/master/LICENSE-SAMPLECODE.)

import boto3

# TableName='attandence_collection'
# bucket ='attandence-bucket'
# collection_id = "attandence_collection"

def delete_faces_from_collection(collection_id, faces):

    client=boto3.client('rekognition','us-east-2')

    response=client.delete_faces(CollectionId=collection_id,
                               FaceIds=faces)
    
    print(str(len(response['DeletedFaces'])) + ' faces deleted:') 							
    for faceId in response['DeletedFaces']:
         print (faceId)
    return len(response['DeletedFaces'])

def main():

    collection_id='attandence_collection'
    faces=[]
    faces.append("2d7a55ff-9704-40ac-bb17-aa5f2f36b528")

    faces_count=delete_faces_from_collection(collection_id, faces)
    print("deleted faces count: " + str(faces_count))

if __name__ == "__main__":
    main()
# Out:
# 1 faces deleted:
# 2d7a55ff-9704-40ac-bb17-aa5f2f36b528
# deleted faces count: 1

# %%
import boto3

BUCKET = "attandence-bucket"
KEY_SOURCE = "index/bb.jpg"
KEY_TARGET = "index/01.jpg"

def compare_faces(bucket, key, bucket_target, key_target, threshold=80, region="us-east-2"):
    rekognition = boto3.client("rekognition", region)
    response = rekognition.compare_faces(
        SourceImage={
            "S3Object": {
                "Bucket": bucket,
                "Name": key,
            }
        },
        TargetImage={
            "S3Object": {
                "Bucket": bucket_target,
                "Name": key_target,
            }
        },
           SimilarityThreshold=threshold,
    )
    print (response)
    
    return(response['SourceImageFace'], response['FaceMatches'])


source_face, matches = compare_faces(BUCKET, KEY_SOURCE, BUCKET, KEY_TARGET)

# the main source face
print ("Source Face ({Confidence}%)".format(**source_face))

# one match for each target face
for match in matches:
    print ("Target Face ({Confidence}%)".format(**match['Face']))
    print ("  Similarity : {}%".format(match['Similarity']))
# Out:
# ---------------------------------------------------------------------------
# InvalidS3ObjectException                  Traceback (most recent call last)
# /tmp/ipykernel_5020/272145641.py in <module>
#      27
#      28
# ---> 29 source_face, matches = compare_faces(BUCKET, KEY_SOURCE, BUCKET, KEY_TARGET)
#      30
#      31 # the main source face
#
# /tmp/ipykernel_5020/272145641.py in compare_faces(bucket, key, bucket_target, key_target, threshold, region)
#       7 def compare_faces(bucket, key, bucket_target, key_target, threshold=80, region="us-east-2"):
#       8     rekognition = boto3.client("rekognition", region)
# ----> 9     response = rekognition.compare_faces(
#      10         SourceImage={
#      11             "S3Object": {
#
# ~/anaconda3/lib/python3.8/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     389                     "%s() only accepts keyword arguments." % py_operation_name)
#     390             # The "self" in this scope is referring to the BaseClient.
# --> 391             return self._make_api_call(operation_name, kwargs)
#     392
#     393         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/lib/python3.8/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     717             error_code = parsed_response.get("Error", {}).get("Code")
#     718             error_class = self.exceptions.from_code(error_code)
# --> 719             raise error_class(parsed_response, operation_name)
#     720         else:
#     721             return parsed_response
#
# InvalidS3ObjectException: An error occurred (InvalidS3ObjectException) when calling the CompareFaces operation: Unable to get object metadata from S3. Check object key, region and/or access permissions.

# %%
import boto3

BUCKET = "attandence-bucket"
KEY = "verify/07010017.jpg"
COLLECTION = "attandence_collection"

def search_faces_by_image(bucket, key, collection_id, threshold=80, region="us-east-2"):
    rekognition = boto3.client("rekognition", region)
    response = rekognition.search_faces_by_image(
        Image={
            "S3Object": {
                "Bucket": bucket,
                "Name": key,
            }
        },
        CollectionId=collection_id,
        FaceMatchThreshold=threshold,
    )
    return (response['FaceMatches'])

for record in search_faces_by_image(BUCKET, KEY, COLLECTION):
    face = record['Face']
    print ("Matched Face ({}%)".format(record['Similarity']))
    print ("  FaceId : {}".format(face['FaceId']))
#     print ("  ImageId : {}".format(face['ExternalImageId']))
# Out:
# Matched Face (99.9436264038086%)
#   FaceId : 2d7a55ff-9704-40ac-bb17-aa5f2f36b528

# %%
client=boto3.client('rekognition')

dynamodb = boto3.client('dynamodb')
s3 = boto3.client('s3')


def add_faces_to_collection(bucket,photo,collection_id):

    response = dynamodb.put_item(
        TableName=bucket,
        Item={
            'RekognitionId': {'S': faceId},
            'FullName': {'S': fullName}
            }
        ) 

    response=client.index_faces(CollectionId=collection_id,
                                Image={'S3Object':{'Bucket':bucket,'Name':photo}},
                                MaxFaces=1,
                                QualityFilter="AUTO",
                                DetectionAttributes=['ALL'])

    print ('Results for ' + photo) 
    print('Faces indexed:')
    for faceRecord in response['FaceRecords']:
         print('  Face ID: ' + faceRecord['Face']['FaceId'])
         print('  Location: {}'.format(faceRecord['Face']['BoundingBox']))

    print('Faces not indexed:')
    for unindexedFace in response['UnindexedFaces']:
        print(' Location: {}'.format(unindexedFace['FaceDetail']['BoundingBox']))
        print(' Reasons:')
        for reason in unindexedFace['Reasons']:
            print('   ' + reason)
    return len(response['FaceRecords'])


bucket='attandence-bucket'
collection_id='attandence_collection'
photo="index/aa.jpg"


indexed_faces_count=add_faces_to_collection(bucket, photo, collection_id)
print("Faces indexed count: " + str(indexed_faces_count))
# Out:
# Results for index/aa.jpg
# Faces indexed:
#   Face ID: 44a6198c-919f-419e-990c-884dabafd440
#   Location: {'Width': 0.5961723327636719, 'Height': 0.47871923446655273, 'Left': 0.2804256081581116, 'Top': 0.3142184019088745}
# Faces not indexed:
# Faces indexed count: 1

# %%
import boto3

def list_faces_in_collection(collection_id):


    maxResults=2
    faces_count=0
    tokens=True

    client=boto3.client('rekognition', "us-east-2")
    response=client.list_faces(CollectionId=collection_id,
                               MaxResults=maxResults)

    print('Faces in collection ' + collection_id)
 
    while tokens:

        faces=response['Faces']

        for face in faces:
            print (face)
            faces_count+=1
        if 'NextToken' in response:
            nextToken=response['NextToken']
            response=client.list_faces(CollectionId=collection_id,
                                       NextToken=nextToken,MaxResults=maxResults)
        else:
            tokens=False
    return faces_count   
def main():

    collection_id='attandence_collection'
    
    faces_count=list_faces_in_collection(collection_id)
    print("faces count: " + str(faces_count))
if __name__ == "__main__":
    main()
# Out:
# Faces in collection attandence_collection
# {'FaceId': '00046532-1ea3-406d-bca5-a5c4c8754dd5', 'BoundingBox': {'Width': 0.33466199040412903, 'Height': 0.36045700311660767, 'Left': 0.3138909935951233, 'Top': 0.29532700777053833}, 'ImageId': '561829cd-2efd-3247-8783-643d2d1d906f', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '00c8fc6f-ccf3-4264-b946-530d32954c1d', 'BoundingBox': {'Width': 0.4525409936904907, 'Height': 0.4694550037384033, 'Left': 0.36021900177001953, 'Top': 0.11219000071287155}, 'ImageId': 'e0e1e007-4e39-34ec-854c-12d50f998b91', 'Confidence': 99.99930572509766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '00ec8606-6853-4e41-bd48-fa54b5588300', 'BoundingBox': {'Width': 0.28390198945999146, 'Height': 0.28691598773002625, 'Left': 0.3172059953212738, 'Top': 0.48694300651550293}, 'ImageId': '586c5d6f-a104-3f1e-b3fb-e0bfce5d8b7f', 'Confidence': 99.99939727783203, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '039b205b-c25c-46bd-99a8-205bcfb4890c', 'BoundingBox': {'Width': 0.4974440038204193, 'Height': 0.31957000494003296, 'Left': 0.2723200023174286, 'Top': 0.25080400705337524}, 'ImageId': '4eaf7aee-121c-3a15-8cf5-6fa71219f0f8', 'Confidence': 99.99559783935547, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '03ebec70-4b4f-4873-af85-7687900e0933', 'BoundingBox': {'Width': 0.47305500507354736, 'Height': 0.5418130159378052, 'Left': 0.35868600010871887, 'Top': 0.35829800367355347}, 'ImageId': 'bfc07b69-2007-3cc7-90b9-3b65a48af5ca', 'Confidence': 99.99829864501953, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '0458bfa8-c87b-4a69-a2ce-1d4b84d269d9', 'BoundingBox': {'Width': 0.32307198643684387, 'Height': 0.3240180015563965, 'Left': 0.2760320007801056, 'Top': 0.20314300060272217}, 'ImageId': 'c9b3946d-0f55-3abe-b831-aca5c3aff2e0', 'Confidence': 99.99970245361328, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '080d4ed4-a587-4e95-b72d-c66bfb3abec3', 'BoundingBox': {'Width': 0.3103730082511902, 'Height': 0.32394400238990784, 'Left': 0.30849701166152954, 'Top': 0.24153999984264374}, 'ImageId': 'c3172ba3-50c3-3d64-a724-d95fc91ec2d6', 'Confidence': 99.99949645996094, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '08f3cd64-878c-4c57-a701-8afa3436a9f5', 'BoundingBox': {'Width': 0.432778000831604, 'Height': 0.44930899143218994, 'Left': 0.26585501432418823, 'Top': 0.24363000690937042}, 'ImageId': '23f5d71c-a770-386d-bff7-b6773fb31815', 'Confidence': 99.99960327148438, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '09d5c2a0-a4fa-4717-9838-020d7aa0d673', 'BoundingBox': {'Width': 0.4535689949989319, 'Height': 0.380748987197876, 'Left': 0.27581799030303955, 'Top': 0.2207449972629547}, 'ImageId': '7550ca3a-af68-3650-b133-d893c56e0189', 'Confidence': 99.84960174560547, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '09feee21-0c7d-4e07-bf4c-4fa7cebe5a5d', 'BoundingBox': {'Width': 0.5478609800338745, 'Height': 0.5909489989280701, 'Left': 0.28284499049186707, 'Top': 0.10773000121116638}, 'ImageId': '7bcf450f-4bfc-38e3-b20e-70feeb14fb1b', 'Confidence': 99.99949645996094, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '0a43b7b5-9236-4c6f-8317-7c8ba2b98fe5', 'BoundingBox': {'Width': 0.4939880073070526, 'Height': 0.5002899765968323, 'Left': 0.26822999119758606, 'Top': 0.2328770011663437}, 'ImageId': 'e84c7bbd-48b7-3340-912e-14d271ed4eb3', 'Confidence': 99.99889373779297, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '0aa56333-34eb-4af9-94f6-3892231d6158', 'BoundingBox': {'Width': 0.3774999976158142, 'Height': 0.39392900466918945, 'Left': 0.29034000635147095, 'Top': 0.45041999220848083}, 'ImageId': '5d9dbf7a-d7c0-3e5d-998d-79b2413002a1', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '0c87a5c6-9d26-42f2-ac80-2bf1b9ee154b', 'BoundingBox': {'Width': 0.3613409996032715, 'Height': 0.3867180049419403, 'Left': 0.31445199251174927, 'Top': 0.29234200716018677}, 'ImageId': '9ab781ce-5ba5-3edb-9f5d-9da5268e1930', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '0f8893aa-58a0-48e7-8f61-ead91f834671', 'BoundingBox': {'Width': 0.6179280281066895, 'Height': 0.3697449862957001, 'Left': 0.2304140031337738, 'Top': 0.3033050000667572}, 'ImageId': '11d73d50-22cc-3d60-92d5-be6f7a3badba', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '1072daff-78d4-4ccf-8c0c-dccf8e3d633e', 'BoundingBox': {'Width': 0.17125000059604645, 'Height': 0.1865610033273697, 'Left': 0.5142289996147156, 'Top': 0.41734498739242554}, 'ImageId': '14d388bb-b3f9-3302-8ab3-26314d9f43b2', 'Confidence': 99.99690246582031, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '1149234f-d4e5-4978-9a74-815f613bf6ef', 'BoundingBox': {'Width': 0.6283149719238281, 'Height': 0.5096759796142578, 'Left': 0.10363399982452393, 'Top': 0.0002028779999818653}, 'ImageId': '7f3dc4d0-8f72-3653-8f4b-22b58e720c23', 'Confidence': 99.99909973144531, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '11afcc18-d50a-4d03-b208-9790eb4cebbb', 'BoundingBox': {'Width': 0.2781600058078766, 'Height': 0.29985499382019043, 'Left': 0.37454599142074585, 'Top': 0.3638080060482025}, 'ImageId': '2e02f801-3f52-3f95-8f2a-c2630d6785e3', 'Confidence': 99.99829864501953, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '12047b69-459c-4399-85be-36d5c97fabf4', 'BoundingBox': {'Width': 0.49758198857307434, 'Height': 0.3856450021266937, 'Left': 0.2497120052576065, 'Top': 0.1465660035610199}, 'ImageId': '6833a6be-61d7-3899-b221-b0d2839f1892', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '120b39a3-5212-4165-9b5f-64e0feb744c4', 'BoundingBox': {'Width': 0.3234879970550537, 'Height': 0.3278369903564453, 'Left': 0.3935129940509796, 'Top': 0.12600399553775787}, 'ImageId': 'e0b60518-3c73-3ee7-8652-7588e5052307', 'Confidence': 99.99949645996094, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '126baf17-b051-48f9-9d8a-544c5c98c747', 'BoundingBox': {'Width': 0.4783729910850525, 'Height': 0.5328829884529114, 'Left': 0.23201699554920197, 'Top': 0.2936680018901825}, 'ImageId': 'bbd81c48-8e39-3087-af20-b10e07d833c4', 'Confidence': 99.99919891357422, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '1410b75b-af56-4459-9155-b68a4f9b09c4', 'BoundingBox': {'Width': 0.3707219958305359, 'Height': 0.3733319938182831, 'Left': 0.29656898975372314, 'Top': 0.2652739882469177}, 'ImageId': '87b0de03-257b-364d-b48a-606b89b84218', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '163c151e-2969-42c9-b4eb-e0f59456fe0d', 'BoundingBox': {'Width': 0.7749459743499756, 'Height': 0.44913598895072937, 'Left': 0.1492139995098114, 'Top': 0.18761099874973297}, 'ImageId': '8bdc0db2-88af-30be-96b6-436c86c818ba', 'Confidence': 99.99970245361328, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '17ec0fac-eba7-4e42-8891-badf37bca62f', 'BoundingBox': {'Width': 0.44937101006507874, 'Height': 0.2267879992723465, 'Left': 0.38727399706840515, 'Top': 0.3216229975223541}, 'ImageId': '5f1cce8d-2f47-3893-9a67-215e64f0c696', 'Confidence': 99.98930358886719, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '191f976f-7367-466a-ac8a-af4ecf8e5a3e', 'BoundingBox': {'Width': 0.4519689977169037, 'Height': 0.4522640109062195, 'Left': 0.28938600420951843, 'Top': 0.14709599316120148}, 'ImageId': '253b3971-a439-3017-9848-257f09e84e91', 'Confidence': 99.99819946289062, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '19db590c-72fc-4ec6-aef3-141dd75f639e', 'BoundingBox': {'Width': 0.5369579792022705, 'Height': 0.43733999133110046, 'Left': 0.20366400480270386, 'Top': 0.24355000257492065}, 'ImageId': 'dcc9e8ca-e8a2-3ce7-ba25-c976e398b7dc', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '1a827ff1-d58c-4c93-af24-d2a2f9d54e0b', 'BoundingBox': {'Width': 0.33605098724365234, 'Height': 0.3485400080680847, 'Left': 0.38273900747299194, 'Top': 0.151419997215271}, 'ImageId': '59a98a22-6f1c-3b64-9ab3-88b53b66faec', 'Confidence': 99.99970245361328, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '1bfcfc04-43b1-47fb-8614-3fcb471824a7', 'BoundingBox': {'Width': 0.7621889710426331, 'Height': 0.5004709959030151, 'Left': 0.07364600151777267, 'Top': -0.00779312988743186}, 'ImageId': '7cb6cd61-9209-3ffa-8bfe-ec1e1a5fca12', 'Confidence': 99.99859619140625, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '1c4d96a9-f314-428e-ba3e-c1e6dec7b81a', 'BoundingBox': {'Width': 0.09816809743642807, 'Height': 0.10565400123596191, 'Left': 0.4954630136489868, 'Top': 0.15657399594783783}, 'ImageId': 'e39197c1-398b-3f84-9018-fbff8b89c122', 'Confidence': 99.93069458007812, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '1cf7bda1-61fd-4fbe-ba9c-057a650014a8', 'BoundingBox': {'Width': 0.6048589944839478, 'Height': 0.6374359726905823, 'Left': 0.1669899970293045, 'Top': 0.016903599724173546}, 'ImageId': '6c556132-09c8-32eb-a0e9-c7b44b5fce02', 'Confidence': 100.0, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '1d6716d7-2686-4414-8191-4dee176bfac1', 'BoundingBox': {'Width': 0.5489519834518433, 'Height': 0.3469240069389343, 'Left': 0.22903700172901154, 'Top': 0.13467800617218018}, 'ImageId': '41b281ea-3ee5-3924-a270-afd61ebbee1c', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '1d95c2f3-47c3-46b3-b427-1b5a7dcea8cd', 'BoundingBox': {'Width': 0.359605997800827, 'Height': 0.3690809905529022, 'Left': 0.30367401242256165, 'Top': 0.3598879873752594}, 'ImageId': 'abd7bc4a-032b-3a35-8110-d029fac80ce4', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '1dd728b0-ec0c-42df-84d7-ff616eedb422', 'BoundingBox': {'Width': 0.3246369957923889, 'Height': 0.3699069917201996, 'Left': 0.3381649851799011, 'Top': 0.42811599373817444}, 'ImageId': 'd630fa04-57f1-3a31-851e-46ebd6ef4f63', 'Confidence': 99.99909973144531, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '1de07d24-aafc-4563-aafc-663b13ff1f76', 'BoundingBox': {'Width': 0.47348400950431824, 'Height': 0.5760290026664734, 'Left': 0.23739799857139587, 'Top': 0.1994680017232895}, 'ImageId': 'a369abc0-3f14-30c8-890a-21a281958895', 'Confidence': 99.9979019165039, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '1e13d5ec-669a-47d8-8b43-f3a7384a3fa8', 'BoundingBox': {'Width': 0.3826259970664978, 'Height': 0.4093019962310791, 'Left': 0.3529070019721985, 'Top': 0.3142949938774109}, 'ImageId': '0baf7fca-6414-3103-930b-2e1c3032a64b', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '1fbdeb65-5493-4ca3-89e7-f289661e2d15', 'BoundingBox': {'Width': 0.14556199312210083, 'Height': 0.15931600332260132, 'Left': 0.4250909984111786, 'Top': 0.37759101390838623}, 'ImageId': '6f38fa65-9fd2-3490-bfb7-d8d971f37323', 'Confidence': 99.9939956665039, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '204bb902-9470-48cd-bd54-4d121d73bf9c', 'BoundingBox': {'Width': 0.6911309957504272, 'Height': 0.4443790018558502, 'Left': 0.13505400717258453, 'Top': 0.2787509858608246}, 'ImageId': 'd64a847f-d82a-333b-aa25-82cfa3594f36', 'Confidence': 99.99939727783203, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '20504411-1c87-4ad6-980a-2ca6bfb060e4', 'BoundingBox': {'Width': 0.46203500032424927, 'Height': 0.46724098920822144, 'Left': 0.2793610095977783, 'Top': 0.3665570020675659}, 'ImageId': '17570570-5269-370b-9e26-fe33f7326e9c', 'Confidence': 99.99759674072266, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '20b2a852-357f-4f54-9de4-0817642657cc', 'BoundingBox': {'Width': 0.40210700035095215, 'Height': 0.4306589961051941, 'Left': 0.36286500096321106, 'Top': 0.18158499896526337}, 'ImageId': 'cd3c0b5b-da91-3069-8cd0-6d81d22da289', 'Confidence': 99.99960327148438, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '21cca3b6-ffd4-4eed-82a7-414411611050', 'BoundingBox': {'Width': 0.561273992061615, 'Height': 0.3623029887676239, 'Left': 0.20969699323177338, 'Top': 0.2105029970407486}, 'ImageId': '6193397a-64bc-37be-9e08-0ec45694b49c', 'Confidence': 99.99960327148438, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '23831571-3cb9-41ed-9c3f-2293a72f4109', 'BoundingBox': {'Width': 0.29069700837135315, 'Height': 0.3095580041408539, 'Left': 0.41517800092697144, 'Top': 0.40055200457572937}, 'ImageId': '4ad34e1b-8cf4-3b6f-bb48-f69b21565564', 'Confidence': 99.99750518798828, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '24431703-e439-450a-98b7-caa68c92b8f0', 'BoundingBox': {'Width': 0.3642750084400177, 'Height': 0.38172098994255066, 'Left': 0.2842690050601959, 'Top': 0.2977530062198639}, 'ImageId': '3f2a3f76-aa06-3d29-b702-d132da49b063', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '2515dc82-04e3-4ace-a974-d6e2b36f47ba', 'BoundingBox': {'Width': 0.5719119906425476, 'Height': 0.3752579987049103, 'Left': 0.2893829941749573, 'Top': 0.2974329888820648}, 'ImageId': 'c186ee83-4a2c-3bc4-96db-3b0044831cb4', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '25674b0c-73e3-46b1-8ded-6aa8c3f3f92c', 'BoundingBox': {'Width': 0.6870350241661072, 'Height': 0.40039700269699097, 'Left': 0.16524800658226013, 'Top': 0.23632100224494934}, 'ImageId': '8750c99d-6fe5-3525-abb0-80dad16235bd', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '25a75e2e-24e6-4695-a691-b206dd027677', 'BoundingBox': {'Width': 0.44411900639533997, 'Height': 0.49271100759506226, 'Left': 0.2839910089969635, 'Top': 0.352975994348526}, 'ImageId': '5f60a368-a6e0-3f1e-92bb-82384bff2fcd', 'Confidence': 99.99810028076172, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '26968d48-9f4f-421c-8cac-c25109a8a214', 'BoundingBox': {'Width': 0.3569200038909912, 'Height': 0.3741759955883026, 'Left': 0.385470986366272, 'Top': 0.22086699306964874}, 'ImageId': '29bf881c-1f12-3b38-bbb3-05f23cc7e101', 'Confidence': 100.0, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '27ac989c-cf15-49e9-90e0-cbc5133cebbe', 'BoundingBox': {'Width': 0.28163498640060425, 'Height': 0.23686900734901428, 'Left': 0.2744230031967163, 'Top': 0.2041260004043579}, 'ImageId': 'f57c7bf3-b9a6-3bea-9fc8-3bae43d29b11', 'Confidence': 99.99610137939453, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '27d3ca91-d1c1-4ec5-b13c-39493170b8c7', 'BoundingBox': {'Width': 0.3165520131587982, 'Height': 0.34321799874305725, 'Left': 0.35458898544311523, 'Top': 0.1456020027399063}, 'ImageId': 'b71f9115-c86d-314b-9032-90c67d02006d', 'Confidence': 99.99870300292969, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '27ddaf41-0005-4cdf-b70a-27065db670d1', 'BoundingBox': {'Width': 0.37325799465179443, 'Height': 0.4065670073032379, 'Left': 0.32058998942375183, 'Top': 0.1779090017080307}, 'ImageId': 'cd80820a-95a0-3f72-892a-037f255c71a2', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '28b4755f-8ee3-430e-baab-64206e2ae381', 'BoundingBox': {'Width': 0.4569160044193268, 'Height': 0.46212801337242126, 'Left': 0.19693699479103088, 'Top': 0.20332899689674377}, 'ImageId': 'bef0a5e1-c95a-35bd-bdb3-c0716302f88d', 'Confidence': 99.99949645996094, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '2a9cc674-ca89-4b35-9429-8a89c0cf404d', 'BoundingBox': {'Width': 0.4124070107936859, 'Height': 0.44354599714279175, 'Left': 0.3275560140609741, 'Top': 0.36647701263427734}, 'ImageId': 'a5daaaee-b8f3-3458-ab3a-754b95b015ee', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '2bc31f7f-827a-4a4f-b12f-a5a536638ec7', 'BoundingBox': {'Width': 0.3111740052700043, 'Height': 0.293971985578537, 'Left': 0.17973700165748596, 'Top': 0.33424898982048035}, 'ImageId': '77e1e26b-4ada-398f-a344-cf0ae06299f6', 'Confidence': 99.99919891357422, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '2c1d0e0e-fb75-4bd5-b755-19b17e82b601', 'BoundingBox': {'Width': 0.3082030117511749, 'Height': 0.3409300148487091, 'Left': 0.4168210029602051, 'Top': 0.31492000818252563}, 'ImageId': '5d81ba19-2be7-3fe8-b2c5-73ad1b4531dc', 'Confidence': 99.99930572509766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '2d67ebc5-b2b5-4e41-8218-676b15d3343f', 'BoundingBox': {'Width': 0.3473460078239441, 'Height': 0.20282499492168427, 'Left': 0.2860789895057678, 'Top': 0.282586008310318}, 'ImageId': 'a6bb750e-a260-3485-bc6b-9f6d24fc12ff', 'Confidence': 99.99750518798828, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '2d7a55ff-9704-40ac-bb17-aa5f2f36b528', 'BoundingBox': {'Width': 0.47482600808143616, 'Height': 0.5158690214157104, 'Left': 0.2653709948062897, 'Top': 0.07332389801740646}, 'ImageId': '0116141a-8dbd-34ae-9884-647036658177', 'Confidence': 99.99840545654297, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '2e54665f-9b42-4e90-aeef-6c1762a8d21f', 'BoundingBox': {'Width': 0.6999310255050659, 'Height': 0.47102200984954834, 'Left': 0.19176800549030304, 'Top': 0.14070700109004974}, 'ImageId': 'a940cf42-2a07-3ff1-b63d-d817cdf4cb3a', 'Confidence': 99.99939727783203, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '2e96e8d4-991b-47e1-b4fc-3215099c2651', 'BoundingBox': {'Width': 0.5424829721450806, 'Height': 0.3393140137195587, 'Left': 0.2903499901294708, 'Top': 0.1838349997997284}, 'ImageId': 'f77fe747-caf3-3965-a55a-9d6bff153478', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '2ff1ce76-d6e1-4935-b066-588c53bc68a6', 'BoundingBox': {'Width': 0.43039101362228394, 'Height': 0.45831000804901123, 'Left': 0.27120301127433777, 'Top': 0.2763890027999878}, 'ImageId': '9a180f7d-c549-3026-a50d-a0471867d8ca', 'Confidence': 99.99939727783203, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '316c2173-b2f4-4b6c-bc7b-f8053e881851', 'BoundingBox': {'Width': 0.6285049915313721, 'Height': 0.5171160101890564, 'Left': 0.16847099363803864, 'Top': 0.39326798915863037}, 'ImageId': '74a364a6-e97b-3e9c-b4d3-742b10dd4b38', 'Confidence': 99.99829864501953, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '325fe5d8-f61b-4346-9008-74ced47fd1b3', 'BoundingBox': {'Width': 0.3794569969177246, 'Height': 0.3601920008659363, 'Left': 0.2777239978313446, 'Top': 0.23135100305080414}, 'ImageId': '039561ac-7139-3c49-a3df-b79319ad4fef', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '369585ca-da27-4403-aeb1-423fc5122855', 'BoundingBox': {'Width': 0.43413999676704407, 'Height': 0.47268399596214294, 'Left': 0.26623299717903137, 'Top': 0.22065100073814392}, 'ImageId': '754d613f-ec5a-3c3a-a5f6-ab80967973f7', 'Confidence': 99.99919891357422, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '36d5bb96-2fa1-4960-9c4c-6c4af3dc54b9', 'BoundingBox': {'Width': 0.628600001335144, 'Height': 0.39976099133491516, 'Left': 0.1514350026845932, 'Top': 0.19364500045776367}, 'ImageId': '1d76eded-2e8a-3dfa-bdb0-ae33ded5c55a', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '36f9247d-f7ee-4b0c-99ce-119913724fbf', 'BoundingBox': {'Width': 0.4808639883995056, 'Height': 0.29739299416542053, 'Left': 0.26627999544143677, 'Top': 0.27804499864578247}, 'ImageId': '33f502c3-1e7f-3b7a-8cb0-689e66e4df69', 'Confidence': 99.99930572509766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '3aa45472-096b-49ed-aedc-746a75b2c83a', 'BoundingBox': {'Width': 0.586122989654541, 'Height': 0.6781489849090576, 'Left': 0.1523829996585846, 'Top': 0.17230099439620972}, 'ImageId': 'd0628c52-9b79-36c5-a78a-423adf798643', 'Confidence': 99.99970245361328, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '3c0232a4-b9c8-4875-b0a1-be5ddbe85e0e', 'BoundingBox': {'Width': 0.5028870105743408, 'Height': 0.3281579911708832, 'Left': 0.27524399757385254, 'Top': 0.21389299631118774}, 'ImageId': 'cd272341-34d1-3b1b-b964-6bfa442aba33', 'Confidence': 99.99960327148438, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '3c1a2630-34c7-4d67-8289-d2242e6ba274', 'BoundingBox': {'Width': 0.30333900451660156, 'Height': 0.31873199343681335, 'Left': 0.35916998982429504, 'Top': 0.26047399640083313}, 'ImageId': '9ffc2811-bed3-33cc-9110-388600184488', 'Confidence': 99.99919891357422, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '415ef802-6f68-4653-aa08-00131bd4e429', 'BoundingBox': {'Width': 0.43982699513435364, 'Height': 0.5043089985847473, 'Left': 0.3099069893360138, 'Top': 0.12898799777030945}, 'ImageId': 'cf1a994a-1004-3d4e-94ef-7fea3d7f0c9b', 'Confidence': 99.9990005493164, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '429032f1-3909-4ff7-b72a-9421152310eb', 'BoundingBox': {'Width': 0.44839200377464294, 'Height': 0.46281400322914124, 'Left': 0.22697100043296814, 'Top': 0.21084900200366974}, 'ImageId': '14d26600-c968-3c3d-903a-334f024c8d14', 'Confidence': 99.99960327148438, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '43b748d4-6728-4c0f-9a12-10dffcde989c', 'BoundingBox': {'Width': 0.15393100678920746, 'Height': 0.16853900253772736, 'Left': 0.5259649753570557, 'Top': 0.394461989402771}, 'ImageId': '8bed91b2-72fe-3116-bb15-3a360642ba4a', 'Confidence': 99.997802734375, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '465d07ad-8ffa-48b8-bb85-ce551422b4f5', 'BoundingBox': {'Width': 0.4235970079898834, 'Height': 0.4617460072040558, 'Left': 0.3318290114402771, 'Top': 0.2840699851512909}, 'ImageId': 'ffb6bf21-a715-306a-b505-377257a5064a', 'Confidence': 99.99939727783203, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '47961a3b-5c8e-4c92-a71d-6faec43601f3', 'BoundingBox': {'Width': 0.34311598539352417, 'Height': 0.3774000108242035, 'Left': 0.3432529866695404, 'Top': 0.14889000356197357}, 'ImageId': '8fa3e23e-c8cb-37ca-8a7b-21166cc92bdd', 'Confidence': 99.99960327148438, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '4be176de-60d8-44ec-868d-5b5a6fe05571', 'BoundingBox': {'Width': 0.4633690118789673, 'Height': 0.47288501262664795, 'Left': 0.2938930094242096, 'Top': 0.2679780125617981}, 'ImageId': '72caccd7-cb12-3316-9854-f8c64e39eeb8', 'Confidence': 99.9990005493164, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '4f9ccbd8-21bd-4edb-b665-dbcbf69436e0', 'BoundingBox': {'Width': 0.5171189904212952, 'Height': 0.2918170094490051, 'Left': 0.31513500213623047, 'Top': 0.3202759921550751}, 'ImageId': '11e1afc0-8253-39ff-bcdd-c8e224d7a4a0', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '505b2b90-f0a3-439e-bb2e-9091d373fd37', 'BoundingBox': {'Width': 0.38697099685668945, 'Height': 0.4318299889564514, 'Left': 0.3445410132408142, 'Top': 0.16933700442314148}, 'ImageId': '1cc52310-f527-3688-843d-07601db4de16', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '50c1f4a9-8c68-4a9b-bdf3-d81e0a90632b', 'BoundingBox': {'Width': 0.22551600635051727, 'Height': 0.24250799417495728, 'Left': 0.32847800850868225, 'Top': 0.28485000133514404}, 'ImageId': '3a549bac-ebc2-3f1a-9d7b-68589a2c338c', 'Confidence': 99.997802734375, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '50eae9f6-3159-4594-a019-54449accbec9', 'BoundingBox': {'Width': 0.2645129859447479, 'Height': 0.27772998809814453, 'Left': 0.29350700974464417, 'Top': 0.2917410135269165}, 'ImageId': '50a52ea0-969e-33a0-8df2-d240f1890276', 'Confidence': 99.99949645996094, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '522a5245-357a-4c09-84a2-eb49e8e4f4f6', 'BoundingBox': {'Width': 0.2834340035915375, 'Height': 0.30347299575805664, 'Left': 0.3923240005970001, 'Top': 0.2244569957256317}, 'ImageId': '72689b07-8452-3c07-bdd3-19cd865c2145', 'Confidence': 99.99970245361328, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '52be6141-3a96-4f83-a147-46b8fa027e23', 'BoundingBox': {'Width': 0.4509499967098236, 'Height': 0.5258690118789673, 'Left': 0.22339500486850739, 'Top': 0.24021799862384796}, 'ImageId': '624eaf15-7596-3cab-975e-f940d9ed4dfc', 'Confidence': 99.99939727783203, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '53f38ca8-26ec-4531-9e47-25ecc2efe775', 'BoundingBox': {'Width': 0.21236200630664825, 'Height': 0.2068769931793213, 'Left': 0.29425498843193054, 'Top': 0.23624099791049957}, 'ImageId': 'df21cfa1-80a6-39ea-be9d-2a2d4189f0f0', 'Confidence': 99.99819946289062, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '54a3d916-2081-46b8-825f-488aeb1f1e27', 'BoundingBox': {'Width': 0.4388140141963959, 'Height': 0.4298030138015747, 'Left': 0.406917005777359, 'Top': 0.009707850404083729}, 'ImageId': '39bfb37c-6f8b-30ee-a729-9105fe80ff13', 'Confidence': 99.99960327148438, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '556939cc-ae86-426b-bda2-5a8ccdb2602e', 'BoundingBox': {'Width': 0.18896999955177307, 'Height': 0.1882220059633255, 'Left': 0.4429610073566437, 'Top': 0.38079598546028137}, 'ImageId': '2628a577-15dd-3eba-be2d-7e1f47235389', 'Confidence': 99.99729919433594, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '55fc0f1d-3fb6-4bd3-b340-ce076257cfca', 'BoundingBox': {'Width': 0.3406060039997101, 'Height': 0.3381910026073456, 'Left': 0.33010199666023254, 'Top': 0.2186489999294281}, 'ImageId': '6e9f4696-59fc-3eae-b1fc-93870376265e', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '5627503b-91d4-4ba5-9c72-aa9f31239fff', 'BoundingBox': {'Width': 0.25493699312210083, 'Height': 0.2598060071468353, 'Left': 0.16107100248336792, 'Top': 0.16944199800491333}, 'ImageId': '087ab1e5-9681-300e-9107-f1998bd31287', 'Confidence': 99.99859619140625, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '569887b6-75de-4daa-870f-85738f35b628', 'BoundingBox': {'Width': 0.7160050272941589, 'Height': 0.4622339904308319, 'Left': 0.16157400608062744, 'Top': 0.16990399360656738}, 'ImageId': '2cd6ea02-3446-33e3-9da3-94de4ec8b4dc', 'Confidence': 99.99970245361328, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '5859e313-df1d-4f26-9daf-93d954e8aae1', 'BoundingBox': {'Width': 0.6763169765472412, 'Height': 0.41186100244522095, 'Left': 0.22533999383449554, 'Top': 0.147025004029274}, 'ImageId': 'a94223aa-2bef-3dae-8041-3f8fb0f1bad9', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '59d14699-2f18-4106-9422-b6b3f5933c89', 'BoundingBox': {'Width': 0.24324600398540497, 'Height': 0.27677100896835327, 'Left': 0.34967198967933655, 'Top': 0.3034000098705292}, 'ImageId': '3ac474be-88b6-3460-b3fd-e93f66f8243f', 'Confidence': 99.9939956665039, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '5a40a257-cd31-4fef-b057-319acf85e55b', 'BoundingBox': {'Width': 0.5971850156784058, 'Height': 0.3650200068950653, 'Left': 0.26109400391578674, 'Top': 0.20443400740623474}, 'ImageId': '7b345b25-01f6-34a4-8a4c-736ef580ebcf', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '5ae10f5e-a5f3-417d-a9bb-dffdac1e1f0b', 'BoundingBox': {'Width': 0.41288700699806213, 'Height': 0.449862003326416, 'Left': 0.2920359969139099, 'Top': 0.23028899729251862}, 'ImageId': '99ef20e8-6d21-3d24-9b8f-c4191a48e45b', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '5d06675a-08c7-4a1c-8b36-dfcb9f6e61c0', 'BoundingBox': {'Width': 0.4382930099964142, 'Height': 0.4558990001678467, 'Left': 0.2813270092010498, 'Top': 0.15093199908733368}, 'ImageId': 'acd98f78-a807-392a-b79e-7287b082e2ea', 'Confidence': 99.99919891357422, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '5d0a4b7f-63e1-4607-a6dd-0da5bfcfe7fc', 'BoundingBox': {'Width': 0.6686149835586548, 'Height': 0.4729369878768921, 'Left': 0.14576900005340576, 'Top': 0.20694999396800995}, 'ImageId': 'dd16e72d-7770-351c-95a6-d76432bab6fd', 'Confidence': 99.99939727783203, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '5fac83e7-e861-4fb9-b13e-be36a253ab8a', 'BoundingBox': {'Width': 0.5101619958877563, 'Height': 0.37973999977111816, 'Left': 0.43459001183509827, 'Top': 0.04688769951462746}, 'ImageId': '0afce4bb-a991-3318-9bf4-5b5ff333b3c0', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '600f3222-0a9d-4bb2-8f38-6f8996833d20', 'BoundingBox': {'Width': 0.43121999502182007, 'Height': 0.4693729877471924, 'Left': 0.3081980049610138, 'Top': 0.07966429740190506}, 'ImageId': '4f97a8e2-d224-3237-8735-ee0e683dd294', 'Confidence': 99.99919891357422, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '610584a7-7787-4db1-b2a4-ee0dd2ed27b4', 'BoundingBox': {'Width': 0.41273999214172363, 'Height': 0.31684601306915283, 'Left': 0.3031289875507355, 'Top': 0.35329899191856384}, 'ImageId': 'b3339e0c-4869-3fe1-b1dc-e9db14419e60', 'Confidence': 99.99930572509766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '61d499b7-6b2c-47e0-94de-39c10f9d2bb2', 'BoundingBox': {'Width': 0.39149099588394165, 'Height': 0.3181760013103485, 'Left': 0.27594199776649475, 'Top': 0.3643740117549896}, 'ImageId': '73526417-42aa-3899-afb5-a42ef362ac92', 'Confidence': 99.99949645996094, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '627d8bd3-358f-4263-b051-ac81a2a084e6', 'BoundingBox': {'Width': 0.3184939920902252, 'Height': 0.3387260138988495, 'Left': 0.3417559862136841, 'Top': 0.28455498814582825}, 'ImageId': '700e3a90-c9f8-30fc-8859-f908039901fc', 'Confidence': 99.99939727783203, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '62d6b049-49bd-4609-97af-2d6195102546', 'BoundingBox': {'Width': 0.4103020131587982, 'Height': 0.44905900955200195, 'Left': 0.3256179988384247, 'Top': 0.31039801239967346}, 'ImageId': '3e6b2490-e23b-305d-a9ca-da07177b1df0', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '643e6035-6f40-4552-930e-3cf836c2b149', 'BoundingBox': {'Width': 0.3814690113067627, 'Height': 0.39374399185180664, 'Left': 0.36053499579429626, 'Top': 0.10683000087738037}, 'ImageId': 'ab58ee96-b27c-387c-9e4d-113038c8f4a5', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '64a96bb1-30cb-4b6c-9305-2effdeae8aa2', 'BoundingBox': {'Width': 0.3050119876861572, 'Height': 0.31391000747680664, 'Left': 0.3239400088787079, 'Top': 0.2706789970397949}, 'ImageId': 'a97bb9c4-c84b-3780-8640-fb7784a1dbe0', 'Confidence': 99.99970245361328, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '64baf020-01a5-4d76-8635-d8ebfe7176fb', 'BoundingBox': {'Width': 0.35511699318885803, 'Height': 0.36249300837516785, 'Left': 0.27694201469421387, 'Top': 0.4635910093784332}, 'ImageId': 'e6f493e0-ad3a-3636-97f6-d6606fe8ab47', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '64d45d0e-67d4-40c9-8502-f80133e150f3', 'BoundingBox': {'Width': 0.7190589904785156, 'Height': 0.5031369924545288, 'Left': 0.13290299475193024, 'Top': 0.1756650060415268}, 'ImageId': '09762d41-4ee5-315a-b077-d3366437cdc9', 'Confidence': 99.99819946289062, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '65274076-52db-41b7-89c8-5e00cdb39f86', 'BoundingBox': {'Width': 0.4216980040073395, 'Height': 0.3329229950904846, 'Left': 0.2899099886417389, 'Top': 0.3201409876346588}, 'ImageId': '3489323e-43f6-3834-98a3-c14472b30b88', 'Confidence': 99.99759674072266, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '652cf314-f83d-4019-b801-e68bcb042e60', 'BoundingBox': {'Width': 0.43733900785446167, 'Height': 0.4926629960536957, 'Left': 0.2538680136203766, 'Top': 0.1459210067987442}, 'ImageId': '10031d50-00a7-3094-bf06-c5a218eac6f9', 'Confidence': 99.99739837646484, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '6958157c-b599-40fc-88b4-30c3ce258d0b', 'BoundingBox': {'Width': 0.413675993680954, 'Height': 0.42098501324653625, 'Left': 0.2623269855976105, 'Top': 0.1756179928779602}, 'ImageId': 'f896f52f-c266-3183-b98d-3163b869d7cd', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '6b09c4d7-ceec-4254-9485-e9bfe70dee2e', 'BoundingBox': {'Width': 0.49995800852775574, 'Height': 0.5548319816589355, 'Left': 0.23621700704097748, 'Top': 0.14389100670814514}, 'ImageId': '13978da3-b4e4-3cde-bf08-409a8de38a67', 'Confidence': 99.99939727783203, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '6b51612e-0dca-4525-b547-6be56b3484e1', 'BoundingBox': {'Width': 0.3992690145969391, 'Height': 0.3851909935474396, 'Left': 0.22482800483703613, 'Top': 0.19480499625205994}, 'ImageId': '50fc3816-45e2-3886-920e-0d9ca1bb1a60', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '6e727db4-e433-4497-89f8-d2c9190ff356', 'BoundingBox': {'Width': 0.3269979953765869, 'Height': 0.3466860055923462, 'Left': 0.30750399827957153, 'Top': 0.3690750002861023}, 'ImageId': '72c79269-6a08-3e7d-9558-9d173828bbf5', 'Confidence': 99.99690246582031, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '6f9d8be0-6044-47e5-a5fc-373e26dc2572', 'BoundingBox': {'Width': 0.299562007188797, 'Height': 0.28262901306152344, 'Left': 0.2666339874267578, 'Top': 0.32069098949432373}, 'ImageId': '666945fc-9b9d-3019-b1ae-8b549bcb2046', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '6fb59a24-6b0f-4d16-a7d8-90d51c0abfce', 'BoundingBox': {'Width': 0.4019300043582916, 'Height': 0.40628600120544434, 'Left': 0.2720620036125183, 'Top': 0.1824900060892105}, 'ImageId': '6997ab74-da29-341a-83c3-5df861089fe4', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '6fbbdbd7-ce77-4485-a0c0-c2e998a63a14', 'BoundingBox': {'Width': 0.42671599984169006, 'Height': 0.44165000319480896, 'Left': 0.26562100648880005, 'Top': 0.17466700077056885}, 'ImageId': 'bb43b805-743e-39cd-875d-14ad3ec5eae5', 'Confidence': 99.99939727783203, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '7258faad-c62a-482b-a81c-25e564949da3', 'BoundingBox': {'Width': 0.19655999541282654, 'Height': 0.18629400432109833, 'Left': 0.3254829943180084, 'Top': 0.2780190110206604}, 'ImageId': '8d1a37b9-8122-3575-b2cf-8f6740911bef', 'Confidence': 99.99739837646484, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '728b5760-05c7-4db6-8e02-e39633573b95', 'BoundingBox': {'Width': 0.42358800768852234, 'Height': 0.4139600098133087, 'Left': 0.3159930109977722, 'Top': 0.015979399904608727}, 'ImageId': '36ef467f-0d2c-3c21-98f0-fd380299e0de', 'Confidence': 99.99939727783203, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '73447a61-71b8-4360-8bd2-87fb68c2be1e', 'BoundingBox': {'Width': 0.1484680026769638, 'Height': 0.15786799788475037, 'Left': 0.4757690131664276, 'Top': 0.2370380014181137}, 'ImageId': 'ca9bed38-1aa0-3237-a1e0-6c3015adcab0', 'Confidence': 99.98170471191406, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '749a887a-9688-4964-9aec-3d0284ccd5eb', 'BoundingBox': {'Width': 0.6140419840812683, 'Height': 0.40748000144958496, 'Left': 0.15663599967956543, 'Top': 0.13529400527477264}, 'ImageId': 'b4bbc14f-4228-38b1-9d95-d4b2256d2117', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '77e60a4a-c347-42f4-8537-8114f061c243', 'BoundingBox': {'Width': 0.33591800928115845, 'Height': 0.3358820080757141, 'Left': 0.30524900555610657, 'Top': 0.2882849872112274}, 'ImageId': '0e692a42-fb6a-36f7-ab11-507c792b2be9', 'Confidence': 99.99919891357422, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '7809aa60-7fe3-4a5e-aaf7-1ab5fdcf1bb3', 'BoundingBox': {'Width': 0.7341949939727783, 'Height': 0.4920639991760254, 'Left': 0.17751500010490417, 'Top': 0.22420300543308258}, 'ImageId': 'eac05fd3-ae04-3429-a981-95a42d62187e', 'Confidence': 99.99849700927734, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '792defc3-e22c-463e-8b91-aa470d3b27cf', 'BoundingBox': {'Width': 0.21820299327373505, 'Height': 0.20910200476646423, 'Left': 0.29907700419425964, 'Top': 0.3194589912891388}, 'ImageId': '961a7a51-4cf7-33ae-a1ed-ba49e2142f63', 'Confidence': 99.99769592285156, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '79c6dba5-04e7-4331-9032-1342a36ba206', 'BoundingBox': {'Width': 0.3509350121021271, 'Height': 0.35881999135017395, 'Left': 0.3039500117301941, 'Top': 0.3603839874267578}, 'ImageId': '092ce36c-d707-3c16-80e0-3ebefdb475d3', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '7ab38530-2fbf-488a-a79c-e8facd0ec380', 'BoundingBox': {'Width': 0.28995001316070557, 'Height': 0.30399999022483826, 'Left': 0.3104960024356842, 'Top': 0.17738600075244904}, 'ImageId': '70db2635-4060-3fe2-b08f-dfe260be332c', 'Confidence': 99.99960327148438, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '7ab41ff5-9699-4c45-95bc-3924d607e52d', 'BoundingBox': {'Width': 0.317236989736557, 'Height': 0.29593899846076965, 'Left': 0.351175993680954, 'Top': 0.14211800694465637}, 'ImageId': '7ef5d8af-0a36-3640-b98f-f652f35a9a5e', 'Confidence': 99.99829864501953, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '7c7ca036-d12b-44f7-9a0c-c507b81c8fad', 'BoundingBox': {'Width': 0.2532140016555786, 'Height': 0.2616559863090515, 'Left': 0.38619300723075867, 'Top': 0.3780049979686737}, 'ImageId': '89b9e296-8821-3762-8dea-fadc3ec46227', 'Confidence': 99.99579620361328, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '7c816d51-14b5-4021-8c3c-01a8d1a31b56', 'BoundingBox': {'Width': 0.3182690143585205, 'Height': 0.34008198976516724, 'Left': 0.2330700010061264, 'Top': 0.25705501437187195}, 'ImageId': 'd11ccf14-7718-3f51-bb60-e54d8a32bd81', 'Confidence': 99.99930572509766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '7dc6da59-de00-4355-9f28-7afb32fc2f84', 'BoundingBox': {'Width': 0.3312720060348511, 'Height': 0.3677160143852234, 'Left': 0.29909801483154297, 'Top': 0.15175500512123108}, 'ImageId': '55544c1a-340b-3ed2-95e0-8600ff613c9b', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '7e153f7f-444f-49d3-9d3f-f2ce58ab2b1d', 'BoundingBox': {'Width': 0.23193900287151337, 'Height': 0.25363001227378845, 'Left': 0.3838079869747162, 'Top': 0.3669300079345703}, 'ImageId': '4c822572-6ef2-32ff-9530-0ac023fb4c5b', 'Confidence': 99.98619842529297, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '7efd7c39-7544-480d-bb13-cb113cf9f746', 'BoundingBox': {'Width': 0.3968749940395355, 'Height': 0.4157699942588806, 'Left': 0.3071820139884949, 'Top': 0.23930500447750092}, 'ImageId': '67d14202-25bc-3640-8a89-4b0249b07b91', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '811e1e6b-1174-4705-aa27-27e85c46f0b1', 'BoundingBox': {'Width': 0.5391250252723694, 'Height': 0.3397490084171295, 'Left': 0.2920309901237488, 'Top': 0.1798650026321411}, 'ImageId': 'b260c721-076d-3df4-b71e-28ac745fb839', 'Confidence': 99.99970245361328, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '81ac202e-5a5a-4611-addd-1b80f3f127d1', 'BoundingBox': {'Width': 0.45469000935554504, 'Height': 0.5150359869003296, 'Left': 0.23179900646209717, 'Top': 0.09276869893074036}, 'ImageId': '987a5348-6bed-3b56-960b-c6c21526594b', 'Confidence': 99.99919891357422, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '835325a0-5b46-4de3-9371-b9adfd672c82', 'BoundingBox': {'Width': 0.4327380061149597, 'Height': 0.46783900260925293, 'Left': 0.2368669956922531, 'Top': 0.36160799860954285}, 'ImageId': '7fc67378-2119-3063-9881-b0750d30661e', 'Confidence': 99.99840545654297, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '87243b26-36e0-4276-98ec-7886540f1df0', 'BoundingBox': {'Width': 0.4756610095500946, 'Height': 0.45943400263786316, 'Left': 0.23473699390888214, 'Top': 0.1555909961462021}, 'ImageId': '5853ce11-5754-3993-8abb-88f7da0125f8', 'Confidence': 99.99819946289062, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '89882802-8c78-4d84-bbf7-fb4feaee6038', 'BoundingBox': {'Width': 0.37808799743652344, 'Height': 0.3964169919490814, 'Left': 0.3716840147972107, 'Top': 0.2348089963197708}, 'ImageId': '2488e4f3-140b-3c0f-8aa3-0ea4904eed8b', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '8a547f14-11fc-493c-a853-208e4a4ea000', 'BoundingBox': {'Width': 0.5931640267372131, 'Height': 0.22856199741363525, 'Left': 0.07734110206365585, 'Top': 0.2882609963417053}, 'ImageId': '6d90dcc4-1c7c-3ef3-b1e2-1f070cc3f428', 'Confidence': 99.99960327148438, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '8afc33bc-3f33-4991-b5cb-e486d0c127b1', 'BoundingBox': {'Width': 0.4887920022010803, 'Height': 0.5452290177345276, 'Left': 0.3603709936141968, 'Top': 0.03945140168070793}, 'ImageId': '26a5643a-0e48-31d5-a40f-33f8bace06b9', 'Confidence': 99.99810028076172, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '8ba4a25c-d211-4700-8876-a12a680ad97e', 'BoundingBox': {'Width': 0.1634639948606491, 'Height': 0.17446400225162506, 'Left': 0.4163140058517456, 'Top': 0.31098100543022156}, 'ImageId': 'f8e8e70e-c13c-35bf-b0ef-85d0c7a2e14c', 'Confidence': 99.99150085449219, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '8baa0501-0a6e-4ec9-a443-b84dcea9a1df', 'BoundingBox': {'Width': 0.3552109897136688, 'Height': 0.37796398997306824, 'Left': 0.3246749937534332, 'Top': 0.20987799763679504}, 'ImageId': '450dc747-a5ed-34a3-805e-05fef63f20b3', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '8cc0a5e8-d1cc-466a-97e6-4a276893c816', 'BoundingBox': {'Width': 0.28174200654029846, 'Height': 0.2954750061035156, 'Left': 0.42449501156806946, 'Top': 0.10345199704170227}, 'ImageId': 'edfed19f-9571-3b58-a8a2-f9eb4d7beb66', 'Confidence': 99.99870300292969, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '8d5ee969-a573-4744-b0d7-ebe003abab9b', 'BoundingBox': {'Width': 0.6318529844284058, 'Height': 0.3719410002231598, 'Left': 0.07079549878835678, 'Top': 0.3213909864425659}, 'ImageId': '175cfaa5-8346-3a27-a315-e1f3ec559834', 'Confidence': 99.99970245361328, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '8d91a387-1542-4880-828f-7dd47b5f8bc1', 'BoundingBox': {'Width': 0.3502979874610901, 'Height': 0.367574006319046, 'Left': 0.2500540018081665, 'Top': 0.39724600315093994}, 'ImageId': 'd2a45ca2-3f7d-3453-adc8-e6ecc5684061', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '8efa9ed6-e70b-48e2-8868-6154d4865869', 'BoundingBox': {'Width': 0.33286601305007935, 'Height': 0.36266300082206726, 'Left': 0.3413020074367523, 'Top': 0.3537310063838959}, 'ImageId': 'b73b10b4-f379-3c18-9aa3-e780969d97a0', 'Confidence': 99.99970245361328, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '8f7a8b18-599a-4cc7-9f1c-7cc173a236a6', 'BoundingBox': {'Width': 0.3250510096549988, 'Height': 0.36096400022506714, 'Left': 0.3181459903717041, 'Top': 0.34953200817108154}, 'ImageId': '303e7509-bd22-31b2-89c4-7907485e8433', 'Confidence': 99.99970245361328, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '90c85dcd-53c3-4ae5-bcff-8783f411422b', 'BoundingBox': {'Width': 0.3703790009021759, 'Height': 0.48664000630378723, 'Left': 0.2560020089149475, 'Top': 0.11653999984264374}, 'ImageId': '929ae21b-36d7-31be-aeb9-157479b2bc7a', 'Confidence': 99.99960327148438, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '934c2f87-2987-4e08-b0d6-68448d178219', 'BoundingBox': {'Width': 0.7458630204200745, 'Height': 0.4792959988117218, 'Left': 0.18984700739383698, 'Top': 0.14304299652576447}, 'ImageId': '409c151f-9ef4-3e79-95f0-b2da1403aec4', 'Confidence': 99.9988021850586, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '94169e03-417b-43c6-8584-fdc24a740ca7', 'BoundingBox': {'Width': 0.39206698536872864, 'Height': 0.4174079895019531, 'Left': 0.2527100145816803, 'Top': 0.3118149936199188}, 'ImageId': '49ca44d0-bf5d-35fa-a7b5-425ce27a612e', 'Confidence': 99.99939727783203, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '9439437c-07d7-4bcf-b143-59294453c966', 'BoundingBox': {'Width': 0.6862859725952148, 'Height': 0.5362759828567505, 'Left': 0.24955900013446808, 'Top': 0.2158759981393814}, 'ImageId': 'e35a88d5-b0b4-3505-a0c7-82df60b13145', 'Confidence': 99.99970245361328, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '946a84fb-c4f8-481a-b3f8-adb85f9cdfab', 'BoundingBox': {'Width': 0.36618998646736145, 'Height': 0.3657990097999573, 'Left': 0.3166249990463257, 'Top': 0.2492000013589859}, 'ImageId': 'cb367657-ca8a-3000-bdfa-b9442202116e', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '95209441-4f1f-4f1a-8a45-1e4d567a7495', 'BoundingBox': {'Width': 0.656141996383667, 'Height': 0.42153099179267883, 'Left': 0.14926399290561676, 'Top': 0.14364799857139587}, 'ImageId': '1d509a81-1d1f-32b4-85cf-635d03737e63', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '971d0d80-7763-44cb-80ee-6772970875e1', 'BoundingBox': {'Width': 0.3566559851169586, 'Height': 0.3967919945716858, 'Left': 0.31222599744796753, 'Top': 0.348363995552063}, 'ImageId': 'cf0da3e7-a7b3-38f1-bad5-7a643eda5f2e', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '97e5236d-adb2-4272-a21c-e317697e736e', 'BoundingBox': {'Width': 0.3093770146369934, 'Height': 0.3302629888057709, 'Left': 0.33118999004364014, 'Top': 0.2647860050201416}, 'ImageId': '1ebc559c-9ef7-3981-9a19-e6d2e2ae8607', 'Confidence': 99.99970245361328, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '98cb9dff-2441-4f52-8cf6-bd2db32e7c80', 'BoundingBox': {'Width': 0.3792180120944977, 'Height': 0.3835799992084503, 'Left': 0.3021810054779053, 'Top': 0.2778730094432831}, 'ImageId': 'da3b8f95-c31b-374c-94ce-c66289768056', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '9adfad36-694f-478f-8f6c-2120ad8aa9d0', 'BoundingBox': {'Width': 0.4302310049533844, 'Height': 0.48091399669647217, 'Left': 0.27117401361465454, 'Top': 0.08222290128469467}, 'ImageId': '835eed42-fd35-3e39-b966-0489403decb4', 'Confidence': 99.99849700927734, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '9c9f988c-df79-41b9-9848-c3063543f984', 'BoundingBox': {'Width': 0.34875500202178955, 'Height': 0.38214799761772156, 'Left': 0.41654300689697266, 'Top': 0.20474499464035034}, 'ImageId': 'b3d3b628-7118-3192-84f3-3b8aa07dd53b', 'Confidence': 99.99960327148438, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '9cb5f131-4e21-4b10-9946-6301c805fce3', 'BoundingBox': {'Width': 0.5293710231781006, 'Height': 0.3161410093307495, 'Left': 0.2884339988231659, 'Top': 0.2201240062713623}, 'ImageId': '66d86420-d083-34de-8cd3-d5b45a95854d', 'Confidence': 99.99970245361328, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '9cee0196-f8da-473d-84dc-51723fe96962', 'BoundingBox': {'Width': 0.4572159945964813, 'Height': 0.36843299865722656, 'Left': 0.23037299513816833, 'Top': 0.26329201459884644}, 'ImageId': 'c94b1b08-4af0-3c89-99fe-bcecac502f74', 'Confidence': 99.99960327148438, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '9f8fc4d7-12f6-412d-ab67-b891ef4b03a0', 'BoundingBox': {'Width': 0.17303499579429626, 'Height': 0.18395300209522247, 'Left': 0.361268013715744, 'Top': 0.3227919936180115}, 'ImageId': '56847af1-15e9-347b-a568-964e85f471a4', 'Confidence': 99.99690246582031, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'a02ffd91-8494-4088-8c4b-166fcdcdbe08', 'BoundingBox': {'Width': 0.30818599462509155, 'Height': 0.3193260133266449, 'Left': 0.3639650046825409, 'Top': 0.28107601404190063}, 'ImageId': '1c1928c3-e4de-3517-8c82-748e0af4c947', 'Confidence': 99.99930572509766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'a0f447ed-9871-4336-bc12-9cde4350c141', 'BoundingBox': {'Width': 0.5696380138397217, 'Height': 0.6508489847183228, 'Left': 0.329708993434906, 'Top': 0.09302210062742233}, 'ImageId': 'f8410893-e864-3367-9fd1-eb44a2006baf', 'Confidence': 99.99840545654297, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'a1514558-7d73-4b0d-9e8d-1994c6326025', 'BoundingBox': {'Width': 0.3481070101261139, 'Height': 0.3875289857387543, 'Left': 0.3125840127468109, 'Top': 0.3024519979953766}, 'ImageId': '7020b59a-040a-3315-b001-274b1131bf84', 'Confidence': 99.99970245361328, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'a27cb0da-11e7-4bcc-8da5-1e6be695f9cc', 'BoundingBox': {'Width': 0.6144099831581116, 'Height': 0.3806830048561096, 'Left': 0.07957000285387039, 'Top': 0.22729000449180603}, 'ImageId': 'a3c65a74-e444-3f1e-885a-0402b1da2a8b', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'a2cf1908-e4f4-42a7-9d3f-23b4558ff0de', 'BoundingBox': {'Width': 0.37371599674224854, 'Height': 0.4058299958705902, 'Left': 0.29367300868034363, 'Top': 0.108924999833107}, 'ImageId': '01e464f7-c4da-3e47-b638-8e2944fedea1', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'a2e781e2-2d21-4fa0-b463-fb99a286e524', 'BoundingBox': {'Width': 0.46801701188087463, 'Height': 0.3377000093460083, 'Left': 0.2817690074443817, 'Top': 0.18497000634670258}, 'ImageId': '25b1c2f4-28ad-3ee1-9079-2460a6419d3c', 'Confidence': 99.99840545654297, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'a32141fa-d89c-486c-9b85-426bde430cd0', 'BoundingBox': {'Width': 0.43647199869155884, 'Height': 0.47091299295425415, 'Left': 0.21714499592781067, 'Top': 0.17120200395584106}, 'ImageId': '45af72f5-0955-3301-b067-f2ae361f8352', 'Confidence': 99.9988021850586, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'a336e4b9-672e-41bb-8a5f-231984ee268a', 'BoundingBox': {'Width': 0.7672709822654724, 'Height': 0.5727710127830505, 'Left': 0.036958400160074234, 'Top': 0.004099269863218069}, 'ImageId': '4dd06b4c-783b-3e52-a8c3-b828539da161', 'Confidence': 99.99960327148438, 'IndexFacesModelVersion': '6.0'}
# ...
# {'FaceId': 'cd44d48a-e792-4076-a65d-fe2b4dc8f301', 'BoundingBox': {'Width': 0.528984010219574, 'Height': 0.37722599506378174, 'Left': 0.188633993268013, 'Top': 0.28839701414108276}, 'ImageId': 'fa8227c4-045e-3c85-820d-a385511785d8', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'cdb3cba6-5bd0-4f1f-93e9-99c4def4d277', 'BoundingBox': {'Width': 0.2380259931087494, 'Height': 0.23170499503612518, 'Left': 0.4420360028743744, 'Top': 0.25534000992774963}, 'ImageId': 'c8d86e9c-1ce7-3ac7-b401-4e31ab2335e1', 'Confidence': 99.9957046508789, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'ce4885b2-dac8-445c-ad17-bd986ea6f01a', 'BoundingBox': {'Width': 0.44810399413108826, 'Height': 0.5292069911956787, 'Left': 0.30087000131607056, 'Top': 0.24275200068950653}, 'ImageId': 'b3e91a5b-f9b5-301a-8131-8ef13a98937c', 'Confidence': 99.99810028076172, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'cf707d26-baf6-4ba8-b3c7-70e03b217d3b', 'BoundingBox': {'Width': 0.36981600522994995, 'Height': 0.37300899624824524, 'Left': 0.3506380021572113, 'Top': 0.4039880037307739}, 'ImageId': '8cd70cd8-8c85-3859-93ac-a824dfbeb82d', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'd183cf45-b048-42a8-8aea-ba8f9e1214e9', 'BoundingBox': {'Width': 0.3950679898262024, 'Height': 0.3192969858646393, 'Left': 0.23749299347400665, 'Top': 0.3647949993610382}, 'ImageId': 'dafc0453-6732-3b5f-847e-2870bfe316d9', 'Confidence': 99.99939727783203, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'd236ed59-7163-4a5e-9127-cdf5073e0608', 'BoundingBox': {'Width': 0.5686450004577637, 'Height': 0.6834669709205627, 'Left': 0.2255460023880005, 'Top': 0.1568019986152649}, 'ImageId': '1db7d913-053f-33fb-ad96-55a3dff94c0b', 'Confidence': 99.99829864501953, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'd3ea44f1-1f32-4417-98ad-dada80085ae5', 'BoundingBox': {'Width': 0.2446729987859726, 'Height': 0.2322620004415512, 'Left': 0.2834460139274597, 'Top': 0.1183210015296936}, 'ImageId': '8f112ac0-a818-37d7-aea3-968dae387e19', 'Confidence': 99.99759674072266, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'd4fa5cbc-29cc-468f-aa11-50f4451a9455', 'BoundingBox': {'Width': 0.3587169945240021, 'Height': 0.37415099143981934, 'Left': 0.21020300686359406, 'Top': 0.25419101119041443}, 'ImageId': '362b7028-78b3-3933-b9e2-b17173e27485', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'd584e6cf-f5b0-4ac3-9b85-582dcd6906fe', 'BoundingBox': {'Width': 0.3420009911060333, 'Height': 0.3704969882965088, 'Left': 0.367684006690979, 'Top': 0.3342759907245636}, 'ImageId': '2abcbd95-c6c5-38af-afe6-8740b313345d', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'd649d2b2-833d-4a25-95a7-57fc58c055bf', 'BoundingBox': {'Width': 0.3863939940929413, 'Height': 0.4070320129394531, 'Left': 0.33753201365470886, 'Top': 0.17695100605487823}, 'ImageId': 'c539b90b-ebc2-3ad3-b3af-6eceaf84b898', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'd665a598-3a48-4098-92a0-f210a0fc3ba1', 'BoundingBox': {'Width': 0.5630099773406982, 'Height': 0.44188299775123596, 'Left': 0.23299099504947662, 'Top': 0.18417300283908844}, 'ImageId': '0c4a05fa-adcb-3e5f-b3f3-17ae3bc8bf37', 'Confidence': 99.99970245361328, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'd708fc9d-55b7-4aa3-bfe8-b1c4de251ccb', 'BoundingBox': {'Width': 0.46724098920822144, 'Height': 0.5188459753990173, 'Left': 0.2471580058336258, 'Top': 0.2571049928665161}, 'ImageId': 'fc6cd9ee-fd49-3854-880d-630f2dea6dae', 'Confidence': 99.99859619140625, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'd72fd942-a310-465b-bbea-975f02daf039', 'BoundingBox': {'Width': 0.507082998752594, 'Height': 0.5442929863929749, 'Left': 0.20516300201416016, 'Top': 0.14192500710487366}, 'ImageId': '5b2a7804-d4df-312c-95da-830166b326fc', 'Confidence': 99.99889373779297, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'd7f1f95e-7031-4981-af21-ceac2ff4782f', 'BoundingBox': {'Width': 0.3657490015029907, 'Height': 0.37399399280548096, 'Left': 0.30722999572753906, 'Top': 0.20643499493598938}, 'ImageId': '2c620b5c-5fad-3a17-90b2-c9e9057f4c1c', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'd9904045-fcaa-4df8-a1e0-2ca6319b13fb', 'BoundingBox': {'Width': 0.42954400181770325, 'Height': 0.5771830081939697, 'Left': 0.25707298517227173, 'Top': 0.14941099286079407}, 'ImageId': '9958b7d7-1f3e-3b58-9d15-45f803a208e7', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'dc386d72-e531-4118-8acc-d646351a3dd5', 'BoundingBox': {'Width': 0.3635280132293701, 'Height': 0.39828500151634216, 'Left': 0.3259890079498291, 'Top': 0.14423899352550507}, 'ImageId': 'c8405ec6-0136-3ecc-812f-85a426c8c0a6', 'Confidence': 99.99970245361328, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'dcd2ca6a-5e78-45ca-a8a4-5406c1c439bd', 'BoundingBox': {'Width': 0.20300699770450592, 'Height': 0.20045700669288635, 'Left': 0.31426799297332764, 'Top': 0.3517009913921356}, 'ImageId': '007c35c3-c882-378e-887e-5346889fbb50', 'Confidence': 97.34310150146484, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'dd09fc1e-0a0e-46ce-aeb7-dcd00d9470dc', 'BoundingBox': {'Width': 0.4198490083217621, 'Height': 0.44224101305007935, 'Left': 0.30118098855018616, 'Top': 0.24473300576210022}, 'ImageId': 'ef5a52bb-616f-3c9d-b706-cbd2da15cab3', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'de424543-e28e-418e-91d5-0e6b5349f313', 'BoundingBox': {'Width': 0.32259199023246765, 'Height': 0.44689100980758667, 'Left': 0.3648430109024048, 'Top': 0.21579299867153168}, 'ImageId': 'd3253aae-a511-38bc-901c-3b05958cb326', 'Confidence': 99.99970245361328, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'deaa34e7-714f-4204-8510-d4ea48acd381', 'BoundingBox': {'Width': 0.31471601128578186, 'Height': 0.3383069932460785, 'Left': 0.3234950006008148, 'Top': 0.1862339973449707}, 'ImageId': '8d7fc9a1-5daf-3d9b-ada2-87b77808781f', 'Confidence': 99.99970245361328, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'deb544e6-b283-40a6-b0f0-45041549bba3', 'BoundingBox': {'Width': 0.3443470001220703, 'Height': 0.34852099418640137, 'Left': 0.3596020042896271, 'Top': 0.26326799392700195}, 'ImageId': '446744b6-e189-30d3-8ea7-4167687b89cb', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'debb09c3-539f-4f12-9a2b-0c9c6396631c', 'BoundingBox': {'Width': 0.3585430085659027, 'Height': 0.39290300011634827, 'Left': 0.2773990035057068, 'Top': 0.23474599421024323}, 'ImageId': 'ab94ff67-2c77-35be-a87c-f81534693669', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'ded05489-029e-4b6f-85bc-614a1426857b', 'BoundingBox': {'Width': 0.6661869883537292, 'Height': 0.7018060088157654, 'Left': 0.1277489960193634, 'Top': 0.13683800399303436}, 'ImageId': 'f08fa816-7d66-3ea6-a448-a91c08840250', 'Confidence': 99.99960327148438, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'e0a13e04-6766-44a8-8782-52973f67a70e', 'BoundingBox': {'Width': 0.5663449764251709, 'Height': 0.3354080021381378, 'Left': 0.16065800189971924, 'Top': 0.19394999742507935}, 'ImageId': 'cb0810f2-0c60-31c0-a3b9-f8e8a21e7d09', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'e11fa944-7248-4deb-b274-44c3d224d5c5', 'BoundingBox': {'Width': 0.6374120116233826, 'Height': 0.7297800183296204, 'Left': 0.2009509950876236, 'Top': 0.22967900335788727}, 'ImageId': 'e9a348e9-eba6-3690-8b98-d821db917c9e', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'e4857cde-1b64-4b5f-b48b-39eb25ae85a8', 'BoundingBox': {'Width': 0.19028499722480774, 'Height': 0.1456809937953949, 'Left': 0.36840999126434326, 'Top': 0.27818599343299866}, 'ImageId': '71bde01d-cd0c-3d61-bebb-4ace7cae20ca', 'Confidence': 99.24539947509766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'e48b4966-a308-423b-a3f5-a24b86b2179a', 'BoundingBox': {'Width': 0.5630679726600647, 'Height': 0.3968920111656189, 'Left': 0.1876019984483719, 'Top': 0.1930840015411377}, 'ImageId': 'fc2cb460-bf6a-39b4-bfff-386d188c45ad', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'e4b63ad2-940d-464c-8350-e50a1a4fa8e8', 'BoundingBox': {'Width': 0.17373399436473846, 'Height': 0.17821399867534637, 'Left': 0.40779200196266174, 'Top': 0.4433729946613312}, 'ImageId': '5f820c9c-16e1-3904-897e-51f96118275f', 'Confidence': 99.99380493164062, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'e50faee0-d3ae-44bb-bf1c-3846bd0f9e54', 'BoundingBox': {'Width': 0.45709100365638733, 'Height': 0.4610840082168579, 'Left': 0.23002299666404724, 'Top': 0.13873200118541718}, 'ImageId': 'c13950c5-32d3-38e9-84fc-9b9f770651fe', 'Confidence': 99.99970245361328, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'e692147a-0a7b-47c3-9e35-5dd640541d17', 'BoundingBox': {'Width': 0.47189900279045105, 'Height': 0.48638901114463806, 'Left': 0.30523499846458435, 'Top': 0.15170200169086456}, 'ImageId': 'f9a0163c-4893-3ed8-9aa1-de92d74beca7', 'Confidence': 99.99889373779297, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'e79b3da7-6057-4ec7-82a2-31effb778652', 'BoundingBox': {'Width': 0.4130769968032837, 'Height': 0.40716999769210815, 'Left': 0.2883630096912384, 'Top': 0.33796200156211853}, 'ImageId': '6e365164-4370-3a2a-90d1-684b9c68479e', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'e97541b5-7b93-4263-85b8-e198bdbd14c6', 'BoundingBox': {'Width': 0.36859598755836487, 'Height': 0.3894380033016205, 'Left': 0.2688769996166229, 'Top': 0.3109770119190216}, 'ImageId': '230dbffa-ebf9-31fb-a227-58382191589b', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'ee1235db-268f-4abe-b01e-67adaf392f09', 'BoundingBox': {'Width': 0.37899699807167053, 'Height': 0.4140259921550751, 'Left': 0.2476859986782074, 'Top': 0.3122220039367676}, 'ImageId': '942a7ce0-7e8c-368a-9623-9d2c1f831606', 'Confidence': 100.0, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'ef1b6e8f-c35b-487d-ac55-d0de5d9e1411', 'BoundingBox': {'Width': 0.31074899435043335, 'Height': 0.3320789933204651, 'Left': 0.2585830092430115, 'Top': 0.13117100298404694}, 'ImageId': 'ada52573-f223-3329-8fd7-430ad3655ce7', 'Confidence': 99.99930572509766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'efb68c96-33bf-451b-96a9-f9cc7146180b', 'BoundingBox': {'Width': 0.3139500021934509, 'Height': 0.31575700640678406, 'Left': 0.3618229925632477, 'Top': 0.4139769971370697}, 'ImageId': '766c0a06-d071-3857-9ecd-d372940840a9', 'Confidence': 99.99949645996094, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'f1e7ba17-7921-4bd0-ba31-82426bd93474', 'BoundingBox': {'Width': 0.6696289777755737, 'Height': 0.40789198875427246, 'Left': 0.17417900264263153, 'Top': 0.31805500388145447}, 'ImageId': '4d84e0c0-d308-39b0-ab80-274fae3ff7eb', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'f3b3eac2-26b3-41e9-9898-cc6df4001378', 'BoundingBox': {'Width': 0.30970698595046997, 'Height': 0.29962998628616333, 'Left': 0.21139200031757355, 'Top': 0.3222379982471466}, 'ImageId': 'ccc81648-a03b-359a-9d42-9d7b6f58b469', 'Confidence': 99.99939727783203, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'f4899b3e-49cf-499a-90ea-3a2dae9ffec8', 'BoundingBox': {'Width': 0.3053230047225952, 'Height': 0.24132099747657776, 'Left': 0.3505620062351227, 'Top': 0.3095589876174927}, 'ImageId': '43c602e2-ed5b-3a05-9e97-5c94119e3902', 'Confidence': 99.97489929199219, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'f4f4678c-c86c-4600-b46f-32cf6f5a5455', 'BoundingBox': {'Width': 0.38534799218177795, 'Height': 0.3883489966392517, 'Left': 0.32729899883270264, 'Top': 0.29180800914764404}, 'ImageId': '2b65479f-5dbb-32a8-adfb-e6e705f01503', 'Confidence': 100.0, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'f52eae1a-c706-42f2-a563-b2e2300788c3', 'BoundingBox': {'Width': 0.3567740023136139, 'Height': 0.36641499400138855, 'Left': 0.2735840082168579, 'Top': 0.20737899839878082}, 'ImageId': 'ad2f22c8-c392-3e19-b984-357f32f46ace', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'f6c7273c-442e-486c-b6ec-29cf7e0f376d', 'BoundingBox': {'Width': 0.4694019854068756, 'Height': 0.29518499970436096, 'Left': 0.23672500252723694, 'Top': 0.34163498878479004}, 'ImageId': '0efa53ca-9bcf-3947-a1ee-1dabf510b562', 'Confidence': 99.99949645996094, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'f7d98b8b-445d-45ab-a31b-e229421ed526', 'BoundingBox': {'Width': 0.12341099977493286, 'Height': 0.12546400725841522, 'Left': 0.3870899975299835, 'Top': 0.2714410126209259}, 'ImageId': '05ccaa71-0a2b-3586-b76f-c99b61f6cac7', 'Confidence': 99.97090148925781, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'f7d9bb2f-dd08-46e4-b977-777090c5d2c2', 'BoundingBox': {'Width': 0.39136001467704773, 'Height': 0.4162389934062958, 'Left': 0.21946899592876434, 'Top': 0.12647800147533417}, 'ImageId': 'd905131d-9d54-3023-a013-b4ed5c14a60d', 'Confidence': 100.0, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'f7eb0a8e-c1e5-45bb-bfef-279dcef5a004', 'BoundingBox': {'Width': 0.4967010021209717, 'Height': 0.7407150268554688, 'Left': 0.21812300384044647, 'Top': 0.184006005525589}, 'ImageId': '596c98ae-31e0-34c8-813f-55baa7d4fa54', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'f8b5223f-bea3-4ebc-9a07-cf1d65f28856', 'BoundingBox': {'Width': 0.3239090144634247, 'Height': 0.3327459990978241, 'Left': 0.3142769932746887, 'Top': 0.30881598591804504}, 'ImageId': 'cd1abbd3-a4a9-366b-b370-e95da0a43660', 'Confidence': 99.99949645996094, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'f9a7e1f9-5aa5-4c9f-a53a-296f02418672', 'BoundingBox': {'Width': 0.5563290119171143, 'Height': 0.38137900829315186, 'Left': 0.1784140020608902, 'Top': 0.32625100016593933}, 'ImageId': '91d2e4ac-6315-3559-860e-b72535ca6550', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'f9ee4d26-eb57-40d4-907f-bd297c45824d', 'BoundingBox': {'Width': 0.2841300070285797, 'Height': 0.3000589907169342, 'Left': 0.34349098801612854, 'Top': 0.2876189947128296}, 'ImageId': 'eb94a010-ffa9-376c-a02f-1359dc80e0bf', 'Confidence': 99.99930572509766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'fb3921d6-f706-4dd6-b19f-1be8e0ecff5e', 'BoundingBox': {'Width': 0.36271798610687256, 'Height': 0.39815598726272583, 'Left': 0.36285001039505005, 'Top': 0.3541960120201111}, 'ImageId': 'c485f75d-d8ef-3b5d-b94a-9a63af4da0a4', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'fbcec673-2644-45b1-a993-0f0c66eb9443', 'BoundingBox': {'Width': 0.49563199281692505, 'Height': 0.4813460111618042, 'Left': 0.03775250166654587, 'Top': 0.3151789903640747}, 'ImageId': '4f8f0e36-bf86-363d-b110-e893dfdfdfa5', 'Confidence': 99.99970245361328, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'fc3b8580-002d-40e2-9850-8abf193aa6e1', 'BoundingBox': {'Width': 0.5089240074157715, 'Height': 0.568356990814209, 'Left': 0.2927579879760742, 'Top': 0.029130199924111366}, 'ImageId': 'da55fc1b-90bd-32de-bf4a-a4cc57b44e52', 'Confidence': 99.99889373779297, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'fe7b3d20-c58c-44d3-9cd4-411643c477da', 'BoundingBox': {'Width': 0.5342140197753906, 'Height': 0.32346099615097046, 'Left': 0.27386200428009033, 'Top': 0.451990008354187}, 'ImageId': 'd912ebae-bc06-3b56-8d43-69eaf80109c6', 'Confidence': 99.99960327148438, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'febcbdc7-7371-4589-89ae-bd6e0ee683e6', 'BoundingBox': {'Width': 0.5946409702301025, 'Height': 0.4034219980239868, 'Left': 0.15620000660419464, 'Top': 0.28080299496650696}, 'ImageId': '8134e949-9142-3836-b337-4161e9f5fcbc', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'ff22d231-0e33-4914-85a2-c523c853f435', 'BoundingBox': {'Width': 0.3718329966068268, 'Height': 0.4039129912853241, 'Left': 0.383186012506485, 'Top': 0.3103390038013458}, 'ImageId': '2fc6dc71-8e14-308b-9ccd-a30d78d8a081', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# faces count: 239

# %%
#Copyright 2018 Amazon.com, Inc. or its affiliates. All Rights Reserved.
#PDX-License-Identifier: MIT-0 (For details, see https://github.com/awsdocs/amazon-rekognition-developer-guide/blob/master/LICENSE-SAMPLECODE.)

import boto3
from botocore.exceptions import ClientError
from os import environ

def delete_collection(collection_id):


    print('Attempting to delete collection ' + collection_id)
    client=boto3.client('rekognition')
    status_code=0
    try:
        response=client.delete_collection(CollectionId=collection_id)
        status_code=response['StatusCode']
        
    except ClientError as e:
        if e.response['Error']['Code'] == 'ResourceNotFoundException':
            print ('The collection ' + collection_id + ' was not found ')
        else:
            print ('Error other than Not Found occurred: ' + e.response['Error']['Message'])
        status_code=e.response['ResponseMetadata']['HTTPStatusCode']
    return(status_code)


def main():
    collection_id='attandence_collection'
    status_code=delete_collection(collection_id)
    print('Status code: ' + str(status_code))

if __name__ == "__main__":
    main()
# Out:
# Attempting to delete collection attandence_collection
# Status code: 200

# %%
import boto3


BUCKET = "attandence-bucket"
KEY = "index/abcd.png"
FEATURES_BLACKLIST = ("Landmarks", "Emotions", "Pose", "Quality", "BoundingBox", "Confidence")

def detect_faces(bucket, key, attributes=['ALL'], region="us-east-2"):
    rekognition = boto3.client("rekognition", region)
    response = rekognition.detect_faces(
        Image={
            "S3Object": {
                "Bucket": bucket,
                "Name": key,
            }
        },
        Attributes=attributes,
    )
    return response['FaceDetails']

for face in detect_faces(BUCKET, KEY):
    print ("Face ({Confidence}%)".format(**face))
    # emotions
    for emotion in face['Emotions']:
        print ("  {Type} : {Confidence}%".format(**emotion))
    # quality
    for quality, value in face['Quality'].iteritems():
        print ("  {quality} : {value}".format(quality=quality, value=value))
    # facial features
    for feature, data in face.iteritems():
        if feature not in FEATURES_BLACKLIST:
            print ("  {feature}({data[Value]}) : {data[Confidence]}%".format(feature=feature, data=data))
# Out:
# Face (99.6942138671875%)
#   SURPRISED : 81.62865447998047%
#   CALM : 8.259970664978027%
#   ANGRY : 4.233240604400635%
#   FEAR : 2.26208233833313%
#   CONFUSED : 1.805971622467041%
#   DISGUSTED : 0.7482640743255615%
#   SAD : 0.5447291731834412%
#   HAPPY : 0.5170879364013672%
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_5020/2468409127.py in <module>
#      25         print ("  {Type} : {Confidence}%".format(**emotion))
#      26     # quality
# ---> 27     for quality, value in face['Quality'].iteritems():
#      28         print ("  {quality} : {value}".format(quality=quality, value=value))
#      29     # facial features
#
# AttributeError: 'dict' object has no attribute 'iteritems'

# %%
a='<div class="contaienr"><div class="col-lg-4 mb-5"> '+'<div class="practicing">'+'<div class="practicing-inner">'+'<div class="wrap-icon">'+'<span class="flaticon-museum"></span>'+'</div>'+'<h3>Bankruptcy Law</h3>'+'<p>Lorem ipsum dolor sit amet, consectetur adipisicing elit. Vero, laboriosam!</p>'+'</div>'+'</div>'+'</div>'+'<div class="col-lg-4 mb-5">'+'<div class="practicing">'+'<div class="practicing-inner">'+'<div class="wrap-icon">'+'<span class="flaticon-shield"></span>'+'</div>'+'<h3>Business Law</h3>'+'<p>Lorem ipsum dolor sit amet, consectetur adipisicing elit. Vero, laboriosam!</p>'+'</div>'+'</div>'+'</div>'+'<div class="col-lg-4 mb-5">'+'<div class="practicing">'+'<div class="practicing-inner">'+'<div class="wrap-icon">'+'<span class="flaticon-help"></span>'+'</div>'+'<h3>Civil Rights Law</h3>'+'<p>Lorem ipsum dolor sit amet, consectetur adipisicing elit. Vero, laboriosam!</p>'+'</div>'+'</div>'+'</div>'+'<div class="col-lg-4 mb-5">'+'<div class="practicing">'+'<div class="practicing-inner">'+'<div class="wrap-icon">'+'<span class="flaticon-revolver"></span>'+'</div>'+'<h3>Criminal Law</h3>'+'<p>Lorem ipsum dolor sit amet, consectetur adipisicing elit. Vero, laboriosam!</p>'+'</div>'+'</div>'+'</div>'+'<div class="col-lg-4 mb-5">'+'<div class="practicing">'+'<div class="practicing-inner">'+'<div class="wrap-icon">'+'<span class="flaticon-luggage"></span>'+'</div>'+'<h3>Immigration Law</h3>'+'<p>Lorem ipsum dolor sit amet, consectetur adipisicing elit. Vero, laboriosam!</p>'+'</div>'+'</div>'+'</div>'+'<div class="col-lg-4 mb-5">'+'<div class="practicing">'+'<div class="practicing-inner">'+'<div class="wrap-icon">'+'<span class="flaticon-house"></span>'+'</div>'+'<h3>Family Law</h3>'+'<p>Lorem ipsum dolor sit amet, consectetur adipisicing elit. Vero, laboriosam!</p>'+'</div>'+'</div>'+'</div></div>'

# %%
a
# Out:
# '<div class="contaienr"><div class="col-lg-4 mb-5"> <div class="practicing"><div class="practicing-inner"><div class="wrap-icon"><span class="flaticon-museum"></span></div><h3>Bankruptcy Law</h3><p>Lorem ipsum dolor sit amet, consectetur adipisicing elit. Vero, laboriosam!</p></div></div></div><div class="col-lg-4 mb-5"><div class="practicing"><div class="practicing-inner"><div class="wrap-icon"><span class="flaticon-shield"></span></div><h3>Business Law</h3><p>Lorem ipsum dolor sit amet, consectetur adipisicing elit. Vero, laboriosam!</p></div></div></div><div class="col-lg-4 mb-5"><div class="practicing"><div class="practicing-inner"><div class="wrap-icon"><span class="flaticon-help"></span></div><h3>Civil Rights Law</h3><p>Lorem ipsum dolor sit amet, consectetur adipisicing elit. Vero, laboriosam!</p></div></div></div><div class="col-lg-4 mb-5"><div class="practicing"><div class="practicing-inner"><div class="wrap-icon"><span class="flaticon-revolver"></span></div><h3>Criminal Law</h3><p>Lorem ipsum dolor sit amet, consectetur adipisicing elit. Vero, laboriosam!</p></div></div></div><div class="col-lg-4 mb-5"><div class="practicing"><div class="practicing-inner"><div class="wrap-icon"><span class="flaticon-luggage"></span></div><h3>Immigration Law</h3><p>Lorem ipsum dolor sit amet, consectetur adipisicing elit. Vero, laboriosam!</p></div></div></div><div class="col-lg-4 mb-5"><div class="practicing"><div class="practicing-inner"><div class="wrap-icon"><span class="flaticon-house"></span></div><h3>Family Law</h3><p>Lorem ipsum dolor sit amet, consectetur adipisicing elit. Vero, laboriosam!</p></div></div></div></div>'

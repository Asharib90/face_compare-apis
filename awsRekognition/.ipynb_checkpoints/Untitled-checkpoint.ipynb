# %%
aws rekognition create-collection --collection-id attandence_collection --region us-east-2

# %%
import boto3
import io
from PIL import Image
from pathlib import Path
import tempfile

name = 'abcd'
name_with_ext =  name + '.png'
path = 'register/'+ name_with_ext
region_name='us-east-2'
bucket ='attandence-bucket'
collection_id = "attandence_collection"
TableName='attandence_collection'

rekognition = boto3.client('rekognition', region_name = region_name)
dynamodb = boto3.client('dynamodb', region_name = region_name)
s3 = boto3.resource('s3')

file = open(name_with_ext,'rb')
object = s3.Object('attandence-bucket',path)
s3_upload = object.put(Body=file,
                Metadata={'FullName':name}
                )

index_face_response=rekognition.index_faces(CollectionId=collection_id,
                            Image={'S3Object':{'Bucket':bucket,'Name':path}},
                            MaxFaces=1,
                            QualityFilter="AUTO",
                            DetectionAttributes=['ALL'])

faceId = index_face_response['FaceRecords'][0]['Face']['FaceId']

dynamodb_response = dynamodb.put_item(
    TableName = TableName,
    Item={
        'RekognitionId': {'S': faceId},
        'FullName': {'S': name}
        }
    )

faceId
# Out:
# '635305bc-d7f8-4e02-8ba2-4f17c5ef2c3c'

# %%
index_face_response
# Out:
# {'FaceRecords': [{'Face': {'FaceId': 'e3ba1690-d133-4e6e-a57e-2b5687b4cf09',
#     'BoundingBox': {'Width': 0.5961723327636719,
#      'Height': 0.47871923446655273,
#      'Left': 0.2804256081581116,
#      'Top': 0.3142184019088745},
#     'ImageId': 'aa080f88-2c7a-3eda-a9b2-00617c487eb5',
#     'Confidence': 99.99990844726562},
#    'FaceDetail': {'BoundingBox': {'Width': 0.5961723327636719,
#      'Height': 0.47871923446655273,
#      'Left': 0.2804256081581116,
#      'Top': 0.3142184019088745},
#     'AgeRange': {'Low': 23, 'High': 33},
#     'Smile': {'Value': False, 'Confidence': 97.58727264404297},
#     'Eyeglasses': {'Value': False, 'Confidence': 95.51785278320312},
#     'Sunglasses': {'Value': False, 'Confidence': 98.27735137939453},
#     'Gender': {'Value': 'Male', 'Confidence': 99.98873138427734},
#     'Beard': {'Value': True, 'Confidence': 87.44587707519531},
#     'Mustache': {'Value': False, 'Confidence': 62.08765411376953},
#     'EyesOpen': {'Value': True, 'Confidence': 97.9516372680664},
#     'MouthOpen': {'Value': False, 'Confidence': 95.88816833496094},
#     'Emotions': [{'Type': 'CALM', 'Confidence': 87.52814483642578},
#      {'Type': 'CONFUSED', 'Confidence': 6.140050888061523},
#      {'Type': 'ANGRY', 'Confidence': 2.1597981452941895},
#      {'Type': 'SURPRISED', 'Confidence': 1.7517898082733154},
#      {'Type': 'SAD', 'Confidence': 1.0860191583633423},
#      {'Type': 'FEAR', 'Confidence': 0.5594051480293274},
#      {'Type': 'HAPPY', 'Confidence': 0.4227452874183655},
#      {'Type': 'DISGUSTED', 'Confidence': 0.35205215215682983}],
#     'Landmarks': [{'Type': 'eyeLeft',
#       'X': 0.40299418568611145,
#       'Y': 0.5050914883613586},
#      {'Type': 'eyeRight', 'X': 0.6571575403213501, 'Y': 0.49635228514671326},
#      {'Type': 'mouthLeft', 'X': 0.4490152597427368, 'Y': 0.6730715036392212},
#      {'Type': 'mouthRight', 'X': 0.661573052406311, 'Y': 0.6664871573448181},
#      {'Type': 'nose', 'X': 0.5012520551681519, 'Y': 0.6082696914672852},
#      {'Type': 'leftEyeBrowLeft',
#       'X': 0.31599339842796326,
#       'Y': 0.4647209644317627},
#      {'Type': 'leftEyeBrowRight',
#       'X': 0.4334433674812317,
#       'Y': 0.4604024291038513},
#      {'Type': 'leftEyeBrowUp',
#       'X': 0.3657611012458801,
#       'Y': 0.4512809216976166},
#      {'Type': 'rightEyeBrowLeft',
#       'X': 0.579447329044342,
#       'Y': 0.45475006103515625},
#      {'Type': 'rightEyeBrowRight',
#       'X': 0.7589688897132874,
#       'Y': 0.4485412538051605},
#      {'Type': 'rightEyeBrowUp',
#       'X': 0.659910261631012,
#       'Y': 0.44007477164268494},
#      {'Type': 'leftEyeLeft',
#       'X': 0.36232253909111023,
#       'Y': 0.5038567781448364},
#      {'Type': 'leftEyeRight',
#       'X': 0.4533901512622833,
#       'Y': 0.5051084756851196},
#      {'Type': 'leftEyeUp', 'X': 0.39845114946365356, 'Y': 0.4977041184902191},
#      {'Type': 'leftEyeDown', 'X': 0.4044998288154602, 'Y': 0.5126394629478455},
#      {'Type': 'rightEyeLeft', 'X': 0.606831431388855, 'Y': 0.4996837079524994},
#      {'Type': 'rightEyeRight',
#       'X': 0.7076190710067749,
#       'Y': 0.4918572008609772},
#      {'Type': 'rightEyeUp', 'X': 0.6539719104766846, 'Y': 0.48872828483581543},
#      {'Type': 'rightEyeDown',
#       'X': 0.6567912101745605,
#       'Y': 0.5039517283439636},
#      {'Type': 'noseLeft', 'X': 0.4809216856956482, 'Y': 0.6168901920318604},
#      {'Type': 'noseRight', 'X': 0.5759921073913574, 'Y': 0.6135326027870178},
#      {'Type': 'mouthUp', 'X': 0.5308904051780701, 'Y': 0.6564050912857056},
#      {'Type': 'mouthDown', 'X': 0.544212281703949, 'Y': 0.7041913270950317},
#      {'Type': 'leftPupil', 'X': 0.40299418568611145, 'Y': 0.5050914883613586},
#      {'Type': 'rightPupil', 'X': 0.6571575403213501, 'Y': 0.49635228514671326},
#      {'Type': 'upperJawlineLeft',
#       'X': 0.31528425216674805,
#       'Y': 0.4883624017238617},
#      {'Type': 'midJawlineLeft',
#       'X': 0.3859782814979553,
#       'Y': 0.6683562994003296},
#      {'Type': 'chinBottom', 'X': 0.5757211446762085, 'Y': 0.7819571495056152},
#      {'Type': 'midJawlineRight',
#       'X': 0.8402753472328186,
#       'Y': 0.651500403881073},
#      {'Type': 'upperJawlineRight',
#       'X': 0.8723658919334412,
#       'Y': 0.467290461063385}],
#     'Pose': {'Roll': -6.23811149597168,
#      'Yaw': -14.224973678588867,
#      'Pitch': -5.432868480682373},
#     'Quality': {'Brightness': 76.86746978759766,
#      'Sharpness': 96.61495208740234},
#     'Confidence': 99.99990844726562}}],
#  'FaceModelVersion': '6.0',
#  'UnindexedFaces': [],
#  'ResponseMetadata': {'RequestId': 'af002a46-80d6-4d56-8e1d-c325de2a734b',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'af002a46-80d6-4d56-8e1d-c325de2a734b',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '3656',
#    'date': 'Sat, 08 Jan 2022 09:11:45 GMT'},
#   'RetryAttempts': 0}}

# %%
index_face_response
# Out:
# {'FaceRecords': [{'Face': {'FaceId': '635305bc-d7f8-4e02-8ba2-4f17c5ef2c3c',
#     'BoundingBox': {'Width': 0.014466222375631332,
#      'Height': 0.03450656309723854,
#      'Left': 0.7998406887054443,
#      'Top': 0.9368987083435059},
#     'ImageId': 'cfe56c71-1776-3e8e-969a-c4f14649090f',
#     'Confidence': 99.6942138671875},
#    'FaceDetail': {'BoundingBox': {'Width': 0.014466222375631332,
#      'Height': 0.03450656309723854,
#      'Left': 0.7998406887054443,
#      'Top': 0.9368987083435059},
#     'AgeRange': {'Low': 48, 'High': 56},
#     'Smile': {'Value': False, 'Confidence': 92.585205078125},
#     'Eyeglasses': {'Value': False, 'Confidence': 97.22028350830078},
#     'Sunglasses': {'Value': False, 'Confidence': 98.96420288085938},
#     'Gender': {'Value': 'Male', 'Confidence': 99.9949722290039},
#     'Beard': {'Value': False, 'Confidence': 80.22366333007812},
#     'Mustache': {'Value': False, 'Confidence': 92.09870147705078},
#     'EyesOpen': {'Value': True, 'Confidence': 78.05277252197266},
#     'MouthOpen': {'Value': True, 'Confidence': 55.75552749633789},
#     'Emotions': [{'Type': 'SURPRISED', 'Confidence': 81.62865447998047},
#      {'Type': 'CALM', 'Confidence': 8.259970664978027},
#      {'Type': 'ANGRY', 'Confidence': 4.233240604400635},
#      {'Type': 'FEAR', 'Confidence': 2.26208233833313},
#      {'Type': 'CONFUSED', 'Confidence': 1.805971622467041},
#      {'Type': 'DISGUSTED', 'Confidence': 0.7482640743255615},
#      {'Type': 'SAD', 'Confidence': 0.5447291731834412},
#      {'Type': 'HAPPY', 'Confidence': 0.5170879364013672}],
#     'Landmarks': [{'Type': 'eyeLeft',
#       'X': 0.8052263855934143,
#       'Y': 0.9499419331550598},
#      {'Type': 'eyeRight', 'X': 0.8108479380607605, 'Y': 0.9502246975898743},
#      {'Type': 'mouthLeft', 'X': 0.8056315183639526, 'Y': 0.9612095355987549},
#      {'Type': 'mouthRight', 'X': 0.8103064298629761, 'Y': 0.9614115357398987},
#      {'Type': 'nose', 'X': 0.8090126514434814, 'Y': 0.9550672769546509},
#      {'Type': 'leftEyeBrowLeft',
#       'X': 0.8027474284172058,
#       'Y': 0.9476047158241272},
#      {'Type': 'leftEyeBrowRight',
#       'X': 0.8067514300346375,
#       'Y': 0.9463250041007996},
#      {'Type': 'leftEyeBrowUp', 'X': 0.8049290180206299, 'Y': 0.94583660364151},
#      {'Type': 'rightEyeBrowLeft',
#       'X': 0.8099907636642456,
#       'Y': 0.9465053081512451},
#      {'Type': 'rightEyeBrowRight',
#       'X': 0.8125511407852173,
#       'Y': 0.9480878114700317},
#      {'Type': 'rightEyeBrowUp',
#       'X': 0.8114487528800964,
#       'Y': 0.9461842775344849},
#      {'Type': 'leftEyeLeft', 'X': 0.8040793538093567, 'Y': 0.9499727487564087},
#      {'Type': 'leftEyeRight',
#       'X': 0.8063176274299622,
#       'Y': 0.9501011371612549},
#      {'Type': 'leftEyeUp', 'X': 0.8052558302879333, 'Y': 0.9493255615234375},
#      {'Type': 'leftEyeDown', 'X': 0.805237889289856, 'Y': 0.9504374265670776},
#      {'Type': 'rightEyeLeft',
#       'X': 0.8097164630889893,
#       'Y': 0.9502761363983154},
#      {'Type': 'rightEyeRight',
#       'X': 0.811705470085144,
#       'Y': 0.9503408074378967},
#      {'Type': 'rightEyeUp', 'X': 0.8109071254730225, 'Y': 0.9496096968650818},
#      {'Type': 'rightEyeDown',
#       'X': 0.8108083009719849,
#       'Y': 0.9507048726081848},
#      {'Type': 'noseLeft', 'X': 0.8072764873504639, 'Y': 0.9568438529968262},
#      {'Type': 'noseRight', 'X': 0.8093673586845398, 'Y': 0.9569342732429504},
#      {'Type': 'mouthUp', 'X': 0.8083930611610413, 'Y': 0.959460437297821},
#      {'Type': 'mouthDown', 'X': 0.8082161545753479, 'Y': 0.9629651308059692},
#      {'Type': 'leftPupil', 'X': 0.8052263855934143, 'Y': 0.9499419331550598},
#      {'Type': 'rightPupil', 'X': 0.8108479380607605, 'Y': 0.9502246975898743},
#      {'Type': 'upperJawlineLeft',
#       'X': 0.8002344369888306,
#       'Y': 0.951482355594635},
#      {'Type': 'midJawlineLeft',
#       'X': 0.8014761805534363,
#       'Y': 0.9634337425231934},
#      {'Type': 'chinBottom', 'X': 0.8077087998390198, 'Y': 0.969161331653595},
#      {'Type': 'midJawlineRight',
#       'X': 0.8114944100379944,
#       'Y': 0.963877260684967},
#      {'Type': 'upperJawlineRight',
#       'X': 0.8125647902488708,
#       'Y': 0.9520912170410156}],
#     'Pose': {'Roll': 4.180323123931885,
#      'Yaw': 7.782762050628662,
#      'Pitch': 12.69754409790039},
#     'Quality': {'Brightness': 92.20983123779297,
#      'Sharpness': 4.3748369216918945},
#     'Confidence': 99.6942138671875}}],
#  'FaceModelVersion': '6.0',
#  'UnindexedFaces': [{'Reasons': ['LOW_SHARPNESS'],
#    'FaceDetail': {'BoundingBox': {'Width': 0.011546825990080833,
#      'Height': 0.023849600926041603,
#      'Left': 0.07112286984920502,
#      'Top': 0.7591665983200073},
#     'AgeRange': {'Low': 24, 'High': 34},
#     'Smile': {'Value': False, 'Confidence': 87.93558502197266},
#     'Eyeglasses': {'Value': False, 'Confidence': 95.09632873535156},
#     'Sunglasses': {'Value': False, 'Confidence': 97.09174346923828},
#     'Gender': {'Value': 'Male', 'Confidence': 99.84854125976562},
#     'Beard': {'Value': False, 'Confidence': 83.08165740966797},
#     'Mustache': {'Value': False, 'Confidence': 95.87628936767578},
#     'EyesOpen': {'Value': True, 'Confidence': 93.00064086914062},
#     'MouthOpen': {'Value': False, 'Confidence': 71.98477172851562},
#     'Emotions': [{'Type': 'CALM', 'Confidence': 74.4066162109375},
#      {'Type': 'FEAR', 'Confidence': 8.698599815368652},
#      {'Type': 'HAPPY', 'Confidence': 8.439961433410645},
#      {'Type': 'SAD', 'Confidence': 4.140251159667969},
#      {'Type': 'CONFUSED', 'Confidence': 1.3740954399108887},
#      {'Type': 'SURPRISED', 'Confidence': 1.370558738708496},
#      {'Type': 'ANGRY', 'Confidence': 0.8518874645233154},
#      {'Type': 'DISGUSTED', 'Confidence': 0.7180302143096924}],
#     'Landmarks': [{'Type': 'eyeLeft',
#       'X': 0.07445304095745087,
#       'Y': 0.7675169110298157},
#      {'Type': 'eyeRight', 'X': 0.07864772528409958, 'Y': 0.7689305543899536},
#      {'Type': 'mouthLeft', 'X': 0.07411623746156693, 'Y': 0.7752893567085266},
#      {'Type': 'mouthRight', 'X': 0.07759678363800049, 'Y': 0.7764402627944946},
#      {'Type': 'nose', 'X': 0.07661749422550201, 'Y': 0.7715001702308655},
#      {'Type': 'leftEyeBrowLeft',
#       'X': 0.07291922718286514,
#       'Y': 0.7654265761375427},
#      {'Type': 'leftEyeBrowRight',
#       'X': 0.07569731771945953,
#       'Y': 0.7652177214622498},
#      {'Type': 'leftEyeBrowUp',
#       'X': 0.07444130629301071,
#       'Y': 0.7645435333251953},
#      {'Type': 'rightEyeBrowLeft',
#       'X': 0.07809838652610779,
#       'Y': 0.7660236954689026},
#      {'Type': 'rightEyeBrowRight',
#       'X': 0.08021034300327301,
#       'Y': 0.7678698897361755},
#      {'Type': 'rightEyeBrowUp',
#       'X': 0.07927712053060532,
#       'Y': 0.7661676406860352},
#      {'Type': 'leftEyeLeft',
#       'X': 0.07365581393241882,
#       'Y': 0.7673237323760986},
#      {'Type': 'leftEyeRight',
#       'X': 0.07527558505535126,
#       'Y': 0.7678481340408325},
#      {'Type': 'leftEyeUp', 'X': 0.07449864596128464, 'Y': 0.7670794725418091},
#      {'Type': 'leftEyeDown',
#       'X': 0.07444602996110916,
#       'Y': 0.7678459882736206},
#      {'Type': 'rightEyeLeft',
#       'X': 0.07781016826629639,
#       'Y': 0.7687036395072937},
#      {'Type': 'rightEyeRight',
#       'X': 0.07933308929204941,
#       'Y': 0.7692254185676575},
#      {'Type': 'rightEyeUp', 'X': 0.0787084773182869, 'Y': 0.7684938907623291},
#      {'Type': 'rightEyeDown',
#       'X': 0.07859513908624649,
#       'Y': 0.7692356705665588},
#      {'Type': 'noseLeft', 'X': 0.07547445595264435, 'Y': 0.7725501656532288},
#      {'Type': 'noseRight', 'X': 0.07701918482780457, 'Y': 0.7730595469474792},
#      {'Type': 'mouthUp', 'X': 0.0761180892586708, 'Y': 0.7745564579963684},
#      {'Type': 'mouthDown', 'X': 0.07584474980831146, 'Y': 0.7769652605056763},
#      {'Type': 'leftPupil', 'X': 0.07445304095745087, 'Y': 0.7675169110298157},
#      {'Type': 'rightPupil', 'X': 0.07864772528409958, 'Y': 0.7689305543899536},
#      {'Type': 'upperJawlineLeft',
#       'X': 0.07131203263998032,
#       'Y': 0.7679024338722229},
#      {'Type': 'midJawlineLeft',
#       'X': 0.07147616893053055,
#       'Y': 0.7763851284980774},
#      {'Type': 'chinBottom', 'X': 0.0752788782119751, 'Y': 0.7812880277633667},
#      {'Type': 'midJawlineRight',
#       'X': 0.07888518273830414,
#       'Y': 0.7788477540016174},
#      {'Type': 'upperJawlineRight',
#       'X': 0.08046089112758636,
#       'Y': 0.7709654569625854}],
#     'Pose': {'Roll': 7.8560004234313965,
#      'Yaw': -0.039492588490247726,
#      'Pitch': 18.113868713378906},
#     'Quality': {'Brightness': 32.4948616027832,
#      'Sharpness': 1.8666280508041382},
#     'Confidence': 98.51432800292969}},
#   {'Reasons': ['SMALL_BOUNDING_BOX'],
#    'FaceDetail': {'BoundingBox': {'Width': 0.009972763247787952,
#      'Height': 0.02284545823931694,
#      'Left': 0.7494029998779297,
#      'Top': 0.7744690179824829},
#     'AgeRange': {'Low': 23, 'High': 33},
#     'Smile': {'Value': True, 'Confidence': 91.43324279785156},
#     'Eyeglasses': {'Value': False, 'Confidence': 57.375},
#     'Sunglasses': {'Value': False, 'Confidence': 80.83677673339844},
#     'Gender': {'Value': 'Male', 'Confidence': 99.85505676269531},
#     'Beard': {'Value': False, 'Confidence': 82.70872497558594},
#     'Mustache': {'Value': False, 'Confidence': 95.45592498779297},
#     'EyesOpen': {'Value': True, 'Confidence': 98.90492248535156},
#     'MouthOpen': {'Value': True, 'Confidence': 80.63475036621094},
#     'Emotions': [{'Type': 'HAPPY', 'Confidence': 99.20429229736328},
#      {'Type': 'SURPRISED', 'Confidence': 0.16553239524364471},
#      {'Type': 'DISGUSTED', 'Confidence': 0.16103044152259827},
#      {'Type': 'ANGRY', 'Confidence': 0.14063586294651031},
#      {'Type': 'FEAR', 'Confidence': 0.11843184381723404},
#      {'Type': 'SAD', 'Confidence': 0.09176445007324219},
#      {'Type': 'CALM', 'Confidence': 0.06820984184741974},
#      {'Type': 'CONFUSED', 'Confidence': 0.0501009002327919}],
#     'Landmarks': [{'Type': 'eyeLeft',
#       'X': 0.7525119781494141,
#       'Y': 0.7835642695426941},
#      {'Type': 'eyeRight', 'X': 0.7566642761230469, 'Y': 0.7839319109916687},
#      {'Type': 'mouthLeft', 'X': 0.7526737451553345, 'Y': 0.7914889454841614},
#      {'Type': 'mouthRight', 'X': 0.7561360597610474, 'Y': 0.7917903065681458},
#      {'Type': 'nose', 'X': 0.7546758055686951, 'Y': 0.7880527973175049},
#      {'Type': 'leftEyeBrowLeft',
#       'X': 0.7509286999702454,
#       'Y': 0.7815595865249634},
#      {'Type': 'leftEyeBrowRight',
#       'X': 0.7534921765327454,
#       'Y': 0.7813196778297424},
#      {'Type': 'leftEyeBrowUp',
#       'X': 0.7522624731063843,
#       'Y': 0.7807819843292236},
#      {'Type': 'rightEyeBrowLeft',
#       'X': 0.7558692097663879,
#       'Y': 0.7815274000167847},
#      {'Type': 'rightEyeBrowRight',
#       'X': 0.7581492066383362,
#       'Y': 0.7821800112724304},
#      {'Type': 'rightEyeBrowUp',
#       'X': 0.7570503950119019,
#       'Y': 0.7811984419822693},
#      {'Type': 'leftEyeLeft', 'X': 0.7517430186271667, 'Y': 0.7834494113922119},
#      {'Type': 'leftEyeRight',
#       'X': 0.7533243894577026,
#       'Y': 0.7837032675743103},
#      {'Type': 'leftEyeUp', 'X': 0.7525148391723633, 'Y': 0.7831687927246094},
#      {'Type': 'leftEyeDown', 'X': 0.7525171041488647, 'Y': 0.783911406993866},
#      {'Type': 'rightEyeLeft',
#       'X': 0.7558319568634033,
#       'Y': 0.7839244604110718},
#      {'Type': 'rightEyeRight',
#       'X': 0.7573700547218323,
#       'Y': 0.7839393615722656},
#      {'Type': 'rightEyeUp', 'X': 0.7566841840744019, 'Y': 0.783534586429596},
#      {'Type': 'rightEyeDown',
#       'X': 0.7566301226615906,
#       'Y': 0.7842696309089661},
#      {'Type': 'noseLeft', 'X': 0.7537447214126587, 'Y': 0.7887758016586304},
#      {'Type': 'noseRight', 'X': 0.7552820444107056, 'Y': 0.7889055609703064},
#      {'Type': 'mouthUp', 'X': 0.754487931728363, 'Y': 0.7907199263572693},
#      {'Type': 'mouthDown', 'X': 0.754402756690979, 'Y': 0.7930739521980286},
#      {'Type': 'leftPupil', 'X': 0.7525119781494141, 'Y': 0.7835642695426941},
#      {'Type': 'rightPupil', 'X': 0.7566642761230469, 'Y': 0.7839319109916687},
#      {'Type': 'upperJawlineLeft',
#       'X': 0.7497340440750122,
#       'Y': 0.7833017706871033},
#      {'Type': 'midJawlineLeft',
#       'X': 0.7504211664199829,
#       'Y': 0.7919085025787354},
#      {'Type': 'chinBottom', 'X': 0.7542215585708618, 'Y': 0.7970978617668152},
#      {'Type': 'midJawlineRight',
#       'X': 0.7577753663063049,
#       'Y': 0.7925280928611755},
#      {'Type': 'upperJawlineRight',
#       'X': 0.7587938904762268,
#       'Y': 0.7840765714645386}],
#     'Pose': {'Roll': 1.3540403842926025,
#      'Yaw': -0.7804293036460876,
#      'Pitch': 1.8846449851989746},
#     'Quality': {'Brightness': 94.90767669677734,
#      'Sharpness': 3.3018569946289062},
#     'Confidence': 99.96475219726562}},
#   {'Reasons': ['EXCEEDS_MAX_FACES'],
#    'FaceDetail': {'BoundingBox': {'Width': 0.011813418008387089,
#      'Height': 0.029269183054566383,
#      'Left': 0.7542082667350769,
#      'Top': 0.2792937755584717},
#     'AgeRange': {'Low': 42, 'High': 50},
#     'Smile': {'Value': False, 'Confidence': 78.46578979492188},
#     'Eyeglasses': {'Value': False, 'Confidence': 96.87250518798828},
#     'Sunglasses': {'Value': False, 'Confidence': 98.69445037841797},
#     'Gender': {'Value': 'Male', 'Confidence': 99.99736022949219},
#     'Beard': {'Value': False, 'Confidence': 51.89208221435547},
#     'Mustache': {'Value': False, 'Confidence': 89.81504821777344},
#     'EyesOpen': {'Value': True, 'Confidence': 85.91902160644531},
#     'MouthOpen': {'Value': False, 'Confidence': 53.47901153564453},
#     'Emotions': [{'Type': 'DISGUSTED', 'Confidence': 26.589527130126953},
#      {'Type': 'SAD', 'Confidence': 15.876642227172852},
#      {'Type': 'HAPPY', 'Confidence': 15.783042907714844},
#      {'Type': 'CONFUSED', 'Confidence': 13.359975814819336},
#      {'Type': 'ANGRY', 'Confidence': 11.304325103759766},
#      {'Type': 'FEAR', 'Confidence': 7.983588218688965},
#      {'Type': 'CALM', 'Confidence': 7.513473033905029},
#      {'Type': 'SURPRISED', 'Confidence': 1.5894213914871216}],
#     'Landmarks': [{'Type': 'eyeLeft',
#       'X': 0.7574391961097717,
#       'Y': 0.29023465514183044},
#      {'Type': 'eyeRight', 'X': 0.7625210881233215, 'Y': 0.29027578234672546},
#      {'Type': 'mouthLeft', 'X': 0.7576383948326111, 'Y': 0.29955151677131653},
#      {'Type': 'mouthRight', 'X': 0.7618758678436279, 'Y': 0.29958850145339966},
#      {'Type': 'nose', 'X': 0.7598116397857666, 'Y': 0.29490071535110474},
#      {'Type': 'leftEyeBrowLeft',
#       'X': 0.7555792927742004,
#       'Y': 0.2881445288658142},
#      {'Type': 'leftEyeBrowRight',
#       'X': 0.7585230469703674,
#       'Y': 0.28732582926750183},
#      {'Type': 'leftEyeBrowUp',
#       'X': 0.757068395614624,
#       'Y': 0.2868775725364685},
#      {'Type': 'rightEyeBrowLeft',
#       'X': 0.7614290714263916,
#       'Y': 0.2873567044734955},
#      {'Type': 'rightEyeBrowRight',
#       'X': 0.7644025087356567,
#       'Y': 0.2882213890552521},
#      {'Type': 'rightEyeBrowUp',
#       'X': 0.762919008731842,
#       'Y': 0.28693878650665283},
#      {'Type': 'leftEyeLeft', 'X': 0.7565335035324097, 'Y': 0.2902156412601471},
#      {'Type': 'leftEyeRight',
#       'X': 0.7584301233291626,
#       'Y': 0.2903226613998413},
#      {'Type': 'leftEyeUp', 'X': 0.7574262619018555, 'Y': 0.2897401452064514},
#      {'Type': 'leftEyeDown', 'X': 0.7574435472488403, 'Y': 0.2906380295753479},
#      {'Type': 'rightEyeLeft',
#       'X': 0.7614982724189758,
#       'Y': 0.2903475761413574},
#      {'Type': 'rightEyeRight',
#       'X': 0.7634134888648987,
#       'Y': 0.29027819633483887},
#      {'Type': 'rightEyeUp', 'X': 0.7625265717506409, 'Y': 0.2897844612598419},
#      {'Type': 'rightEyeDown', 'X': 0.7624732255935669, 'Y': 0.290682315826416},
#      {'Type': 'noseLeft', 'X': 0.7588518857955933, 'Y': 0.2961108982563019},
#      {'Type': 'noseRight', 'X': 0.760726273059845, 'Y': 0.29613563418388367},
#      {'Type': 'mouthUp', 'X': 0.7597390413284302, 'Y': 0.2983110249042511},
#      {'Type': 'mouthDown', 'X': 0.7596811652183533, 'Y': 0.3011673390865326},
#      {'Type': 'leftPupil', 'X': 0.7574391961097717, 'Y': 0.29023465514183044},
#      {'Type': 'rightPupil', 'X': 0.7625210881233215, 'Y': 0.29027578234672546},
#      {'Type': 'upperJawlineLeft',
#       'X': 0.7544469237327576,
#       'Y': 0.2908005714416504},
#      {'Type': 'midJawlineLeft',
#       'X': 0.755294144153595,
#       'Y': 0.30085495114326477},
#      {'Type': 'chinBottom', 'X': 0.7596067190170288, 'Y': 0.3061491847038269},
#      {'Type': 'midJawlineRight',
#       'X': 0.7642552256584167,
#       'Y': 0.30096590518951416},
#      {'Type': 'upperJawlineRight',
#       'X': 0.7655059099197388,
#       'Y': 0.2909127175807953}],
#     'Pose': {'Roll': 0.08293751627206802,
#      'Yaw': -0.7235618829727173,
#      'Pitch': 11.370366096496582},
#     'Quality': {'Brightness': 92.44574737548828,
#      'Sharpness': 3.3018569946289062},
#     'Confidence': 99.98267364501953}},
#   {'Reasons': ['EXCEEDS_MAX_FACES'],
#    'FaceDetail': {'BoundingBox': {'Width': 0.011697769165039062,
#      'Height': 0.0273759625852108,
#      'Left': 0.8018202185630798,
#      'Top': 0.6736711263656616},
#     'AgeRange': {'Low': 39, 'High': 47},
#     'Smile': {'Value': True, 'Confidence': 63.97356414794922},
#     'Eyeglasses': {'Value': False, 'Confidence': 97.01604461669922},
#     'Sunglasses': {'Value': False, 'Confidence': 98.71723175048828},
#     'Gender': {'Value': 'Male', 'Confidence': 99.98869323730469},
#     'Beard': {'Value': True, 'Confidence': 59.346431732177734},
#     'Mustache': {'Value': False, 'Confidence': 87.74765014648438},
#     'EyesOpen': {'Value': True, 'Confidence': 92.74591827392578},
#     'MouthOpen': {'Value': False, 'Confidence': 59.93415069580078},
#     'Emotions': [{'Type': 'HAPPY', 'Confidence': 92.13668060302734},
#      {'Type': 'CALM', 'Confidence': 2.867469072341919},
#      {'Type': 'CONFUSED', 'Confidence': 1.955694556236267},
#      {'Type': 'DISGUSTED', 'Confidence': 0.823129415512085},
#      {'Type': 'ANGRY', 'Confidence': 0.7276338934898376},
#      {'Type': 'SURPRISED', 'Confidence': 0.5486819744110107},
#      {'Type': 'SAD', 'Confidence': 0.4805256724357605},
#      {'Type': 'FEAR', 'Confidence': 0.46017685532569885}],
#     'Landmarks': [{'Type': 'eyeLeft',
#       'X': 0.8047116994857788,
#       'Y': 0.6836944222450256},
#      {'Type': 'eyeRight', 'X': 0.8093545436859131, 'Y': 0.683510422706604},
#      {'Type': 'mouthLeft', 'X': 0.8051559329032898, 'Y': 0.6924107670783997},
#      {'Type': 'mouthRight', 'X': 0.8090301156044006, 'Y': 0.6922754645347595},
#      {'Type': 'nose', 'X': 0.8067153096199036, 'Y': 0.6881715059280396},
#      {'Type': 'leftEyeBrowLeft',
#       'X': 0.803063690662384,
#       'Y': 0.681775689125061},
#      {'Type': 'leftEyeBrowRight',
#       'X': 0.8055244088172913,
#       'Y': 0.6810178160667419},
#      {'Type': 'leftEyeBrowUp',
#       'X': 0.8042365908622742,
#       'Y': 0.6806329488754272},
#      {'Type': 'rightEyeBrowLeft',
#       'X': 0.8081821203231812,
#       'Y': 0.680902361869812},
#      {'Type': 'rightEyeBrowRight',
#       'X': 0.8111297488212585,
#       'Y': 0.6814376711845398},
#      {'Type': 'rightEyeBrowUp',
#       'X': 0.8095873594284058,
#       'Y': 0.6804035902023315},
#      {'Type': 'leftEyeLeft', 'X': 0.803921639919281, 'Y': 0.6836962103843689},
#      {'Type': 'leftEyeRight',
#       'X': 0.8056226372718811,
#       'Y': 0.6837384104728699},
#      {'Type': 'leftEyeUp', 'X': 0.8046712875366211, 'Y': 0.6832471489906311},
#      {'Type': 'leftEyeDown', 'X': 0.8047260046005249, 'Y': 0.6840759515762329},
#      {'Type': 'rightEyeLeft',
#       'X': 0.8084258437156677,
#       'Y': 0.6836240887641907},
#      {'Type': 'rightEyeRight',
#       'X': 0.8102110624313354,
#       'Y': 0.6834474205970764},
#      {'Type': 'rightEyeUp', 'X': 0.8093326687812805, 'Y': 0.6830598711967468},
#      {'Type': 'rightEyeDown',
#       'X': 0.8093236684799194,
#       'Y': 0.6838953495025635},
#      {'Type': 'noseLeft', 'X': 0.8060513734817505, 'Y': 0.6892136931419373},
#      {'Type': 'noseRight', 'X': 0.8077681660652161, 'Y': 0.6891484260559082},
#      {'Type': 'mouthUp', 'X': 0.8068986535072327, 'Y': 0.6912459135055542},
#      {'Type': 'mouthDown', 'X': 0.8069650530815125, 'Y': 0.693891167640686},
#      {'Type': 'leftPupil', 'X': 0.8047116994857788, 'Y': 0.6836944222450256},
#      {'Type': 'rightPupil', 'X': 0.8093545436859131, 'Y': 0.683510422706604},
#      {'Type': 'upperJawlineLeft',
#       'X': 0.8024553060531616,
#       'Y': 0.68409264087677},
#      {'Type': 'midJawlineLeft',
#       'X': 0.8034383058547974,
#       'Y': 0.6934632658958435},
#      {'Type': 'chinBottom', 'X': 0.8071592450141907, 'Y': 0.698448657989502},
#      {'Type': 'midJawlineRight',
#       'X': 0.8116435408592224,
#       'Y': 0.6931285262107849},
#      {'Type': 'upperJawlineRight',
#       'X': 0.8125708699226379,
#       'Y': 0.6836596727371216}],
#     'Pose': {'Roll': -4.902154922485352,
#      'Yaw': -4.248603343963623,
#      'Pitch': 9.588418960571289},
#     'Quality': {'Brightness': 96.68366241455078,
#      'Sharpness': 3.3018569946289062},
#     'Confidence': 99.93358612060547}},
#   {'Reasons': ['EXCEEDS_MAX_FACES'],
#    'FaceDetail': {'BoundingBox': {'Width': 0.011534309014678001,
#      'Height': 0.026639584451913834,
#      'Left': 0.8107326626777649,
#      'Top': 0.7760174870491028},
#     'AgeRange': {'Low': 39, 'High': 47},
#     'Smile': {'Value': True, 'Confidence': 99.09579467773438},
#     'Eyeglasses': {'Value': False, 'Confidence': 99.0262222290039},
#     'Sunglasses': {'Value': False, 'Confidence': 99.50767517089844},
#     'Gender': {'Value': 'Male', 'Confidence': 99.95097351074219},
#     'Beard': {'Value': False, 'Confidence': 88.16368865966797},
#     'Mustache': {'Value': False, 'Confidence': 98.03215026855469},
#     'EyesOpen': {'Value': True, 'Confidence': 99.32192993164062},
#     'MouthOpen': {'Value': True, 'Confidence': 95.85452270507812},
#     'Emotions': [{'Type': 'HAPPY', 'Confidence': 99.84729766845703},
#      {'Type': 'ANGRY', 'Confidence': 0.05916696414351463},
#      {'Type': 'FEAR', 'Confidence': 0.035535432398319244},
#      {'Type': 'SURPRISED', 'Confidence': 0.01794353500008583},
#      {'Type': 'SAD', 'Confidence': 0.0136978505179286},
#      {'Type': 'DISGUSTED', 'Confidence': 0.012038415297865868},
#      {'Type': 'CONFUSED', 'Confidence': 0.008061064407229424},
#      {'Type': 'CALM', 'Confidence': 0.006264083087444305}],
#     'Landmarks': [{'Type': 'eyeLeft',
#       'X': 0.8139811754226685,
#       'Y': 0.786207377910614},
#      {'Type': 'eyeRight', 'X': 0.8186172246932983, 'Y': 0.7862752676010132},
#      {'Type': 'mouthLeft', 'X': 0.8143444061279297, 'Y': 0.7953702807426453},
#      {'Type': 'mouthRight', 'X': 0.8182123899459839, 'Y': 0.7954328656196594},
#      {'Type': 'nose', 'X': 0.8162003755569458, 'Y': 0.7913760542869568},
#      {'Type': 'leftEyeBrowLeft',
#       'X': 0.8122647404670715,
#       'Y': 0.7840040326118469},
#      {'Type': 'leftEyeBrowRight',
#       'X': 0.8149133920669556,
#       'Y': 0.7836101651191711},
#      {'Type': 'leftEyeBrowUp',
#       'X': 0.8135814666748047,
#       'Y': 0.7830697298049927},
#      {'Type': 'rightEyeBrowLeft',
#       'X': 0.8175718784332275,
#       'Y': 0.7836424112319946},
#      {'Type': 'rightEyeBrowRight',
#       'X': 0.8203319311141968,
#       'Y': 0.7841050624847412},
#      {'Type': 'rightEyeBrowUp',
#       'X': 0.8189356923103333,
#       'Y': 0.783135175704956},
#      {'Type': 'leftEyeLeft', 'X': 0.8131564259529114, 'Y': 0.7861250042915344},
#      {'Type': 'leftEyeRight',
#       'X': 0.8148905634880066,
#       'Y': 0.7863072752952576},
#      {'Type': 'leftEyeUp', 'X': 0.8139585256576538, 'Y': 0.7857615351676941},
#      {'Type': 'leftEyeDown', 'X': 0.8139919638633728, 'Y': 0.7866129875183105},
#      {'Type': 'rightEyeLeft',
#       'X': 0.8176897764205933,
#       'Y': 0.7863468527793884},
#      {'Type': 'rightEyeRight',
#       'X': 0.8194442391395569,
#       'Y': 0.7862135171890259},
#      {'Type': 'rightEyeUp', 'X': 0.818615734577179, 'Y': 0.7858272194862366},
#      {'Type': 'rightEyeDown',
#       'X': 0.8185870051383972,
#       'Y': 0.7866786122322083},
#      {'Type': 'noseLeft', 'X': 0.8153607845306396, 'Y': 0.7921918034553528},
#      {'Type': 'noseRight', 'X': 0.8170831799507141, 'Y': 0.7922144532203674},
#      {'Type': 'mouthUp', 'X': 0.8162124752998352, 'Y': 0.7943875789642334},
#      {'Type': 'mouthDown', 'X': 0.8162147402763367, 'Y': 0.7970918416976929},
#      {'Type': 'leftPupil', 'X': 0.8139811754226685, 'Y': 0.786207377910614},
#      {'Type': 'rightPupil', 'X': 0.8186172246932983, 'Y': 0.7862752676010132},
#      {'Type': 'upperJawlineLeft',
#       'X': 0.8113172650337219,
#       'Y': 0.7859586477279663},
#      {'Type': 'midJawlineLeft',
#       'X': 0.8122343420982361,
#       'Y': 0.7958223819732666},
#      {'Type': 'chinBottom', 'X': 0.8162413239479065, 'Y': 0.8016683459281921},
#      {'Type': 'midJawlineRight',
#       'X': 0.8204706907272339,
#       'Y': 0.795916736125946},
#      {'Type': 'upperJawlineRight',
#       'X': 0.8214483857154846,
#       'Y': 0.7860757112503052}],
#     'Pose': {'Roll': -0.2509962022304535,
#      'Yaw': -1.9320470094680786,
#      'Pitch': -0.42347249388694763},
#     'Quality': {'Brightness': 89.54339599609375,
#      'Sharpness': 3.3018569946289062},
#     'Confidence': 99.99630737304688}}],
#  'ResponseMetadata': {'RequestId': '79f25b1a-4bb8-49f0-b5d8-500e7b95f380',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '79f25b1a-4bb8-49f0-b5d8-500e7b95f380',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '20486',
#    'date': 'Sat, 08 Jan 2022 09:12:25 GMT'},
#   'RetryAttempts': 0}}

# %%
import boto3
import io
from PIL import Image

name = 'abcd'
name_with_ext =  name + '.jpg'
path = 'register/'+ name_with_ext
region_name='us-east-2'
threshold=80

TableName='attandence_collection'
bucket ='attandence-bucket'
collection_id = "attandence_collection"

rekognition = boto3.client('rekognition', region_name = region_name)
dynamodb = boto3.client('dynamodb', region_name = region_name)
s3 = boto3.resource('s3')

response = rekognition.search_faces_by_image(
    Image={
        "S3Object": {
            "Bucket": bucket,
            "Name": path,
        }
    },
    CollectionId=collection_id,
    FaceMatchThreshold=threshold)

faceId = response['FaceMatches'][0]['Face']['FaceId']
similarity = response['FaceMatches'][0]['Similarity']

dynamodb_response = dynamodb.get_item(
    TableName=TableName,  
    Key={'RekognitionId':{'S': faceId}})


RekognitionId = dynamodb_response['Item']['RekognitionId']['S']
FullName = dynamodb_response['Item']['FullName']['S']

RekognitionId,FullName
# Out:
# ---------------------------------------------------------------------------
# InvalidS3ObjectException                  Traceback (most recent call last)
# /tmp/ipykernel_5020/911317208.py in <module>
#      17 s3 = boto3.resource('s3')
#      18
# ---> 19 response = rekognition.search_faces_by_image(
#      20     Image={
#      21         "S3Object": {
#
# ~/anaconda3/lib/python3.8/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     389                     "%s() only accepts keyword arguments." % py_operation_name)
#     390             # The "self" in this scope is referring to the BaseClient.
# --> 391             return self._make_api_call(operation_name, kwargs)
#     392
#     393         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/lib/python3.8/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     717             error_code = parsed_response.get("Error", {}).get("Code")
#     718             error_class = self.exceptions.from_code(error_code)
# --> 719             raise error_class(parsed_response, operation_name)
#     720         else:
#     721             return parsed_response
#
# InvalidS3ObjectException: An error occurred (InvalidS3ObjectException) when calling the SearchFacesByImage operation: Unable to get object metadata from S3. Check object key, region and/or access permissions.

# %%
s3 = boto3.resource('s3')

# Get list of objects for indexing
images=[('abcd.png','Albert Einstein')]

# Iterate through list to upload objects to S3   
for image in images:
    file = open(image[0],'rb')
    object = s3.Object('attandence-bucket','index/'+ image[0])
    ret = object.put(Body=file,
                    Metadata={'FullName':image[1]}
                    )

# %%
import boto3
import io
from PIL import Image

rekognition = boto3.client('rekognition', region_name='us-east-2')
dynamodb = boto3.client('dynamodb', region_name='us-east-2')
    
image = Image.open("bb.jpg")
stream = io.BytesIO()
image.save(stream,format="JPEG")
image_binary = stream.getvalue()


response = rekognition.search_faces_by_image(
        CollectionId='attandence_collection',
        Image={'Bytes':image_binary}                                       
        )
for match in response['FaceMatches']:
    print (match['Face']['FaceId'],match['Face']['Confidence'])
        
    face = dynamodb.get_item(
        TableName='attandence_collection',  
        Key={'RekognitionId': {'S': match['Face']['FaceId']}}
        )
    
    if 'Item' in face:
        print (face['Item']['FullName']['S'])
    else:
        print ('no match found in person lookup')
# Out:
# 19808c2c-3233-44f1-8330-c50c030fff78 99.99979400634766
# no match found in person lookup

# %%
import boto3

BUCKET = "attandence-bucket"
KEY_SOURCE = "index/bb.jpg"
KEY_TARGET = "index/01.jpg"

def compare_faces(bucket, key, bucket_target, key_target, threshold=80, region="us-east-2"):
    rekognition = boto3.client("rekognition", region)
    response = rekognition.compare_faces(
        SourceImage={
            "S3Object": {
                "Bucket": bucket,
                "Name": key,
            }
        },
        TargetImage={
            "S3Object": {
                "Bucket": bucket_target,
                "Name": key_target,
            }
        },
           SimilarityThreshold=threshold,
    )
    print (response)
    
    return(response['SourceImageFace'], response['FaceMatches'])


source_face, matches = compare_faces(BUCKET, KEY_SOURCE, BUCKET, KEY_TARGET)

# the main source face
print ("Source Face ({Confidence}%)".format(**source_face))

# one match for each target face
for match in matches:
    print ("Target Face ({Confidence}%)".format(**match['Face']))
    print ("  Similarity : {}%".format(match['Similarity']))
# Out:
# ---------------------------------------------------------------------------
# InvalidS3ObjectException                  Traceback (most recent call last)
# /tmp/ipykernel_5020/272145641.py in <module>
#      27
#      28
# ---> 29 source_face, matches = compare_faces(BUCKET, KEY_SOURCE, BUCKET, KEY_TARGET)
#      30
#      31 # the main source face
#
# /tmp/ipykernel_5020/272145641.py in compare_faces(bucket, key, bucket_target, key_target, threshold, region)
#       7 def compare_faces(bucket, key, bucket_target, key_target, threshold=80, region="us-east-2"):
#       8     rekognition = boto3.client("rekognition", region)
# ----> 9     response = rekognition.compare_faces(
#      10         SourceImage={
#      11             "S3Object": {
#
# ~/anaconda3/lib/python3.8/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     389                     "%s() only accepts keyword arguments." % py_operation_name)
#     390             # The "self" in this scope is referring to the BaseClient.
# --> 391             return self._make_api_call(operation_name, kwargs)
#     392
#     393         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/lib/python3.8/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     717             error_code = parsed_response.get("Error", {}).get("Code")
#     718             error_class = self.exceptions.from_code(error_code)
# --> 719             raise error_class(parsed_response, operation_name)
#     720         else:
#     721             return parsed_response
#
# InvalidS3ObjectException: An error occurred (InvalidS3ObjectException) when calling the CompareFaces operation: Unable to get object metadata from S3. Check object key, region and/or access permissions.

# %%
import boto3

BUCKET = "attandence-bucket"
KEY = "a.jpg"
COLLECTION = "attandence_collection"

def search_faces_by_image(bucket, key, collection_id, threshold=80, region="us-east-2"):
    rekognition = boto3.client("rekognition", region)
    response = rekognition.search_faces_by_image(
        Image={
            "S3Object": {
                "Bucket": bucket,
                "Name": key,
            }
        },
        CollectionId=collection_id,
        FaceMatchThreshold=threshold,
    )
    return (response['FaceMatches'])

for record in search_faces_by_image(BUCKET, KEY, COLLECTION):
    face = record['Face']
    print ("Matched Face ({}%)".format(record['Similarity']))
    print ("  FaceId : {}".format(face['FaceId']))
#     print ("  ImageId : {}".format(face['ExternalImageId']))
# Out:
# ---------------------------------------------------------------------------
# InvalidImageFormatException               Traceback (most recent call last)
# /tmp/ipykernel_94880/197339735.py in <module>
#      19     return (response['FaceMatches'])
#      20
# ---> 21 for record in search_faces_by_image(BUCKET, KEY, COLLECTION):
#      22     face = record['Face']
#      23     print ("Matched Face ({}%)".format(record['Similarity']))
#
# /tmp/ipykernel_94880/197339735.py in search_faces_by_image(bucket, key, collection_id, threshold, region)
#       7 def search_faces_by_image(bucket, key, collection_id, threshold=80, region="us-east-2"):
#       8     rekognition = boto3.client("rekognition", region)
# ----> 9     response = rekognition.search_faces_by_image(
#      10         Image={
#      11             "S3Object": {
#
# ~/anaconda3/lib/python3.8/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     389                     "%s() only accepts keyword arguments." % py_operation_name)
#     390             # The "self" in this scope is referring to the BaseClient.
# --> 391             return self._make_api_call(operation_name, kwargs)
#     392
#     393         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/lib/python3.8/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     717             error_code = parsed_response.get("Error", {}).get("Code")
#     718             error_class = self.exceptions.from_code(error_code)
# --> 719             raise error_class(parsed_response, operation_name)
#     720         else:
#     721             return parsed_response
#
# InvalidImageFormatException: An error occurred (InvalidImageFormatException) when calling the SearchFacesByImage operation: Request has invalid image format

# %%
#delete image

#Copyright 2018 Amazon.com, Inc. or its affiliates. All Rights Reserved.
#PDX-License-Identifier: MIT-0 (For details, see https://github.com/awsdocs/amazon-rekognition-developer-guide/blob/master/LICENSE-SAMPLECODE.)

import boto3

def delete_faces_from_collection(collection_id, faces):

    client=boto3.client('rekognition')

    response=client.delete_faces(CollectionId=collection_id,
                               FaceIds=faces)
    
    print(str(len(response['DeletedFaces'])) + ' faces deleted:') 							
    for faceId in response['DeletedFaces']:
         print (faceId)
    return len(response['DeletedFaces'])

def main():

    collection_id='attandence_collection'
    faces=[]
    faces.append("73012bb2-ab0e-4001-8556-a36a2b4a20fb")
    faces.append("f76c7c76-f154-4a68-905c-0ca142aa14b4")
    faces.append("28f8c6af-9411-441e-a7f4-36ff982e79d1")

    faces_count=delete_faces_from_collection(collection_id, faces)
    print("deleted faces count: " + str(faces_count))

if __name__ == "__main__":
    main()
# Out:
# 1 faces deleted:
# 73012bb2-ab0e-4001-8556-a36a2b4a20fb
# deleted faces count: 1

# %%
client=boto3.client('rekognition')

dynamodb = boto3.client('dynamodb')
s3 = boto3.client('s3')


def add_faces_to_collection(bucket,photo,collection_id):

    response = dynamodb.put_item(
        TableName=bucket,
        Item={
            'RekognitionId': {'S': faceId},
            'FullName': {'S': fullName}
            }
        ) 

    response=client.index_faces(CollectionId=collection_id,
                                Image={'S3Object':{'Bucket':bucket,'Name':photo}},
                                MaxFaces=1,
                                QualityFilter="AUTO",
                                DetectionAttributes=['ALL'])

    print ('Results for ' + photo) 
    print('Faces indexed:')
    for faceRecord in response['FaceRecords']:
         print('  Face ID: ' + faceRecord['Face']['FaceId'])
         print('  Location: {}'.format(faceRecord['Face']['BoundingBox']))

    print('Faces not indexed:')
    for unindexedFace in response['UnindexedFaces']:
        print(' Location: {}'.format(unindexedFace['FaceDetail']['BoundingBox']))
        print(' Reasons:')
        for reason in unindexedFace['Reasons']:
            print('   ' + reason)
    return len(response['FaceRecords'])


bucket='attandence-bucket'
collection_id='attandence_collection'
photo="index/aa.jpg"


indexed_faces_count=add_faces_to_collection(bucket, photo, collection_id)
print("Faces indexed count: " + str(indexed_faces_count))
# Out:
# Results for index/aa.jpg
# Faces indexed:
#   Face ID: 44a6198c-919f-419e-990c-884dabafd440
#   Location: {'Width': 0.5961723327636719, 'Height': 0.47871923446655273, 'Left': 0.2804256081581116, 'Top': 0.3142184019088745}
# Faces not indexed:
# Faces indexed count: 1

# %%
import boto3

def list_faces_in_collection(collection_id):


    maxResults=2
    faces_count=0
    tokens=True

    client=boto3.client('rekognition')
    response=client.list_faces(CollectionId=collection_id,
                               MaxResults=maxResults)

    print('Faces in collection ' + collection_id)
 
    while tokens:
        
        print(response)

        faces=response['Faces']

        for face in faces:
            print ()
            faces_count+=1
        if 'NextToken' in response:
            nextToken=response['NextToken']
            response=client.list_faces(CollectionId=collection_id,
                                       NextToken=nextToken,MaxResults=maxResults)
        else:
            tokens=False
    return faces_count   
def main():

    collection_id='attandence_collection'
    
    faces_count=list_faces_in_collection(collection_id)
    print("faces count: " + str(faces_count))
if __name__ == "__main__":
    main()
# Out:
# Faces in collection attandence_collection
# {'Faces': [{'FaceId': '00046532-1ea3-406d-bca5-a5c4c8754dd5', 'BoundingBox': {'Width': 0.33466199040412903, 'Height': 0.36045700311660767, 'Left': 0.3138909935951233, 'Top': 0.29532700777053833}, 'ImageId': '561829cd-2efd-3247-8783-643d2d1d906f', 'Confidence': 99.99979400634766}, {'FaceId': '00c8fc6f-ccf3-4264-b946-530d32954c1d', 'BoundingBox': {'Width': 0.4525409936904907, 'Height': 0.4694550037384033, 'Left': 0.36021900177001953, 'Top': 0.11219000071287155}, 'ImageId': 'e0e1e007-4e39-34ec-854c-12d50f998b91', 'Confidence': 99.99930572509766}], 'NextToken': 'K3s77mNPABOziCeBAY3za4hRXS/y1dZAF5/+cn2xy3DogR6/QGC8KpICA7Yzx9Rvne0Hg/Vp+NIBNG2efTKCU4Hsne3ssTFS1DaEVqjaf/rqQHvFlUK8tUU=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '5efc47ac-2941-497b-b30e-71d3dca6b82a', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '5efc47ac-2941-497b-b30e-71d3dca6b82a', 'content-type': 'application/x-amz-json-1.1', 'content-length': '742', 'date': 'Tue, 21 Jun 2022 11:57:38 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '00ec8606-6853-4e41-bd48-fa54b5588300', 'BoundingBox': {'Width': 0.28390198945999146, 'Height': 0.28691598773002625, 'Left': 0.3172059953212738, 'Top': 0.48694300651550293}, 'ImageId': '586c5d6f-a104-3f1e-b3fb-e0bfce5d8b7f', 'Confidence': 99.99939727783203}, {'FaceId': '0180dccb-d76c-4ed6-b878-9a0adaaf3a6f', 'BoundingBox': {'Width': 0.5049700140953064, 'Height': 0.477524995803833, 'Left': 0.23315800726413727, 'Top': 0.28718799352645874}, 'ImageId': 'd6648543-6bcc-3b2d-9ed9-8d2fd4fc179e', 'Confidence': 99.99639892578125}], 'NextToken': 'bi4qqlhCOOJQrjZ5bEFRWZj+kEcCSJmah4nXOvl7gwBoQ6V3EDPtTAHfLMT2mr8wEzAhHt/V2xAX4U+TWtGCBkV+HRlDA0pDK+Ebaztp/zNkFxHZjnM5yfk=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': 'b809e0a7-bef4-4865-b4a9-9a6f157678f4', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'b809e0a7-bef4-4865-b4a9-9a6f157678f4', 'content-type': 'application/x-amz-json-1.1', 'content-length': '741', 'date': 'Tue, 21 Jun 2022 11:57:38 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '039b205b-c25c-46bd-99a8-205bcfb4890c', 'BoundingBox': {'Width': 0.4974440038204193, 'Height': 0.31957000494003296, 'Left': 0.2723200023174286, 'Top': 0.25080400705337524}, 'ImageId': '4eaf7aee-121c-3a15-8cf5-6fa71219f0f8', 'Confidence': 99.99559783935547}, {'FaceId': '03ebec70-4b4f-4873-af85-7687900e0933', 'BoundingBox': {'Width': 0.47305500507354736, 'Height': 0.5418130159378052, 'Left': 0.35868600010871887, 'Top': 0.35829800367355347}, 'ImageId': 'bfc07b69-2007-3cc7-90b9-3b65a48af5ca', 'Confidence': 99.99829864501953}], 'NextToken': '+lzuNQSLqhsM/8Dzx8raE6nEwtcTyOSM9R7FHK+ZBNT1kLr3++PXnupl7oS7/RH19ET50H0+ihZOntft9/KhLNTbGSyGEf4g1hR2bt72Y/ys6p52LnGsRPk=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': 'c5c2043e-c394-44f9-9c41-4cfedda46f53', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'c5c2043e-c394-44f9-9c41-4cfedda46f53', 'content-type': 'application/x-amz-json-1.1', 'content-length': '742', 'date': 'Tue, 21 Jun 2022 11:57:38 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '0458bfa8-c87b-4a69-a2ce-1d4b84d269d9', 'BoundingBox': {'Width': 0.32307198643684387, 'Height': 0.3240180015563965, 'Left': 0.2760320007801056, 'Top': 0.20314300060272217}, 'ImageId': 'c9b3946d-0f55-3abe-b831-aca5c3aff2e0', 'Confidence': 99.99970245361328}, {'FaceId': '080d4ed4-a587-4e95-b72d-c66bfb3abec3', 'BoundingBox': {'Width': 0.3103730082511902, 'Height': 0.32394400238990784, 'Left': 0.30849701166152954, 'Top': 0.24153999984264374}, 'ImageId': 'c3172ba3-50c3-3d64-a724-d95fc91ec2d6', 'Confidence': 99.99949645996094}], 'NextToken': 'HxE/TMxjSzaUxFkHiTm94w0Hb1Hde7sQBvTAmz6/QWCqA+Vuqb7CrJP5GY4wON9Dmow5FA+rRZE7wZaSqXr6U7fSln4DwUIEN8nkmi0fzz2lnVa1qxBRbeg=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '8507c34b-dc54-4106-85cb-a7e941eb96db', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '8507c34b-dc54-4106-85cb-a7e941eb96db', 'content-type': 'application/x-amz-json-1.1', 'content-length': '742', 'date': 'Tue, 21 Jun 2022 11:57:38 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '08f3cd64-878c-4c57-a701-8afa3436a9f5', 'BoundingBox': {'Width': 0.432778000831604, 'Height': 0.44930899143218994, 'Left': 0.26585501432418823, 'Top': 0.24363000690937042}, 'ImageId': '23f5d71c-a770-386d-bff7-b6773fb31815', 'Confidence': 99.99960327148438}, {'FaceId': '09d5c2a0-a4fa-4717-9838-020d7aa0d673', 'BoundingBox': {'Width': 0.4535689949989319, 'Height': 0.380748987197876, 'Left': 0.27581799030303955, 'Top': 0.2207449972629547}, 'ImageId': '7550ca3a-af68-3650-b133-d893c56e0189', 'Confidence': 99.84960174560547}], 'NextToken': 'ZyfBXAyvrUbmzaJTTnTMsX5I6V8Q4fqpU4m+dqPnsBtZAmHgoMaK7i4GEHzc4mH0EZIaw4As4mK+8tZo9BEu4fmfrxqHKcP1VPY9zFkBrrQlMBOBWbalVjE=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '27619564-7353-488d-931b-58d09d5c06c0', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '27619564-7353-488d-931b-58d09d5c06c0', 'content-type': 'application/x-amz-json-1.1', 'content-length': '739', 'date': 'Tue, 21 Jun 2022 11:57:39 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '09feee21-0c7d-4e07-bf4c-4fa7cebe5a5d', 'BoundingBox': {'Width': 0.5478609800338745, 'Height': 0.5909489989280701, 'Left': 0.28284499049186707, 'Top': 0.10773000121116638}, 'ImageId': '7bcf450f-4bfc-38e3-b20e-70feeb14fb1b', 'Confidence': 99.99949645996094}, {'FaceId': '0a43b7b5-9236-4c6f-8317-7c8ba2b98fe5', 'BoundingBox': {'Width': 0.4939880073070526, 'Height': 0.5002899765968323, 'Left': 0.26822999119758606, 'Top': 0.2328770011663437}, 'ImageId': 'e84c7bbd-48b7-3340-912e-14d271ed4eb3', 'Confidence': 99.99889373779297}], 'NextToken': 'xMflirmU8HzITFnp+0Ninmuxcb6xVy6rbT867fQfX+BCjWV8iJ06gD566KjPpQiLHVtv7eeNLmdkoi4VE5l3DFGQ6m849Ssc3tR7YOVtv/GfO/iJye0yFUs=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '1d3d5739-e5e0-4713-b865-9fdda6475ba3', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '1d3d5739-e5e0-4713-b865-9fdda6475ba3', 'content-type': 'application/x-amz-json-1.1', 'content-length': '740', 'date': 'Tue, 21 Jun 2022 11:57:39 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '0aa56333-34eb-4af9-94f6-3892231d6158', 'BoundingBox': {'Width': 0.3774999976158142, 'Height': 0.39392900466918945, 'Left': 0.29034000635147095, 'Top': 0.45041999220848083}, 'ImageId': '5d9dbf7a-d7c0-3e5d-998d-79b2413002a1', 'Confidence': 99.9999008178711}, {'FaceId': '0c87a5c6-9d26-42f2-ac80-2bf1b9ee154b', 'BoundingBox': {'Width': 0.3613409996032715, 'Height': 0.3867180049419403, 'Left': 0.31445199251174927, 'Top': 0.29234200716018677}, 'ImageId': '9ab781ce-5ba5-3edb-9f5d-9da5268e1930', 'Confidence': 99.99979400634766}], 'NextToken': 'B8RDzqVplkpGYF/CIRakAMDOeh+HMZ4PtacaQA0TsgVWXSMcmHmC6+59KhS7I+/bUkZ0M63BNxVcQPNzUmWEz2K736nGnnk9vXP04Y7mBoX4iXVBCLe8KCc=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': 'a80ddc6b-e2d4-4848-bd29-72296a4c50de', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'a80ddc6b-e2d4-4848-bd29-72296a4c50de', 'content-type': 'application/x-amz-json-1.1', 'content-length': '741', 'date': 'Tue, 21 Jun 2022 11:57:39 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '0f8893aa-58a0-48e7-8f61-ead91f834671', 'BoundingBox': {'Width': 0.6179280281066895, 'Height': 0.3697449862957001, 'Left': 0.2304140031337738, 'Top': 0.3033050000667572}, 'ImageId': '11d73d50-22cc-3d60-92d5-be6f7a3badba', 'Confidence': 99.9999008178711}, {'FaceId': '1072daff-78d4-4ccf-8c0c-dccf8e3d633e', 'BoundingBox': {'Width': 0.17125000059604645, 'Height': 0.1865610033273697, 'Left': 0.5142289996147156, 'Top': 0.41734498739242554}, 'ImageId': '14d388bb-b3f9-3302-8ab3-26314d9f43b2', 'Confidence': 99.99690246582031}], 'NextToken': 'pSJdQ4PL1ZhDwZWcB/7awR9vNr8HfZmozLXraKMf9+WAS1bOKSS6wyKRA6VOEWQC+by7487cA5EC5QOxD4YXnKsNez8gkfFXYCBCC0Mm4Xms2cWap32ePMA=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '0509c01d-99a0-4a5d-81e9-4a623c65aa84', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '0509c01d-99a0-4a5d-81e9-4a623c65aa84', 'content-type': 'application/x-amz-json-1.1', 'content-length': '738', 'date': 'Tue, 21 Jun 2022 11:57:39 GMT'}, 'RetryAttempts': 0}}
# {'Faces': [{'FaceId': '1149234f-d4e5-4978-9a74-815f613bf6ef', 'BoundingBox': {'Width': 0.6283149719238281, 'Height': 0.5096759796142578, 'Left': 0.10363399982452393, 'Top': 0.0002028779999818653}, 'ImageId': '7f3dc4d0-8f72-3653-8f4b-22b58e720c23', 'Confidence': 99.99909973144531}, {'FaceId': '11ad85de-07d1-4bd3-a339-d4b9ccf2d989', 'BoundingBox': {'Width': 0.7485820055007935, 'Height': 0.8176270127296448, 'Left': 0.1518069952726364, 'Top': 0.1437709927558899}, 'ImageId': '7c899e43-16e6-339a-b930-db2904155a5a', 'Confidence': 99.99960327148438}], 'NextToken': 'IHu6N8zbccNZIFY6nvYlgCw8Ulw7zWBR69z3yJsCSdZwCUQnNLTUNcwHcLzZm+oZPjGulJE8atkBptfghRCZrZxHnI+ha28PGmck95djd8jBBWKA61cbDVY=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': 'ef55ea0c-ee0b-4d54-bf86-54205b3cbb5b', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'ef55ea0c-ee0b-4d54-bf86-54205b3cbb5b', 'content-type': 'application/x-amz-json-1.1', 'content-length': '740', 'date': 'Tue, 21 Jun 2022 11:57:40 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '11afcc18-d50a-4d03-b208-9790eb4cebbb', 'BoundingBox': {'Width': 0.2781600058078766, 'Height': 0.29985499382019043, 'Left': 0.37454599142074585, 'Top': 0.3638080060482025}, 'ImageId': '2e02f801-3f52-3f95-8f2a-c2630d6785e3', 'Confidence': 99.99829864501953}, {'FaceId': '12047b69-459c-4399-85be-36d5c97fabf4', 'BoundingBox': {'Width': 0.49758198857307434, 'Height': 0.3856450021266937, 'Left': 0.2497120052576065, 'Top': 0.1465660035610199}, 'ImageId': '6833a6be-61d7-3899-b221-b0d2839f1892', 'Confidence': 99.9999008178711}], 'NextToken': 'wCxRMicfYG2XgWXRBOj6A5z6tVUUuU7qTsJYHG+U1O1GS9xomkrdsCKOBnpyKjPgCjNQRTGcETxEZwx/t7EpxqDEA9UpH0BpMBxAQqojZxXr0DFp8aLRGgg=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': 'b3a5bff4-cd55-416e-88e3-db8375501a72', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'b3a5bff4-cd55-416e-88e3-db8375501a72', 'content-type': 'application/x-amz-json-1.1', 'content-length': '739', 'date': 'Tue, 21 Jun 2022 11:57:40 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '120b39a3-5212-4165-9b5f-64e0feb744c4', 'BoundingBox': {'Width': 0.3234879970550537, 'Height': 0.3278369903564453, 'Left': 0.3935129940509796, 'Top': 0.12600399553775787}, 'ImageId': 'e0b60518-3c73-3ee7-8652-7588e5052307', 'Confidence': 99.99949645996094}, {'FaceId': '1410b75b-af56-4459-9155-b68a4f9b09c4', 'BoundingBox': {'Width': 0.3707219958305359, 'Height': 0.3733319938182831, 'Left': 0.29656898975372314, 'Top': 0.2652739882469177}, 'ImageId': '87b0de03-257b-364d-b48a-606b89b84218', 'Confidence': 99.9999008178711}], 'NextToken': 'isJIA2jhxPgUDCEScsB8zIw3/cyc9CYRePE9YRZxL/QfAZ/xiDRikc+HlPjcHOk8GCPDzcHsFfFRWL7vh/Ae/w9iZJrDC4ejzNtaXBAjtX7u9jJP532z1OY=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '72fbe3e7-2f1c-46ff-b434-e84652dae3d4', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '72fbe3e7-2f1c-46ff-b434-e84652dae3d4', 'content-type': 'application/x-amz-json-1.1', 'content-length': '738', 'date': 'Tue, 21 Jun 2022 11:57:40 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '17ec0fac-eba7-4e42-8891-badf37bca62f', 'BoundingBox': {'Width': 0.44937101006507874, 'Height': 0.2267879992723465, 'Left': 0.38727399706840515, 'Top': 0.3216229975223541}, 'ImageId': '5f1cce8d-2f47-3893-9a67-215e64f0c696', 'Confidence': 99.98930358886719}, {'FaceId': '191f976f-7367-466a-ac8a-af4ecf8e5a3e', 'BoundingBox': {'Width': 0.4519689977169037, 'Height': 0.4522640109062195, 'Left': 0.28938600420951843, 'Top': 0.14709599316120148}, 'ImageId': '253b3971-a439-3017-9848-257f09e84e91', 'Confidence': 99.99819946289062}], 'NextToken': 'n+2x+usSkHvBMHExFQ48lQdCco/bar4Xa+M9aCGOuHrh1UVH2NrV3LcWqmI11Yb6jRY5knSmc/tIb+SdVYM6+tRfi3MV8cqu7fU7GUXdBilUnb+JqUjOvto=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '183118a3-da37-461b-ab26-f1a5a3e27a76', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '183118a3-da37-461b-ab26-f1a5a3e27a76', 'content-type': 'application/x-amz-json-1.1', 'content-length': '741', 'date': 'Tue, 21 Jun 2022 11:57:40 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '19db590c-72fc-4ec6-aef3-141dd75f639e', 'BoundingBox': {'Width': 0.5369579792022705, 'Height': 0.43733999133110046, 'Left': 0.20366400480270386, 'Top': 0.24355000257492065}, 'ImageId': 'dcc9e8ca-e8a2-3ce7-ba25-c976e398b7dc', 'Confidence': 99.99979400634766}, {'FaceId': '1bfcfc04-43b1-47fb-8614-3fcb471824a7', 'BoundingBox': {'Width': 0.7621889710426331, 'Height': 0.5004709959030151, 'Left': 0.07364600151777267, 'Top': -0.00779312988743186}, 'ImageId': '7cb6cd61-9209-3ffa-8bfe-ec1e1a5fca12', 'Confidence': 99.99859619140625}], 'NextToken': 'cHtSvN73T5q7cHBMNCoMr6ciMKlR3Bj3SF/f32enLuyMkMLPQP5a7ou5bvnbLr2kaWMp5A12dTAB5KQV+vRwjQ3Yhrp54kuf4WFY/Wk4DeRfX2N3rx75nek=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '1d170560-659f-457a-87aa-1e2a7830cf3f', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '1d170560-659f-457a-87aa-1e2a7830cf3f', 'content-type': 'application/x-amz-json-1.1', 'content-length': '743', 'date': 'Tue, 21 Jun 2022 11:57:41 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '1c4d96a9-f314-428e-ba3e-c1e6dec7b81a', 'BoundingBox': {'Width': 0.09816809743642807, 'Height': 0.10565400123596191, 'Left': 0.4954630136489868, 'Top': 0.15657399594783783}, 'ImageId': 'e39197c1-398b-3f84-9018-fbff8b89c122', 'Confidence': 99.93069458007812}, {'FaceId': '1cf7bda1-61fd-4fbe-ba9c-057a650014a8', 'BoundingBox': {'Width': 0.6048589944839478, 'Height': 0.6374359726905823, 'Left': 0.1669899970293045, 'Top': 0.016903599724173546}, 'ImageId': '6c556132-09c8-32eb-a0e9-c7b44b5fce02', 'Confidence': 100.0}], 'NextToken': 'aVXEFHJyhGL39Kq/7l/T0LHvsNa+pLJ8YelliuV1XOnZqapj4+yH6nEDWtpbuisfWRsxSdgny0TtLjTQiopF7PtDuRtlbmo6gox2YnYqqq1+LTb+3NBavWw=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': 'b92ae70f-74a7-4e0e-94f3-5fca06920a23', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'b92ae70f-74a7-4e0e-94f3-5fca06920a23', 'content-type': 'application/x-amz-json-1.1', 'content-length': '730', 'date': 'Tue, 21 Jun 2022 11:57:41 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '1d6716d7-2686-4414-8191-4dee176bfac1', 'BoundingBox': {'Width': 0.5489519834518433, 'Height': 0.3469240069389343, 'Left': 0.22903700172901154, 'Top': 0.13467800617218018}, 'ImageId': '41b281ea-3ee5-3924-a270-afd61ebbee1c', 'Confidence': 99.99979400634766}, {'FaceId': '1d95c2f3-47c3-46b3-b427-1b5a7dcea8cd', 'BoundingBox': {'Width': 0.359605997800827, 'Height': 0.3690809905529022, 'Left': 0.30367401242256165, 'Top': 0.3598879873752594}, 'ImageId': 'abd7bc4a-032b-3a35-8110-d029fac80ce4', 'Confidence': 99.99979400634766}], 'NextToken': 'NCNh8pcZ/g7slrIlO5nBuDQrYy081kbJZRy4K20xqP5KcNvpv4yNjapa06KAMpowfXXH2IlWrDu80RGUBqGCg2byJHLDvtxv/2aLkoITEGXtge0hV7ufkQg=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '96794502-d6db-496c-9a03-7e5e1cb9e9dc', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '96794502-d6db-496c-9a03-7e5e1cb9e9dc', 'content-type': 'application/x-amz-json-1.1', 'content-length': '739', 'date': 'Tue, 21 Jun 2022 11:57:41 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '1dd728b0-ec0c-42df-84d7-ff616eedb422', 'BoundingBox': {'Width': 0.3246369957923889, 'Height': 0.3699069917201996, 'Left': 0.3381649851799011, 'Top': 0.42811599373817444}, 'ImageId': 'd630fa04-57f1-3a31-851e-46ebd6ef4f63', 'Confidence': 99.99909973144531}, {'FaceId': '1de07d24-aafc-4563-aafc-663b13ff1f76', 'BoundingBox': {'Width': 0.47348400950431824, 'Height': 0.5760290026664734, 'Left': 0.23739799857139587, 'Top': 0.1994680017232895}, 'ImageId': 'a369abc0-3f14-30c8-890a-21a281958895', 'Confidence': 99.9979019165039}], 'NextToken': 'bd8IwnKpRXI7c6uBdt+OnQTwoqckC+ZSPqvTKU48HNch1JQsYSio6WV3ezlA/guBnhk6mjwNBHDnCOZWVi4dIanrEtnkGxvXw+gp1DunNRp4q3Ym15+k10c=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '567fae6c-8d2e-4062-ac28-e771546488a0', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '567fae6c-8d2e-4062-ac28-e771546488a0', 'content-type': 'application/x-amz-json-1.1', 'content-length': '739', 'date': 'Tue, 21 Jun 2022 11:57:41 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '1e13d5ec-669a-47d8-8b43-f3a7384a3fa8', 'BoundingBox': {'Width': 0.3826259970664978, 'Height': 0.4093019962310791, 'Left': 0.3529070019721985, 'Top': 0.3142949938774109}, 'ImageId': '0baf7fca-6414-3103-930b-2e1c3032a64b', 'Confidence': 99.9999008178711}, {'FaceId': '1fbdeb65-5493-4ca3-89e7-f289661e2d15', 'BoundingBox': {'Width': 0.14556199312210083, 'Height': 0.15931600332260132, 'Left': 0.4250909984111786, 'Top': 0.37759101390838623}, 'ImageId': '6f38fa65-9fd2-3490-bfb7-d8d971f37323', 'Confidence': 99.9939956665039}], 'NextToken': 'Z/GSROwKw61A/vfH/6aEcXX+P3/iHR5X72Geq5xwvFaPm5fz6vJE+nZmg0b+iZ0ENEbCY8af4BMX400XAxvB3pH9LxO2SRsRq6GXW/NqumunZs33MisiZ7k=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': 'cb8fa1fe-38a5-457d-803d-d331fd347bb1', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'cb8fa1fe-38a5-457d-803d-d331fd347bb1', 'content-type': 'application/x-amz-json-1.1', 'content-length': '738', 'date': 'Tue, 21 Jun 2022 11:57:43 GMT'}, 'RetryAttempts': 0}}
# {'Faces': [{'FaceId': '204bb902-9470-48cd-bd54-4d121d73bf9c', 'BoundingBox': {'Width': 0.6911309957504272, 'Height': 0.4443790018558502, 'Left': 0.13505400717258453, 'Top': 0.2787509858608246}, 'ImageId': 'd64a847f-d82a-333b-aa25-82cfa3594f36', 'Confidence': 99.99939727783203}, {'FaceId': '20504411-1c87-4ad6-980a-2ca6bfb060e4', 'BoundingBox': {'Width': 0.46203500032424927, 'Height': 0.46724098920822144, 'Left': 0.2793610095977783, 'Top': 0.3665570020675659}, 'ImageId': '17570570-5269-370b-9e26-fe33f7326e9c', 'Confidence': 99.99759674072266}], 'NextToken': 'G+psfYjDa9+DJRTOs09EY0scOAc8k3oLrWXG/pdASUSiGJ0wZUkCDokdTEVZxlJGoDtNSboncBLjYD7O/jUGnPxSBCeiLYZ62Je2/XxutBKO6sea03sKa2g=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': 'bf16065f-0ee2-440f-8fd1-d706a9cf2f7c', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'bf16065f-0ee2-440f-8fd1-d706a9cf2f7c', 'content-type': 'application/x-amz-json-1.1', 'content-length': '740', 'date': 'Tue, 21 Jun 2022 11:57:43 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '20b2a852-357f-4f54-9de4-0817642657cc', 'BoundingBox': {'Width': 0.40210700035095215, 'Height': 0.4306589961051941, 'Left': 0.36286500096321106, 'Top': 0.18158499896526337}, 'ImageId': 'cd3c0b5b-da91-3069-8cd0-6d81d22da289', 'Confidence': 99.99960327148438}, {'FaceId': '21cca3b6-ffd4-4eed-82a7-414411611050', 'BoundingBox': {'Width': 0.561273992061615, 'Height': 0.3623029887676239, 'Left': 0.20969699323177338, 'Top': 0.2105029970407486}, 'ImageId': '6193397a-64bc-37be-9e08-0ec45694b49c', 'Confidence': 99.99960327148438}], 'NextToken': 'iKUuK5m6ItNyRCkzReuKeRr5d8UCaiT7Wr5Y6cei5UihQHWIEzxCQdVZL55SFFanopTOejj2xRqkYOmhT/lvO4n8LScZ/97+knE2s9u96vkB3kWO/qjn1w0=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': 'a3b02547-d127-4ffb-8acf-26c95ea12f6a', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'a3b02547-d127-4ffb-8acf-26c95ea12f6a', 'content-type': 'application/x-amz-json-1.1', 'content-length': '740', 'date': 'Tue, 21 Jun 2022 11:57:43 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '23831571-3cb9-41ed-9c3f-2293a72f4109', 'BoundingBox': {'Width': 0.29069700837135315, 'Height': 0.3095580041408539, 'Left': 0.41517800092697144, 'Top': 0.40055200457572937}, 'ImageId': '4ad34e1b-8cf4-3b6f-bb48-f69b21565564', 'Confidence': 99.99750518798828}, {'FaceId': '24431703-e439-450a-98b7-caa68c92b8f0', 'BoundingBox': {'Width': 0.3642750084400177, 'Height': 0.38172098994255066, 'Left': 0.2842690050601959, 'Top': 0.2977530062198639}, 'ImageId': '3f2a3f76-aa06-3d29-b702-d132da49b063', 'Confidence': 99.9999008178711}], 'NextToken': 'GDd6yY9Z/q2pWvvBpumvW69L/cgeVj3W9hPwVxbjUiOJUkNy34NH6FOiH6tkWAkOyJC4mvjqz0SNSEUvlCkEvORXLp4cmvO62cFwvn4jflctjnZYR84TgV0=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': 'fa8175fe-beff-46da-b765-0602255fa244', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'fa8175fe-beff-46da-b765-0602255fa244', 'content-type': 'application/x-amz-json-1.1', 'content-length': '740', 'date': 'Tue, 21 Jun 2022 11:57:43 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '2515dc82-04e3-4ace-a974-d6e2b36f47ba', 'BoundingBox': {'Width': 0.5719119906425476, 'Height': 0.3752579987049103, 'Left': 0.2893829941749573, 'Top': 0.2974329888820648}, 'ImageId': 'c186ee83-4a2c-3bc4-96db-3b0044831cb4', 'Confidence': 99.9999008178711}, {'FaceId': '25674b0c-73e3-46b1-8ded-6aa8c3f3f92c', 'BoundingBox': {'Width': 0.6870350241661072, 'Height': 0.40039700269699097, 'Left': 0.16524800658226013, 'Top': 0.23632100224494934}, 'ImageId': '8750c99d-6fe5-3525-abb0-80dad16235bd', 'Confidence': 99.9999008178711}], 'NextToken': '10Yjo+bLhbqNEFPDcm9z52H1IBiR7OgrZxpUPjbriQzN52NIY7YZ6+8K6Mm9LMsUqQDE7t0c5SS0U6R6wmdWn9QFLKy+YMfPggXaDVmUfp+zVeBdW7+NSOo=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': 'b1a09f1d-07ed-474f-8c19-467362c56e2b', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'b1a09f1d-07ed-474f-8c19-467362c56e2b', 'content-type': 'application/x-amz-json-1.1', 'content-length': '738', 'date': 'Tue, 21 Jun 2022 11:57:44 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '25a75e2e-24e6-4695-a691-b206dd027677', 'BoundingBox': {'Width': 0.44411900639533997, 'Height': 0.49271100759506226, 'Left': 0.2839910089969635, 'Top': 0.352975994348526}, 'ImageId': '5f60a368-a6e0-3f1e-92bb-82384bff2fcd', 'Confidence': 99.99810028076172}, {'FaceId': '26968d48-9f4f-421c-8cac-c25109a8a214', 'BoundingBox': {'Width': 0.3569200038909912, 'Height': 0.3741759955883026, 'Left': 0.385470986366272, 'Top': 0.22086699306964874}, 'ImageId': '29bf881c-1f12-3b38-bbb3-05f23cc7e101', 'Confidence': 100.0}], 'NextToken': 'wBC3rqQ8z6ABCjvdBHDx6MABwzVSk0tEf5MaGi+ufBut21MIxSRwRAcv2DVkT/UBd6Z9HpeeWUCTcCEoY0ZUP0pltBxHzTVpQbDhR4/wRGuVkXsXVf4n2cE=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '91f5a0a6-3260-47bd-8459-b50b2313b834', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '91f5a0a6-3260-47bd-8459-b50b2313b834', 'content-type': 'application/x-amz-json-1.1', 'content-length': '726', 'date': 'Tue, 21 Jun 2022 11:57:44 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '27ac989c-cf15-49e9-90e0-cbc5133cebbe', 'BoundingBox': {'Width': 0.28163498640060425, 'Height': 0.23686900734901428, 'Left': 0.2744230031967163, 'Top': 0.2041260004043579}, 'ImageId': 'f57c7bf3-b9a6-3bea-9fc8-3bae43d29b11', 'Confidence': 99.99610137939453}, {'FaceId': '27d3ca91-d1c1-4ec5-b13c-39493170b8c7', 'BoundingBox': {'Width': 0.3165520131587982, 'Height': 0.34321799874305725, 'Left': 0.35458898544311523, 'Top': 0.1456020027399063}, 'ImageId': 'b71f9115-c86d-314b-9032-90c67d02006d', 'Confidence': 99.99870300292969}], 'NextToken': '3UvXyGDmGempbvf7TuzIqOQ+3qEPntlrQdNGKMoOgPcdYx0f6PR0UKJq5yydA8sKLOx+VLQ7hS9LRuNHTFBMWlcPUIcGCubAgkC+636kuYi0dktonq9+EHQ=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '8db36ffb-74ce-46e1-871b-d806ceda64ef', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '8db36ffb-74ce-46e1-871b-d806ceda64ef', 'content-type': 'application/x-amz-json-1.1', 'content-length': '741', 'date': 'Tue, 21 Jun 2022 11:57:44 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '27ddaf41-0005-4cdf-b70a-27065db670d1', 'BoundingBox': {'Width': 0.37325799465179443, 'Height': 0.4065670073032379, 'Left': 0.32058998942375183, 'Top': 0.1779090017080307}, 'ImageId': 'cd80820a-95a0-3f72-892a-037f255c71a2', 'Confidence': 99.9999008178711}, {'FaceId': '28b4755f-8ee3-430e-baab-64206e2ae381', 'BoundingBox': {'Width': 0.4569160044193268, 'Height': 0.46212801337242126, 'Left': 0.19693699479103088, 'Top': 0.20332899689674377}, 'ImageId': 'bef0a5e1-c95a-35bd-bdb3-c0716302f88d', 'Confidence': 99.99949645996094}], 'NextToken': '92/AuqLh+D8wqQC3KvFkte+4UmR6fgBoquinctrjFffi192xcFwiRDldoRElfMwHQdnazk0eOavHIUCJadLyhqOkKT4ztOTqRBvHxzT7NRVP2JlYbSd4NjU=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': 'abdf79d1-a636-4b53-a5b5-5ba3025c1dec', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'abdf79d1-a636-4b53-a5b5-5ba3025c1dec', 'content-type': 'application/x-amz-json-1.1', 'content-length': '741', 'date': 'Tue, 21 Jun 2022 11:57:44 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '28f8c6af-9411-441e-a7f4-36ff982e79d1', 'BoundingBox': {'Width': 0.2509860098361969, 'Height': 0.2804180085659027, 'Left': 0.4298419952392578, 'Top': 0.21907499432563782}, 'ImageId': '24a4d100-939f-3126-a3c8-e081c0804fe6', 'Confidence': 99.99720001220703}, {'FaceId': '2a9cc674-ca89-4b35-9429-8a89c0cf404d', 'BoundingBox': {'Width': 0.4124070107936859, 'Height': 0.44354599714279175, 'Left': 0.3275560140609741, 'Top': 0.36647701263427734}, 'ImageId': 'a5daaaee-b8f3-3458-ab3a-754b95b015ee', 'Confidence': 99.99979400634766}], 'NextToken': 'CJTJBmm68WOOxbpXuAtTnsORL6iR1tstSKYDUpBMS8jdE0f4bN/pU+O4tTb4l1Q/AcH1wG4LwsHh2vQaUWHa7gQnprBefC+1J/XnfEY+WtCr8TKVGIAMSHA=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '49197196-0bc8-4eaa-b807-f8596f142e34', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '49197196-0bc8-4eaa-b807-f8596f142e34', 'content-type': 'application/x-amz-json-1.1', 'content-length': '740', 'date': 'Tue, 21 Jun 2022 11:57:45 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '2bc31f7f-827a-4a4f-b12f-a5a536638ec7', 'BoundingBox': {'Width': 0.3111740052700043, 'Height': 0.293971985578537, 'Left': 0.17973700165748596, 'Top': 0.33424898982048035}, 'ImageId': '77e1e26b-4ada-398f-a344-cf0ae06299f6', 'Confidence': 99.99919891357422}, {'FaceId': '2c1d0e0e-fb75-4bd5-b755-19b17e82b601', 'BoundingBox': {'Width': 0.3082030117511749, 'Height': 0.3409300148487091, 'Left': 0.4168210029602051, 'Top': 0.31492000818252563}, 'ImageId': '5d81ba19-2be7-3fe8-b2c5-73ad1b4531dc', 'Confidence': 99.99930572509766}], 'NextToken': '9eHMNOhvd89xbSw1pOV3dZi+j8ZfdabnWlOQs8Hmw+vQeU138P85rIHroD/JwhZR2KqeC4SQxgg3TNIE8UeUyDTHnvHk65DgOHp7dmrgnkQDMHwpZxmL1l8=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': 'a5ddc32f-1c94-4b04-9232-043c6f7cfc6b', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'a5ddc32f-1c94-4b04-9232-043c6f7cfc6b', 'content-type': 'application/x-amz-json-1.1', 'content-length': '739', 'date': 'Tue, 21 Jun 2022 11:57:45 GMT'}, 'RetryAttempts': 0}}
# {'Faces': [{'FaceId': '2d67ebc5-b2b5-4e41-8218-676b15d3343f', 'BoundingBox': {'Width': 0.3473460078239441, 'Height': 0.20282499492168427, 'Left': 0.2860789895057678, 'Top': 0.282586008310318}, 'ImageId': 'a6bb750e-a260-3485-bc6b-9f6d24fc12ff', 'Confidence': 99.99750518798828}, {'FaceId': '2e54665f-9b42-4e90-aeef-6c1762a8d21f', 'BoundingBox': {'Width': 0.6999310255050659, 'Height': 0.47102200984954834, 'Left': 0.19176800549030304, 'Top': 0.14070700109004974}, 'ImageId': 'a940cf42-2a07-3ff1-b63d-d817cdf4cb3a', 'Confidence': 99.99939727783203}], 'NextToken': 'DwWstvWzAeWKEJKsiZVeTAwR6BzhLyesyIFCT+Y+TWVTtXkKPRb1QDP8aBDqtRVDnE1KZeHlDinIbYtOGFcmRird8TZqzFrvbU0cZe8PD9Brj+5iBGHmYyE=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '5a9afbb7-c9e7-4709-b38c-160652ba65d4', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '5a9afbb7-c9e7-4709-b38c-160652ba65d4', 'content-type': 'application/x-amz-json-1.1', 'content-length': '740', 'date': 'Tue, 21 Jun 2022 11:57:45 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '2e96e8d4-991b-47e1-b4fc-3215099c2651', 'BoundingBox': {'Width': 0.5424829721450806, 'Height': 0.3393140137195587, 'Left': 0.2903499901294708, 'Top': 0.1838349997997284}, 'ImageId': 'f77fe747-caf3-3965-a55a-9d6bff153478', 'Confidence': 99.9999008178711}, {'FaceId': '316c2173-b2f4-4b6c-bc7b-f8053e881851', 'BoundingBox': {'Width': 0.6285049915313721, 'Height': 0.5171160101890564, 'Left': 0.16847099363803864, 'Top': 0.39326798915863037}, 'ImageId': '74a364a6-e97b-3e9c-b4d3-742b10dd4b38', 'Confidence': 99.99829864501953}], 'NextToken': '+75N0yxtPSPkzdTW2su4roiLMkZZy+BNZQg2SFPih2BhpaI4hLAk0tq2SvvXZRA9lxZRYGRmn/HgsUP06WZlZ1VykKHo3mWpC0iyDxfjkCjvZodUMpEvUuM=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '5b6a1a72-40ae-46bb-a479-40e967b3ee04', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '5b6a1a72-40ae-46bb-a479-40e967b3ee04', 'content-type': 'application/x-amz-json-1.1', 'content-length': '738', 'date': 'Tue, 21 Jun 2022 11:57:45 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '325fe5d8-f61b-4346-9008-74ced47fd1b3', 'BoundingBox': {'Width': 0.3794569969177246, 'Height': 0.3601920008659363, 'Left': 0.2777239978313446, 'Top': 0.23135100305080414}, 'ImageId': '039561ac-7139-3c49-a3df-b79319ad4fef', 'Confidence': 99.9999008178711}, {'FaceId': '32a65787-85dc-4b06-903d-15767290384e', 'BoundingBox': {'Width': 0.17802700400352478, 'Height': 0.3026370108127594, 'Left': 0.4316680133342743, 'Top': 0.0932127982378006}, 'ImageId': 'd24ad74a-36f9-38c8-88d2-d152248fca4c', 'Confidence': 99.99909973144531}], 'NextToken': '3iHbwA6/6oiobz7WSGUaMYgPJ09VI6Xy9HGlYD1RVE+kHjKVEnZUyT9syZc8UXx23z3ZJPMA/ZlpXZCRvgF/Q/XkHjCg+5fEkdBVs6sF6e4LwKETLJEiQ5c=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '8e7c478f-cdf0-4bd7-be78-31eeef2e16b6', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '8e7c478f-cdf0-4bd7-be78-31eeef2e16b6', 'content-type': 'application/x-amz-json-1.1', 'content-length': '738', 'date': 'Tue, 21 Jun 2022 11:57:46 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '369585ca-da27-4403-aeb1-423fc5122855', 'BoundingBox': {'Width': 0.43413999676704407, 'Height': 0.47268399596214294, 'Left': 0.26623299717903137, 'Top': 0.22065100073814392}, 'ImageId': '754d613f-ec5a-3c3a-a5f6-ab80967973f7', 'Confidence': 99.99919891357422}, {'FaceId': '36d5bb96-2fa1-4960-9c4c-6c4af3dc54b9', 'BoundingBox': {'Width': 0.628600001335144, 'Height': 0.39976099133491516, 'Left': 0.1514350026845932, 'Top': 0.19364500045776367}, 'ImageId': '1d76eded-2e8a-3dfa-bdb0-ae33ded5c55a', 'Confidence': 99.99979400634766}], 'NextToken': 'sHrZbajnBulivW9y/1v9sq8SJlCT36KVZVqtFcnuPHx6maY2Ajw48Us/IoCQ84PXwADymCLtl2E/7oN6oURKEvBnLVUkdUqSDPtIBf8qwzCw2/+ehcMCZhc=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '9ef4f652-902a-44fd-83f6-681552d0e5a0', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '9ef4f652-902a-44fd-83f6-681552d0e5a0', 'content-type': 'application/x-amz-json-1.1', 'content-length': '742', 'date': 'Tue, 21 Jun 2022 11:57:46 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '36f9247d-f7ee-4b0c-99ce-119913724fbf', 'BoundingBox': {'Width': 0.4808639883995056, 'Height': 0.29739299416542053, 'Left': 0.26627999544143677, 'Top': 0.27804499864578247}, 'ImageId': '33f502c3-1e7f-3b7a-8cb0-689e66e4df69', 'Confidence': 99.99930572509766}, {'FaceId': '3aa45472-096b-49ed-aedc-746a75b2c83a', 'BoundingBox': {'Width': 0.586122989654541, 'Height': 0.6781489849090576, 'Left': 0.1523829996585846, 'Top': 0.17230099439620972}, 'ImageId': 'd0628c52-9b79-36c5-a78a-423adf798643', 'Confidence': 99.99970245361328}], 'NextToken': 'es2zjBpz6QpZ7iCXHZW/Nbii5y6SibaOlW/PGihwB6ZM5DanGu47o71VYbsiWWCJ/dC9zlAI583GDfR9OhgIhmSPGuP6RP9HqHBuEtJIyzlMfgDzsvovQoc=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '5c5dee6f-fe19-47ac-a97e-d3d11a271102', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '5c5dee6f-fe19-47ac-a97e-d3d11a271102', 'content-type': 'application/x-amz-json-1.1', 'content-length': '740', 'date': 'Tue, 21 Jun 2022 11:57:46 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '3c0232a4-b9c8-4875-b0a1-be5ddbe85e0e', 'BoundingBox': {'Width': 0.5028870105743408, 'Height': 0.3281579911708832, 'Left': 0.27524399757385254, 'Top': 0.21389299631118774}, 'ImageId': 'cd272341-34d1-3b1b-b964-6bfa442aba33', 'Confidence': 99.99960327148438}, {'FaceId': '3c1a2630-34c7-4d67-8289-d2242e6ba274', 'BoundingBox': {'Width': 0.30333900451660156, 'Height': 0.31873199343681335, 'Left': 0.35916998982429504, 'Top': 0.26047399640083313}, 'ImageId': '9ffc2811-bed3-33cc-9110-388600184488', 'Confidence': 99.99919891357422}], 'NextToken': 'dFKmpVb0x0HCqMd/JR+rPQLioXFNzjpahdq8kgQHaW4ftwNMFmHCEtD7U6pSJs6QWuHcB3J0vQONUUzCRineKC1P6iM+JNkaRNhkSHf+QTHvcCOC4f3cq2U=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '090d28fc-bf60-4c24-926d-25f873fcecb9', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '090d28fc-bf60-4c24-926d-25f873fcecb9', 'content-type': 'application/x-amz-json-1.1', 'content-length': '743', 'date': 'Tue, 21 Jun 2022 11:57:46 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '415ef802-6f68-4653-aa08-00131bd4e429', 'BoundingBox': {'Width': 0.43982699513435364, 'Height': 0.5043089985847473, 'Left': 0.3099069893360138, 'Top': 0.12898799777030945}, 'ImageId': 'cf1a994a-1004-3d4e-94ef-7fea3d7f0c9b', 'Confidence': 99.9990005493164}, {'FaceId': '429032f1-3909-4ff7-b72a-9421152310eb', 'BoundingBox': {'Width': 0.44839200377464294, 'Height': 0.46281400322914124, 'Left': 0.22697100043296814, 'Top': 0.21084900200366974}, 'ImageId': '14d26600-c968-3c3d-903a-334f024c8d14', 'Confidence': 99.99960327148438}], 'NextToken': 'UPFtiwTCv154h5pwp0OTUNVhqMBGNrMnwlXaTrHx7OrApsitiSl2dLCaryXs08B4XIQoRCrP+OZuuTQy1sXzdkoAyi0HGHItvLGtO0VfReXTDvxac+Az5TE=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': 'de1b8228-5b61-420a-8871-e0cd4d742867', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'de1b8228-5b61-420a-8871-e0cd4d742867', 'content-type': 'application/x-amz-json-1.1', 'content-length': '742', 'date': 'Tue, 21 Jun 2022 11:57:47 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '43b748d4-6728-4c0f-9a12-10dffcde989c', 'BoundingBox': {'Width': 0.15393100678920746, 'Height': 0.16853900253772736, 'Left': 0.5259649753570557, 'Top': 0.394461989402771}, 'ImageId': '8bed91b2-72fe-3116-bb15-3a360642ba4a', 'Confidence': 99.997802734375}, {'FaceId': '465d07ad-8ffa-48b8-bb85-ce551422b4f5', 'BoundingBox': {'Width': 0.4235970079898834, 'Height': 0.4617460072040558, 'Left': 0.3318290114402771, 'Top': 0.2840699851512909}, 'ImageId': 'ffb6bf21-a715-306a-b505-377257a5064a', 'Confidence': 99.99939727783203}], 'NextToken': 'WwzEppk+feMNsTBNJnsLQZgOkIxxhMLOCWT2ywopsFM8S2utaG/TqcDd0CJOU3uVFzTimEEyuhxgOJc5pzqM2XprKKLSjx4lQuCOsM+yX3IoB3bt7wAC5pk=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': 'b2c3abda-59e0-4a30-999f-3d3fe61864c0', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'b2c3abda-59e0-4a30-999f-3d3fe61864c0', 'content-type': 'application/x-amz-json-1.1', 'content-length': '736', 'date': 'Tue, 21 Jun 2022 11:57:47 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '47961a3b-5c8e-4c92-a71d-6faec43601f3', 'BoundingBox': {'Width': 0.34311598539352417, 'Height': 0.3774000108242035, 'Left': 0.3432529866695404, 'Top': 0.14889000356197357}, 'ImageId': '8fa3e23e-c8cb-37ca-8a7b-21166cc92bdd', 'Confidence': 99.99960327148438}, {'FaceId': '4be176de-60d8-44ec-868d-5b5a6fe05571', 'BoundingBox': {'Width': 0.4633690118789673, 'Height': 0.47288501262664795, 'Left': 0.2938930094242096, 'Top': 0.2679780125617981}, 'ImageId': '72caccd7-cb12-3316-9854-f8c64e39eeb8', 'Confidence': 99.9990005493164}], 'NextToken': 'kO0cAbfVttxUgRVJhTI22cbfUb3eCo9LsmjED/gT+WdIvVhKAo1KUk+lG9gFmEZTO3L9XhJF8JrpawL/cuhEBbV+HfVossgyAW4bI9+HgLXddL7gSESxb7o=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '487a08d8-a822-4807-bff1-e749dbdb96ec', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '487a08d8-a822-4807-bff1-e749dbdb96ec', 'content-type': 'application/x-amz-json-1.1', 'content-length': '739', 'date': 'Tue, 21 Jun 2022 11:57:47 GMT'}, 'RetryAttempts': 0}}
# {'Faces': [{'FaceId': '4f9ccbd8-21bd-4edb-b665-dbcbf69436e0', 'BoundingBox': {'Width': 0.5171189904212952, 'Height': 0.2918170094490051, 'Left': 0.31513500213623047, 'Top': 0.3202759921550751}, 'ImageId': '11e1afc0-8253-39ff-bcdd-c8e224d7a4a0', 'Confidence': 99.9999008178711}, {'FaceId': '505b2b90-f0a3-439e-bb2e-9091d373fd37', 'BoundingBox': {'Width': 0.38697099685668945, 'Height': 0.4318299889564514, 'Left': 0.3445410132408142, 'Top': 0.16933700442314148}, 'ImageId': '1cc52310-f527-3688-843d-07601db4de16', 'Confidence': 99.9999008178711}], 'NextToken': 'y0urvZLl0LT+ax7+mTp/HeyW91e+Hta3O8JBnjm5okYyXPSV2mKUVX38VT4XrsczDd/FA+3P8gYEtue9CawcoAYj3tdeFZyWbzmhDKSo3f9dLpYb434Kk+M=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '9e615039-ae56-40fd-81ac-842a03a4f103', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '9e615039-ae56-40fd-81ac-842a03a4f103', 'content-type': 'application/x-amz-json-1.1', 'content-length': '738', 'date': 'Tue, 21 Jun 2022 11:57:48 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '50c1f4a9-8c68-4a9b-bdf3-d81e0a90632b', 'BoundingBox': {'Width': 0.22551600635051727, 'Height': 0.24250799417495728, 'Left': 0.32847800850868225, 'Top': 0.28485000133514404}, 'ImageId': '3a549bac-ebc2-3f1a-9d7b-68589a2c338c', 'Confidence': 99.997802734375}, {'FaceId': '50eae9f6-3159-4594-a019-54449accbec9', 'BoundingBox': {'Width': 0.2645129859447479, 'Height': 0.27772998809814453, 'Left': 0.29350700974464417, 'Top': 0.2917410135269165}, 'ImageId': '50a52ea0-969e-33a0-8df2-d240f1890276', 'Confidence': 99.99949645996094}], 'NextToken': 'c34075KdDWZih2GX3YdJs1p6I71iCzCx1miXW0w/u6YH13qta9vH76rlCwT2rIhOlSU/3rg4vyQErfv38P6gEMiep6I+Nk8NmF3PVm8qNCVVU8lEbuJ5Wpg=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '44af2c2f-dbd0-4dcf-b45d-918d1253ceba', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '44af2c2f-dbd0-4dcf-b45d-918d1253ceba', 'content-type': 'application/x-amz-json-1.1', 'content-length': '741', 'date': 'Tue, 21 Jun 2022 11:57:48 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '522a5245-357a-4c09-84a2-eb49e8e4f4f6', 'BoundingBox': {'Width': 0.2834340035915375, 'Height': 0.30347299575805664, 'Left': 0.3923240005970001, 'Top': 0.2244569957256317}, 'ImageId': '72689b07-8452-3c07-bdd3-19cd865c2145', 'Confidence': 99.99970245361328}, {'FaceId': '52be6141-3a96-4f83-a147-46b8fa027e23', 'BoundingBox': {'Width': 0.4509499967098236, 'Height': 0.5258690118789673, 'Left': 0.22339500486850739, 'Top': 0.24021799862384796}, 'ImageId': '624eaf15-7596-3cab-975e-f940d9ed4dfc', 'Confidence': 99.99939727783203}], 'NextToken': '2nTXG+JrvDJfkHjmG9TBoGMxi0dyXTEFsRcQTN2nSiqcsekxlCIRkjlIUjE0is9tjdzmnWXD9SrjOLH1Da7/EsbBIc6uI9yRTOl+omNOAIf/rtdfS++sogs=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '8191f1b4-9170-4c47-80a0-fa753a28dc89', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '8191f1b4-9170-4c47-80a0-fa753a28dc89', 'content-type': 'application/x-amz-json-1.1', 'content-length': '740', 'date': 'Tue, 21 Jun 2022 11:57:48 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '53f38ca8-26ec-4531-9e47-25ecc2efe775', 'BoundingBox': {'Width': 0.21236200630664825, 'Height': 0.2068769931793213, 'Left': 0.29425498843193054, 'Top': 0.23624099791049957}, 'ImageId': 'df21cfa1-80a6-39ea-be9d-2a2d4189f0f0', 'Confidence': 99.99819946289062}, {'FaceId': '54ce720b-182f-4648-b5bd-4aa4ed47f980', 'BoundingBox': {'Width': 0.5343350172042847, 'Height': 0.322176992893219, 'Left': 0.09821689873933792, 'Top': 0.22859400510787964}, 'ImageId': '6d34ad39-e40b-3073-ac8e-d387b7d9e58d', 'Confidence': 99.9999008178711}], 'NextToken': 'MZK+99yFElwB8OxmMzwgo9JU/ubD/b+552W7CwiWS6QEmOTCbd6lHrpPOaVaHSBLHjBwk2qVxSC7QzhBjt6Yeh+wIqfiCgBnV884f6VogNoazne5u2Lb7Wo=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '8a648d5a-ac27-4ef1-8263-3c3bdb6e0f09', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '8a648d5a-ac27-4ef1-8263-3c3bdb6e0f09', 'content-type': 'application/x-amz-json-1.1', 'content-length': '740', 'date': 'Tue, 21 Jun 2022 11:57:48 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '556939cc-ae86-426b-bda2-5a8ccdb2602e', 'BoundingBox': {'Width': 0.18896999955177307, 'Height': 0.1882220059633255, 'Left': 0.4429610073566437, 'Top': 0.38079598546028137}, 'ImageId': '2628a577-15dd-3eba-be2d-7e1f47235389', 'Confidence': 99.99729919433594}, {'FaceId': '55dc550c-badf-430e-a9d0-9e5a29c4a37b', 'BoundingBox': {'Width': 0.5475119948387146, 'Height': 0.5970039963722229, 'Left': 0.28190600872039795, 'Top': 0.2549920082092285}, 'ImageId': 'c49a9b0f-4a5a-3da5-85e4-61994ac8d82f', 'Confidence': 99.99970245361328}], 'NextToken': 'H6aH9qnKqBtCAHa6oB4kZBMVRw7isCBfmyqyIr806Ar8qwUddrYFUYMfnHUNqyqdUEZD9dM3P91dvCw5VFaDyt9SFawc+TBL11qrzW6nh6yk5mS+y1pEwKY=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': 'a3ee1203-a670-4140-92cb-07b7f36f0cc6', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'a3ee1203-a670-4140-92cb-07b7f36f0cc6', 'content-type': 'application/x-amz-json-1.1', 'content-length': '740', 'date': 'Tue, 21 Jun 2022 11:57:49 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '55fc0f1d-3fb6-4bd3-b340-ce076257cfca', 'BoundingBox': {'Width': 0.3406060039997101, 'Height': 0.3381910026073456, 'Left': 0.33010199666023254, 'Top': 0.2186489999294281}, 'ImageId': '6e9f4696-59fc-3eae-b1fc-93870376265e', 'Confidence': 99.99979400634766}, {'FaceId': '5627503b-91d4-4ba5-9c72-aa9f31239fff', 'BoundingBox': {'Width': 0.25493699312210083, 'Height': 0.2598060071468353, 'Left': 0.16107100248336792, 'Top': 0.16944199800491333}, 'ImageId': '087ab1e5-9681-300e-9107-f1998bd31287', 'Confidence': 99.99859619140625}], 'NextToken': 'Zs8cwoxc7/bzkKwG8OF8Ahu6Jg3Ry27Lk5vA+Gt9HIN5om3k9N9pM1R/n+uU8sZfbVA31mvR9VVoXmQOPfh/7ja8K0dTho4zx02xub/r71aTsM+kLL8TDYU=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '4115829f-c507-447e-ad41-81cf201a57b6', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '4115829f-c507-447e-ad41-81cf201a57b6', 'content-type': 'application/x-amz-json-1.1', 'content-length': '741', 'date': 'Tue, 21 Jun 2022 11:57:49 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '569887b6-75de-4daa-870f-85738f35b628', 'BoundingBox': {'Width': 0.7160050272941589, 'Height': 0.4622339904308319, 'Left': 0.16157400608062744, 'Top': 0.16990399360656738}, 'ImageId': '2cd6ea02-3446-33e3-9da3-94de4ec8b4dc', 'Confidence': 99.99970245361328}, {'FaceId': '5859e313-df1d-4f26-9daf-93d954e8aae1', 'BoundingBox': {'Width': 0.6763169765472412, 'Height': 0.41186100244522095, 'Left': 0.22533999383449554, 'Top': 0.147025004029274}, 'ImageId': 'a94223aa-2bef-3dae-8041-3f8fb0f1bad9', 'Confidence': 99.9999008178711}], 'NextToken': 'fgXk18jzblUC8KDJVSZWz1ufowgKwYU7Xuwof9T/ESGTbAVlb5ULIPnkmhhSFNZPnMoBHd9z9OuxjDBKz8a3N05ZJJQySsPdqAqyLiknGwtMgEJzVB/VAys=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '636d5de9-604b-4ebc-a274-06718420add8', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '636d5de9-604b-4ebc-a274-06718420add8', 'content-type': 'application/x-amz-json-1.1', 'content-length': '739', 'date': 'Tue, 21 Jun 2022 11:57:49 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '59d14699-2f18-4106-9422-b6b3f5933c89', 'BoundingBox': {'Width': 0.24324600398540497, 'Height': 0.27677100896835327, 'Left': 0.34967198967933655, 'Top': 0.3034000098705292}, 'ImageId': '3ac474be-88b6-3460-b3fd-e93f66f8243f', 'Confidence': 99.9939956665039}, {'FaceId': '5a40a257-cd31-4fef-b057-319acf85e55b', 'BoundingBox': {'Width': 0.5971850156784058, 'Height': 0.3650200068950653, 'Left': 0.26109400391578674, 'Top': 0.20443400740623474}, 'ImageId': '7b345b25-01f6-34a4-8a4c-736ef580ebcf', 'Confidence': 99.9999008178711}], 'NextToken': 'qBiBzqUkwjarLVsA+wIbqHCMWbxlegyfHmA+V2mnjDuqVpEnftdSUbUVk2LHWe94YVzNNLkJyQaEAV9DjbgCzlNqArsUiv7LAvTgWzs1tuzhOjt4HjjOzUY=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': 'b9cfba51-d7a2-4b1c-a555-7f69a163eaed', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'b9cfba51-d7a2-4b1c-a555-7f69a163eaed', 'content-type': 'application/x-amz-json-1.1', 'content-length': '740', 'date': 'Tue, 21 Jun 2022 11:57:50 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '5d06675a-08c7-4a1c-8b36-dfcb9f6e61c0', 'BoundingBox': {'Width': 0.4382930099964142, 'Height': 0.4558990001678467, 'Left': 0.2813270092010498, 'Top': 0.15093199908733368}, 'ImageId': 'acd98f78-a807-392a-b79e-7287b082e2ea', 'Confidence': 99.99919891357422}, {'FaceId': '5d0a4b7f-63e1-4607-a6dd-0da5bfcfe7fc', 'BoundingBox': {'Width': 0.6686149835586548, 'Height': 0.4729369878768921, 'Left': 0.14576900005340576, 'Top': 0.20694999396800995}, 'ImageId': 'dd16e72d-7770-351c-95a6-d76432bab6fd', 'Confidence': 99.99939727783203}], 'NextToken': 'zXslatsyex3SyTsbqCE/IqmNC3UkwJAdURTPhP8OsE214QuYuOmM+0aN3DDubKxFnkvc0ggDJc/TPTk/P47CrOoLZxngzXQu2FyxrdQHozi0Xk02Jb/zL+o=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '7bf328e5-9769-454e-b2d4-a097633a255e', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '7bf328e5-9769-454e-b2d4-a097633a255e', 'content-type': 'application/x-amz-json-1.1', 'content-length': '740', 'date': 'Tue, 21 Jun 2022 11:57:50 GMT'}, 'RetryAttempts': 0}}
# {'Faces': [{'FaceId': '5d7b4998-478a-4739-bfde-105683a89db0', 'BoundingBox': {'Width': 0.5082359910011292, 'Height': 0.38832899928092957, 'Left': 0.20558799803256989, 'Top': 0.2971250116825104}, 'ImageId': 'c696f7fd-1922-38f2-b9a7-37d0e664122e', 'Confidence': 99.9999008178711}, {'FaceId': '5fac83e7-e861-4fb9-b13e-be36a253ab8a', 'BoundingBox': {'Width': 0.5101619958877563, 'Height': 0.37973999977111816, 'Left': 0.43459001183509827, 'Top': 0.04688769951462746}, 'ImageId': '0afce4bb-a991-3318-9bf4-5b5ff333b3c0', 'Confidence': 99.9999008178711}], 'NextToken': 'k7azElcMcx+f9C28Y3s8uBFob9l+XLrK6f0PRCQ8wEjHw0BPdrFEa7Oesj68T+ikC7T54edPzIYsuySv2Vw338CzAgFxFBa29TjP2Y89DFbLwc8Ys08+Te4=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': 'af34c09b-ec1e-419e-abdc-246479f8bffa', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'af34c09b-ec1e-419e-abdc-246479f8bffa', 'content-type': 'application/x-amz-json-1.1', 'content-length': '740', 'date': 'Tue, 21 Jun 2022 11:57:50 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': '600f3222-0a9d-4bb2-8f38-6f8996833d20', 'BoundingBox': {'Width': 0.43121999502182007, 'Height': 0.4693729877471924, 'Left': 0.3081980049610138, 'Top': 0.07966429740190506}, 'ImageId': '4f97a8e2-d224-3237-8735-ee0e683dd294', 'Confidence': 99.99919891357422}, {'FaceId': '610584a7-7787-4db1-b2a4-ee0dd2ed27b4', 'BoundingBox': {'Width': 0.41273999214172363, 'Height': 0.31684601306915283, 'Left': 0.3031289875507355, 'Top': 0.35329899191856384}, 'ImageId': 'b3339e0c-4869-3fe1-b1dc-e9db14419e60', 'Confidence': 99.99930572509766}], 'NextToken': 'Q7SXqdoP8Dnh7MSkiYRkIkQGR7dGgCxJTt/u85ndvS7W6/UEbAMOhjaps/8Xe2bV1NbRP5QAf1JdfHgox468vle13XuRibXJHdfxZZdAICe/v9QQ6vRTQcM=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '22d496cb-a941-4e5f-827c-dde7f8e67c9e', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '22d496cb-a941-4e5f-827c-dde7f8e67c9e', 'content-type': 'application/x-amz-json-1.1', 'content-length': '742', 'date': 'Tue, 21 Jun 2022 11:57:52 GMT'}, 'RetryAttempts': 0}}
#
#
# ...
#
#
# {'Faces': [{'FaceId': 'e2ae8521-8742-43e9-a0b0-43fff8a6909a', 'BoundingBox': {'Width': 0.5035120248794556, 'Height': 0.5608959794044495, 'Left': 0.3317820131778717, 'Top': 0.18636499345302582}, 'ImageId': '59d4fd10-8415-37a6-b239-0d65dd473868', 'Confidence': 99.99930572509766}, {'FaceId': 'e4857cde-1b64-4b5f-b48b-39eb25ae85a8', 'BoundingBox': {'Width': 0.19028499722480774, 'Height': 0.1456809937953949, 'Left': 0.36840999126434326, 'Top': 0.27818599343299866}, 'ImageId': '71bde01d-cd0c-3d61-bebb-4ace7cae20ca', 'Confidence': 99.24539947509766}], 'NextToken': 'r2jUBSYJ+UocjzYI9Y8AcdU25c5UNtvIn1Zn+HBp8c2WMKTtsEyqwz9zEiMq8vBeI6Kj1YbVDv+H4vY2jpOb7cNKQje2T5w6uL03WqN3Jr637n1uE1LZ4RE=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': 'bff79d7e-a4bb-4cc5-a05b-2ceb76611784', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'bff79d7e-a4bb-4cc5-a05b-2ceb76611784', 'content-type': 'application/x-amz-json-1.1', 'content-length': '741', 'date': 'Tue, 21 Jun 2022 11:58:10 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': 'e48b4966-a308-423b-a3f5-a24b86b2179a', 'BoundingBox': {'Width': 0.5630679726600647, 'Height': 0.3968920111656189, 'Left': 0.1876019984483719, 'Top': 0.1930840015411377}, 'ImageId': 'fc2cb460-bf6a-39b4-bfff-386d188c45ad', 'Confidence': 99.99979400634766}, {'FaceId': 'e4b63ad2-940d-464c-8350-e50a1a4fa8e8', 'BoundingBox': {'Width': 0.17373399436473846, 'Height': 0.17821399867534637, 'Left': 0.40779200196266174, 'Top': 0.4433729946613312}, 'ImageId': '5f820c9c-16e1-3904-897e-51f96118275f', 'Confidence': 99.99380493164062}], 'NextToken': 'hDtkgzotlXa00A/120TiBSM/5gyIwbv+na6+cwGuh8xivuSESXZCOFGOELSrAq5ledU8yl+fsmJPhK0nhJExQnrx5myDKIDj+BKsPFVzice5DgxeR/e9r8Y=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '8d359390-4a90-4ba6-adc8-52345400cb0c', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '8d359390-4a90-4ba6-adc8-52345400cb0c', 'content-type': 'application/x-amz-json-1.1', 'content-length': '740', 'date': 'Tue, 21 Jun 2022 11:58:10 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': 'e50faee0-d3ae-44bb-bf1c-3846bd0f9e54', 'BoundingBox': {'Width': 0.45709100365638733, 'Height': 0.4610840082168579, 'Left': 0.23002299666404724, 'Top': 0.13873200118541718}, 'ImageId': 'c13950c5-32d3-38e9-84fc-9b9f770651fe', 'Confidence': 99.99970245361328}, {'FaceId': 'e692147a-0a7b-47c3-9e35-5dd640541d17', 'BoundingBox': {'Width': 0.47189900279045105, 'Height': 0.48638901114463806, 'Left': 0.30523499846458435, 'Top': 0.15170200169086456}, 'ImageId': 'f9a0163c-4893-3ed8-9aa1-de92d74beca7', 'Confidence': 99.99889373779297}], 'NextToken': 'FHwrlNvhTyG7fqGLQ122q/Ad4QqTUiryIrFLorsi1pKDdhMp4r595OCKzgpzZ9GaCQv39O/yfQV6tWZnh4SlMPu4mtfB6x201OaiS2Oz89sqqi0+su0Vnb4=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': 'e45bd516-29da-4e13-9aa7-c28720393147', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'e45bd516-29da-4e13-9aa7-c28720393147', 'content-type': 'application/x-amz-json-1.1', 'content-length': '744', 'date': 'Tue, 21 Jun 2022 11:58:11 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': 'e97541b5-7b93-4263-85b8-e198bdbd14c6', 'BoundingBox': {'Width': 0.36859598755836487, 'Height': 0.3894380033016205, 'Left': 0.2688769996166229, 'Top': 0.3109770119190216}, 'ImageId': '230dbffa-ebf9-31fb-a227-58382191589b', 'Confidence': 99.9999008178711}, {'FaceId': 'ee1235db-268f-4abe-b01e-67adaf392f09', 'BoundingBox': {'Width': 0.37899699807167053, 'Height': 0.4140259921550751, 'Left': 0.2476859986782074, 'Top': 0.3122220039367676}, 'ImageId': '942a7ce0-7e8c-368a-9623-9d2c1f831606', 'Confidence': 100.0}], 'NextToken': 'J06OS04/Dco+57xnXBJm9m0CIaTY8TqJtGgdbxAnhHr79JXZNiin0pe/FT6YTlnn7D7Y06nFrgecUjRbBUWr1Hdm+XEDJb8E7WiBp1JeUPaKG+myXYsg8Ho=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': 'ab3baedd-37a2-4b97-8ac9-4b2cb89b8404', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'ab3baedd-37a2-4b97-8ac9-4b2cb89b8404', 'content-type': 'application/x-amz-json-1.1', 'content-length': '726', 'date': 'Tue, 21 Jun 2022 11:58:11 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': 'ef1b6e8f-c35b-487d-ac55-d0de5d9e1411', 'BoundingBox': {'Width': 0.31074899435043335, 'Height': 0.3320789933204651, 'Left': 0.2585830092430115, 'Top': 0.13117100298404694}, 'ImageId': 'ada52573-f223-3329-8fd7-430ad3655ce7', 'Confidence': 99.99930572509766}, {'FaceId': 'efb68c96-33bf-451b-96a9-f9cc7146180b', 'BoundingBox': {'Width': 0.3139500021934509, 'Height': 0.31575700640678406, 'Left': 0.3618229925632477, 'Top': 0.4139769971370697}, 'ImageId': '766c0a06-d071-3857-9ecd-d372940840a9', 'Confidence': 99.99949645996094}], 'NextToken': 'Top5orgLy9U+YkUf8q7fkSpjC+S/O59Ke04dOBThmQ0XO/jGSqt/RbavNbOn+CnOakZ9SjzEUt+3X0q91U/bTN5kg+PcPtcukmMHjcVc9BpDikZ7E4Yc7ts=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '9e59f286-9db6-4cd3-b883-d9f8a253722c', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '9e59f286-9db6-4cd3-b883-d9f8a253722c', 'content-type': 'application/x-amz-json-1.1', 'content-length': '740', 'date': 'Tue, 21 Jun 2022 11:58:11 GMT'}, 'RetryAttempts': 0}}
# {'Faces': [{'FaceId': 'f1e7ba17-7921-4bd0-ba31-82426bd93474', 'BoundingBox': {'Width': 0.6696289777755737, 'Height': 0.40789198875427246, 'Left': 0.17417900264263153, 'Top': 0.31805500388145447}, 'ImageId': '4d84e0c0-d308-39b0-ab80-274fae3ff7eb', 'Confidence': 99.9999008178711}, {'FaceId': 'f1effdc6-4b9c-458d-a994-5bbb1f73c65e', 'BoundingBox': {'Width': 0.4872890114784241, 'Height': 0.5218819975852966, 'Left': 0.3055900037288666, 'Top': 0.18034599721431732}, 'ImageId': '4c43315e-c71c-3fe1-ac06-7d849e275a1c', 'Confidence': 99.99800109863281}], 'NextToken': 'hKJPKZSwc6Y+qGNH4Pj53BkXnFRWHQjuo6i77yum3+gMjyh18wKPY9QbuQWdEHwVQrofXFhRbNC2MZbsswODYa1ySo+TRxlE7u47lAdrIJw/mg6DOwLUIkk=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': 'cbd467a6-012a-48eb-bc1c-bb4eb951a9a2', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'cbd467a6-012a-48eb-bc1c-bb4eb951a9a2', 'content-type': 'application/x-amz-json-1.1', 'content-length': '740', 'date': 'Tue, 21 Jun 2022 11:58:11 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': 'f3b3eac2-26b3-41e9-9898-cc6df4001378', 'BoundingBox': {'Width': 0.30970698595046997, 'Height': 0.29962998628616333, 'Left': 0.21139200031757355, 'Top': 0.3222379982471466}, 'ImageId': 'ccc81648-a03b-359a-9d42-9d7b6f58b469', 'Confidence': 99.99939727783203}, {'FaceId': 'f4899b3e-49cf-499a-90ea-3a2dae9ffec8', 'BoundingBox': {'Width': 0.3053230047225952, 'Height': 0.24132099747657776, 'Left': 0.3505620062351227, 'Top': 0.3095589876174927}, 'ImageId': '43c602e2-ed5b-3a05-9e97-5c94119e3902', 'Confidence': 99.97489929199219}], 'NextToken': 'Hn30FANB48LtbBw0WJUj0xPjE7dhmrG+vAiVPRYfYGFW3xgGS+E+7Zwwp9jf7wvZzbZThMLsOS6hHZRqhZoENOHJU9FdIqJn0xIo+jnQ6UVBRiw8htfGsb8=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': 'd1e8e635-1e89-4d72-b1e5-4ad14efd7ea6', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'd1e8e635-1e89-4d72-b1e5-4ad14efd7ea6', 'content-type': 'application/x-amz-json-1.1', 'content-length': '741', 'date': 'Tue, 21 Jun 2022 11:58:11 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': 'f4f4678c-c86c-4600-b46f-32cf6f5a5455', 'BoundingBox': {'Width': 0.38534799218177795, 'Height': 0.3883489966392517, 'Left': 0.32729899883270264, 'Top': 0.29180800914764404}, 'ImageId': '2b65479f-5dbb-32a8-adfb-e6e705f01503', 'Confidence': 100.0}, {'FaceId': 'f52eae1a-c706-42f2-a563-b2e2300788c3', 'BoundingBox': {'Width': 0.3567740023136139, 'Height': 0.36641499400138855, 'Left': 0.2735840082168579, 'Top': 0.20737899839878082}, 'ImageId': 'ad2f22c8-c392-3e19-b984-357f32f46ace', 'Confidence': 99.99979400634766}], 'NextToken': 'zJBCGWXHXmItJBYzi7ppjsRPpsO+jlN2GyrTdYC8xjxgah7g4AG3bWt1AH5GcZejL6NjPoDWfx2NkLZ/7UtehGwz0XiW7LobgGG1aWSSfdF8uz58meOUfWs=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': 'c26e6678-c032-4e3d-8f60-4cb8400779b2', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'c26e6678-c032-4e3d-8f60-4cb8400779b2', 'content-type': 'application/x-amz-json-1.1', 'content-length': '730', 'date': 'Tue, 21 Jun 2022 11:58:12 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': 'f6c7273c-442e-486c-b6ec-29cf7e0f376d', 'BoundingBox': {'Width': 0.4694019854068756, 'Height': 0.29518499970436096, 'Left': 0.23672500252723694, 'Top': 0.34163498878479004}, 'ImageId': '0efa53ca-9bcf-3947-a1ee-1dabf510b562', 'Confidence': 99.99949645996094}, {'FaceId': 'f76c7c76-f154-4a68-905c-0ca142aa14b4', 'BoundingBox': {'Width': 0.13026100397109985, 'Height': 0.1476919949054718, 'Left': 0.4570859968662262, 'Top': 0.4175789952278137}, 'ImageId': 'f172d1b3-3618-3a76-84a2-e0eb5ef556ae', 'Confidence': 99.98660278320312}], 'NextToken': 'fLxBwXOtLO2hjaIhNF9xwgtTO14Qu75DC4dJ7NLipO4FjPf4K6/XYRDtsJE1PRufHDnh2QIgHRznpPOzHwhqtwj73qyM+uLVfaOxSodt46VWeZUh2RJ5Hcc=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '37110369-e235-4e07-9020-a3372627028e', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '37110369-e235-4e07-9020-a3372627028e', 'content-type': 'application/x-amz-json-1.1', 'content-length': '741', 'date': 'Tue, 21 Jun 2022 11:58:12 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': 'f7d98b8b-445d-45ab-a31b-e229421ed526', 'BoundingBox': {'Width': 0.12341099977493286, 'Height': 0.12546400725841522, 'Left': 0.3870899975299835, 'Top': 0.2714410126209259}, 'ImageId': '05ccaa71-0a2b-3586-b76f-c99b61f6cac7', 'Confidence': 99.97090148925781}, {'FaceId': 'f7d9bb2f-dd08-46e4-b977-777090c5d2c2', 'BoundingBox': {'Width': 0.39136001467704773, 'Height': 0.4162389934062958, 'Left': 0.21946899592876434, 'Top': 0.12647800147533417}, 'ImageId': 'd905131d-9d54-3023-a013-b4ed5c14a60d', 'Confidence': 100.0}], 'NextToken': 'pweXppcPnYPi1SwKdqOEwnBG2kpN4TsPC77BxTL/5WFrQTMFOXh3N/3zVmqqYzSh+nn8ad9Dqbs2Pe+aooa0lSUuzrwpGrKqMsPspP8vbuoCzThDnW3X6NU=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '8a3c5488-dfd1-4402-ab9e-230ea31cabe8', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '8a3c5488-dfd1-4402-ab9e-230ea31cabe8', 'content-type': 'application/x-amz-json-1.1', 'content-length': '730', 'date': 'Tue, 21 Jun 2022 11:58:12 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': 'f7eb0a8e-c1e5-45bb-bfef-279dcef5a004', 'BoundingBox': {'Width': 0.4967010021209717, 'Height': 0.7407150268554688, 'Left': 0.21812300384044647, 'Top': 0.184006005525589}, 'ImageId': '596c98ae-31e0-34c8-813f-55baa7d4fa54', 'Confidence': 99.9999008178711}, {'FaceId': 'f8b5223f-bea3-4ebc-9a07-cf1d65f28856', 'BoundingBox': {'Width': 0.3239090144634247, 'Height': 0.3327459990978241, 'Left': 0.3142769932746887, 'Top': 0.30881598591804504}, 'ImageId': 'cd1abbd3-a4a9-366b-b370-e95da0a43660', 'Confidence': 99.99949645996094}], 'NextToken': 'DIbAD58Nrvzj1Kl6AUfH3LpPCHK+nhYgMndxe/qVBlFjgRxXOwcrNrOvbTgKAdLFt3Ko1rh8PDmMHc8kwSHw+hcgWHHXggy96DCEugkLPsQSuyJCo3aLnvk=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': 'f7ea7b4c-f9d5-44cd-bb72-b1d365701d88', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'f7ea7b4c-f9d5-44cd-bb72-b1d365701d88', 'content-type': 'application/x-amz-json-1.1', 'content-length': '737', 'date': 'Tue, 21 Jun 2022 11:58:12 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': 'f8d45d89-af4b-4705-addc-d34db72a5b05', 'BoundingBox': {'Width': 0.5767930150032043, 'Height': 0.649370014667511, 'Left': 0.27188101410865784, 'Top': 0.276324987411499}, 'ImageId': 'dc744f3d-e504-3618-953b-788d7c9551ab', 'Confidence': 99.9999008178711}, {'FaceId': 'f9a7e1f9-5aa5-4c9f-a53a-296f02418672', 'BoundingBox': {'Width': 0.5563290119171143, 'Height': 0.38137900829315186, 'Left': 0.1784140020608902, 'Top': 0.32625100016593933}, 'ImageId': '91d2e4ac-6315-3559-860e-b72535ca6550', 'Confidence': 99.99979400634766}], 'NextToken': 'Yr2J3MGdNc6J9w8vGAENh4Njou+AnjFaz1GbmkxbaIgm21PS3ldYrWnW+VmJd7CZJUqMGa9VS99vum+jDD57K/9fdg8+xEFs3OCPi8Wqk6zX+qO0TPyc8DQ=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '2c8583c7-99b2-4b8b-8324-2ef47ae9b814', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '2c8583c7-99b2-4b8b-8324-2ef47ae9b814', 'content-type': 'application/x-amz-json-1.1', 'content-length': '737', 'date': 'Tue, 21 Jun 2022 11:58:13 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': 'f9ee4d26-eb57-40d4-907f-bd297c45824d', 'BoundingBox': {'Width': 0.2841300070285797, 'Height': 0.3000589907169342, 'Left': 0.34349098801612854, 'Top': 0.2876189947128296}, 'ImageId': 'eb94a010-ffa9-376c-a02f-1359dc80e0bf', 'Confidence': 99.99930572509766}, {'FaceId': 'fb3921d6-f706-4dd6-b19f-1be8e0ecff5e', 'BoundingBox': {'Width': 0.36271798610687256, 'Height': 0.39815598726272583, 'Left': 0.36285001039505005, 'Top': 0.3541960120201111}, 'ImageId': 'c485f75d-d8ef-3b5d-b94a-9a63af4da0a4', 'Confidence': 99.9999008178711}], 'NextToken': 'IMwjjJEadlVJ8Cay5cyKT7hsmbtxtEe8+BIOvucw+1dbDlnZILTdgU9Kc1ye673R7A1ZSWE4A0ab10C82iQOykqSboMYIN5QMxR8xBFGAkqyvlG0g/6Ti0I=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '4a2b17a4-501f-4341-8bb6-061c21e96c74', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '4a2b17a4-501f-4341-8bb6-061c21e96c74', 'content-type': 'application/x-amz-json-1.1', 'content-length': '740', 'date': 'Tue, 21 Jun 2022 11:58:13 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': 'fbcec673-2644-45b1-a993-0f0c66eb9443', 'BoundingBox': {'Width': 0.49563199281692505, 'Height': 0.4813460111618042, 'Left': 0.03775250166654587, 'Top': 0.3151789903640747}, 'ImageId': '4f8f0e36-bf86-363d-b110-e893dfdfdfa5', 'Confidence': 99.99970245361328}, {'FaceId': 'fc3b8580-002d-40e2-9850-8abf193aa6e1', 'BoundingBox': {'Width': 0.5089240074157715, 'Height': 0.568356990814209, 'Left': 0.2927579879760742, 'Top': 0.029130199924111366}, 'ImageId': 'da55fc1b-90bd-32de-bf4a-a4cc57b44e52', 'Confidence': 99.99889373779297}], 'NextToken': 'ohGGtfwIgpbmJIkkD/bcyuCTcvBMjAmRuX2lDUsF+u4h+YVQx09+mDefKrCx6EZFYeLOANEGSNF8gYUtuKPBNw0gt7rxJobhH0yhVOhH9t1Gbt/r4zFjp2U=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '1d0925cb-0906-4c84-b619-ef163f5d723a', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '1d0925cb-0906-4c84-b619-ef163f5d723a', 'content-type': 'application/x-amz-json-1.1', 'content-length': '740', 'date': 'Tue, 21 Jun 2022 11:58:13 GMT'}, 'RetryAttempts': 0}}
# {'Faces': [{'FaceId': 'fe7b3d20-c58c-44d3-9cd4-411643c477da', 'BoundingBox': {'Width': 0.5342140197753906, 'Height': 0.32346099615097046, 'Left': 0.27386200428009033, 'Top': 0.451990008354187}, 'ImageId': 'd912ebae-bc06-3b56-8d43-69eaf80109c6', 'Confidence': 99.99960327148438}, {'FaceId': 'febcbdc7-7371-4589-89ae-bd6e0ee683e6', 'BoundingBox': {'Width': 0.5946409702301025, 'Height': 0.4034219980239868, 'Left': 0.15620000660419464, 'Top': 0.28080299496650696}, 'ImageId': '8134e949-9142-3836-b337-4161e9f5fcbc', 'Confidence': 99.9999008178711}], 'NextToken': '1tGE/MFFELGuT7rABmtNGyPI4dW0LDuedkhqnsjx13gEeUzlckMGAIK4gj8rd0+C+s12pa0zWZAKiv44mIlHKnqXwE4YS8oWb2Ks9BEC0iM+EW6mXOqrMnY=', 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': '1fec55c3-e7ce-4077-a36d-2f606a4b6b41', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '1fec55c3-e7ce-4077-a36d-2f606a4b6b41', 'content-type': 'application/x-amz-json-1.1', 'content-length': '739', 'date': 'Tue, 21 Jun 2022 11:58:13 GMT'}, 'RetryAttempts': 0}}
#
#
# {'Faces': [{'FaceId': 'ff22d231-0e33-4914-85a2-c523c853f435', 'BoundingBox': {'Width': 0.3718329966068268, 'Height': 0.4039129912853241, 'Left': 0.383186012506485, 'Top': 0.3103390038013458}, 'ImageId': '2fc6dc71-8e14-308b-9ccd-a30d78d8a081', 'Confidence': 99.99979400634766}], 'FaceModelVersion': '6.0', 'ResponseMetadata': {'RequestId': 'c3ea951c-a478-4319-8f2b-fa3a50b17216', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'c3ea951c-a478-4319-8f2b-fa3a50b17216', 'content-type': 'application/x-amz-json-1.1', 'content-length': '318', 'date': 'Tue, 21 Jun 2022 11:58:13 GMT'}, 'RetryAttempts': 0}}
#
# faces count: 251

# %%
#Copyright 2018 Amazon.com, Inc. or its affiliates. All Rights Reserved.
#PDX-License-Identifier: MIT-0 (For details, see https://github.com/awsdocs/amazon-rekognition-developer-guide/blob/master/LICENSE-SAMPLECODE.)

import boto3
from botocore.exceptions import ClientError
from os import environ

def delete_collection(collection_id):


    print('Attempting to delete collection ' + collection_id)
    client=boto3.client('rekognition')
    status_code=0
    try:
        response=client.delete_collection(CollectionId=collection_id)
        status_code=response['StatusCode']
        
    except ClientError as e:
        if e.response['Error']['Code'] == 'ResourceNotFoundException':
            print ('The collection ' + collection_id + ' was not found ')
        else:
            print ('Error other than Not Found occurred: ' + e.response['Error']['Message'])
        status_code=e.response['ResponseMetadata']['HTTPStatusCode']
    return(status_code)


def main():
    collection_id='attandence_collection'
    status_code=delete_collection(collection_id)
    print('Status code: ' + str(status_code))

if __name__ == "__main__":
    main()
# Out:
# Attempting to delete collection attandence_collection
# Status code: 200

# %%
import boto3


BUCKET = "attandence-bucket"
KEY = "index/abcd.png"
FEATURES_BLACKLIST = ("Landmarks", "Emotions", "Pose", "Quality", "BoundingBox", "Confidence")

def detect_faces(bucket, key, attributes=['ALL'], region="us-east-2"):
    rekognition = boto3.client("rekognition", region)
    response = rekognition.detect_faces(
        Image={
            "S3Object": {
                "Bucket": bucket,
                "Name": key,
            }
        },
        Attributes=attributes,
    )
    return response['FaceDetails']

for face in detect_faces(BUCKET, KEY):
    print ("Face ({Confidence}%)".format(**face))
    # emotions
    for emotion in face['Emotions']:
        print ("  {Type} : {Confidence}%".format(**emotion))
    # quality
    for quality, value in face['Quality'].iteritems():
        print ("  {quality} : {value}".format(quality=quality, value=value))
    # facial features
    for feature, data in face.iteritems():
        if feature not in FEATURES_BLACKLIST:
            print ("  {feature}({data[Value]}) : {data[Confidence]}%".format(feature=feature, data=data))
# Out:
# Face (99.6942138671875%)
#   SURPRISED : 81.62865447998047%
#   CALM : 8.259970664978027%
#   ANGRY : 4.233240604400635%
#   FEAR : 2.26208233833313%
#   CONFUSED : 1.805971622467041%
#   DISGUSTED : 0.7482640743255615%
#   SAD : 0.5447291731834412%
#   HAPPY : 0.5170879364013672%
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_5020/2468409127.py in <module>
#      25         print ("  {Type} : {Confidence}%".format(**emotion))
#      26     # quality
# ---> 27     for quality, value in face['Quality'].iteritems():
#      28         print ("  {quality} : {value}".format(quality=quality, value=value))
#      29     # facial features
#
# AttributeError: 'dict' object has no attribute 'iteritems'

# %%
a='<div class="contaienr"><div class="col-lg-4 mb-5"> '+'<div class="practicing">'+'<div class="practicing-inner">'+'<div class="wrap-icon">'+'<span class="flaticon-museum"></span>'+'</div>'+'<h3>Bankruptcy Law</h3>'+'<p>Lorem ipsum dolor sit amet, consectetur adipisicing elit. Vero, laboriosam!</p>'+'</div>'+'</div>'+'</div>'+'<div class="col-lg-4 mb-5">'+'<div class="practicing">'+'<div class="practicing-inner">'+'<div class="wrap-icon">'+'<span class="flaticon-shield"></span>'+'</div>'+'<h3>Business Law</h3>'+'<p>Lorem ipsum dolor sit amet, consectetur adipisicing elit. Vero, laboriosam!</p>'+'</div>'+'</div>'+'</div>'+'<div class="col-lg-4 mb-5">'+'<div class="practicing">'+'<div class="practicing-inner">'+'<div class="wrap-icon">'+'<span class="flaticon-help"></span>'+'</div>'+'<h3>Civil Rights Law</h3>'+'<p>Lorem ipsum dolor sit amet, consectetur adipisicing elit. Vero, laboriosam!</p>'+'</div>'+'</div>'+'</div>'+'<div class="col-lg-4 mb-5">'+'<div class="practicing">'+'<div class="practicing-inner">'+'<div class="wrap-icon">'+'<span class="flaticon-revolver"></span>'+'</div>'+'<h3>Criminal Law</h3>'+'<p>Lorem ipsum dolor sit amet, consectetur adipisicing elit. Vero, laboriosam!</p>'+'</div>'+'</div>'+'</div>'+'<div class="col-lg-4 mb-5">'+'<div class="practicing">'+'<div class="practicing-inner">'+'<div class="wrap-icon">'+'<span class="flaticon-luggage"></span>'+'</div>'+'<h3>Immigration Law</h3>'+'<p>Lorem ipsum dolor sit amet, consectetur adipisicing elit. Vero, laboriosam!</p>'+'</div>'+'</div>'+'</div>'+'<div class="col-lg-4 mb-5">'+'<div class="practicing">'+'<div class="practicing-inner">'+'<div class="wrap-icon">'+'<span class="flaticon-house"></span>'+'</div>'+'<h3>Family Law</h3>'+'<p>Lorem ipsum dolor sit amet, consectetur adipisicing elit. Vero, laboriosam!</p>'+'</div>'+'</div>'+'</div></div>'

# %%
a
# Out:
# '<div class="contaienr"><div class="col-lg-4 mb-5"> <div class="practicing"><div class="practicing-inner"><div class="wrap-icon"><span class="flaticon-museum"></span></div><h3>Bankruptcy Law</h3><p>Lorem ipsum dolor sit amet, consectetur adipisicing elit. Vero, laboriosam!</p></div></div></div><div class="col-lg-4 mb-5"><div class="practicing"><div class="practicing-inner"><div class="wrap-icon"><span class="flaticon-shield"></span></div><h3>Business Law</h3><p>Lorem ipsum dolor sit amet, consectetur adipisicing elit. Vero, laboriosam!</p></div></div></div><div class="col-lg-4 mb-5"><div class="practicing"><div class="practicing-inner"><div class="wrap-icon"><span class="flaticon-help"></span></div><h3>Civil Rights Law</h3><p>Lorem ipsum dolor sit amet, consectetur adipisicing elit. Vero, laboriosam!</p></div></div></div><div class="col-lg-4 mb-5"><div class="practicing"><div class="practicing-inner"><div class="wrap-icon"><span class="flaticon-revolver"></span></div><h3>Criminal Law</h3><p>Lorem ipsum dolor sit amet, consectetur adipisicing elit. Vero, laboriosam!</p></div></div></div><div class="col-lg-4 mb-5"><div class="practicing"><div class="practicing-inner"><div class="wrap-icon"><span class="flaticon-luggage"></span></div><h3>Immigration Law</h3><p>Lorem ipsum dolor sit amet, consectetur adipisicing elit. Vero, laboriosam!</p></div></div></div><div class="col-lg-4 mb-5"><div class="practicing"><div class="practicing-inner"><div class="wrap-icon"><span class="flaticon-house"></span></div><h3>Family Law</h3><p>Lorem ipsum dolor sit amet, consectetur adipisicing elit. Vero, laboriosam!</p></div></div></div></div>'
